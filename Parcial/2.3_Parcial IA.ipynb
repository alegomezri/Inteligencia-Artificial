# %% [markdown]
# # 2.3 Modelo de clasificiacion MNIST con autoencoders

# %%
# !pip install -U git+https://github.com/UN-GCPDS/python-gcpds.EEG_Tensorflow_models
# Out:
# Collecting git+https://github.com/UN-GCPDS/python-gcpds.EEG_Tensorflow_models
#   Cloning https://github.com/UN-GCPDS/python-gcpds.EEG_Tensorflow_models to /tmp/pip-req-build-t4n0cebd
#   Running command git clone --filter=blob:none --quiet https://github.com/UN-GCPDS/python-gcpds.EEG_Tensorflow_models /tmp/pip-req-build-t4n0cebd
#   Resolved https://github.com/UN-GCPDS/python-gcpds.EEG_Tensorflow_models to commit 975885b1f6814fd5958199919b33e02a6a9aa152
#   Preparing metadata (setup.py) ... done
# Collecting braindecode==0.7 (from EEG_Tensorflow_models==0.2)
#   Downloading Braindecode-0.7-py3-none-any.whl.metadata (6.8 kB)
# Collecting moabb (from EEG_Tensorflow_models==0.2)
#   Downloading moabb-1.1.0-py3-none-any.whl.metadata (16 kB)
# Collecting tensorflow-addons (from EEG_Tensorflow_models==0.2)
#   Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.8 kB)
# Requirement already satisfied: tensorflow>=2.8 in /opt/conda/lib/python3.10/site-packages (from EEG_Tensorflow_models==0.2) (2.15.0)
# Collecting tf-keras-vis (from EEG_Tensorflow_models==0.2)
#   Downloading tf_keras_vis-0.8.7-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: mne in /opt/conda/lib/python3.10/site-packages (from braindecode==0.7->EEG_Tensorflow_models==0.2) (1.6.1)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from braindecode==0.7->EEG_Tensorflow_models==0.2) (1.26.4)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from braindecode==0.7->EEG_Tensorflow_models==0.2) (2.1.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from braindecode==0.7->EEG_Tensorflow_models==0.2) (1.11.4)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from braindecode==0.7->EEG_Tensorflow_models==0.2) (3.7.5)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.10/site-packages (from braindecode==0.7->EEG_Tensorflow_models==0.2) (3.10.0)
# Collecting skorch (from braindecode==0.7->EEG_Tensorflow_models==0.2)
#   Downloading skorch-1.0.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.8->EEG_Tensorflow_models==0.2) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.8->EEG_Tensorflow_models==0.2) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.8->EEG_Tensorflow_models==0.2) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.8->EEG_Tensorflow_models==0.2) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.8->EEG_Tensorflow_models==0.2) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.8->EEG_Tensorflow_models==0.2) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.8->EEG_Tensorflow_models==0.2) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.8->EEG_Tensorflow_models==0.2) (3.3.0)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.8->EEG_Tensorflow_models==0.2) (21.3)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.8->EEG_Tensorflow_models==0.2) (3.20.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.8->EEG_Tensorflow_models==0.2) (69.0.3)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.8->EEG_Tensorflow_models==0.2) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.8->EEG_Tensorflow_models==0.2) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.8->EEG_Tensorflow_models==0.2) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.8->EEG_Tensorflow_models==0.2) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.8->EEG_Tensorflow_models==0.2) (0.35.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.8->EEG_Tensorflow_models==0.2) (1.51.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.8->EEG_Tensorflow_models==0.2) (2.15.1)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in /opt/conda/lib/python3.10/site-packages (from tensorflow>=2.8->EEG_Tensorflow_models==0.2) (2.15.0)
# Collecting keras<2.16,>=2.15.0 (from tensorflow>=2.8->EEG_Tensorflow_models==0.2)
#   Downloading keras-2.15.0-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: PyYAML<7.0,>=6.0 in /opt/conda/lib/python3.10/site-packages (from moabb->EEG_Tensorflow_models==0.2) (6.0.1)
# Collecting coverage<8.0.0,>=7.0.1 (from moabb->EEG_Tensorflow_models==0.2)
#   Downloading coverage-7.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.3 kB)
# Collecting edfio<0.5.0,>=0.4.2 (from moabb->EEG_Tensorflow_models==0.2)
#   Downloading edfio-0.4.3-py3-none-any.whl.metadata (4.0 kB)
# Collecting edflib-python<2.0.0,>=1.0.6 (from moabb->EEG_Tensorflow_models==0.2)
#   Downloading EDFlib_Python-1.0.8-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: memory-profiler<0.62.0,>=0.61.0 in /opt/conda/lib/python3.10/site-packages (from moabb->EEG_Tensorflow_models==0.2) (0.61.0)
# Collecting mne (from braindecode==0.7->EEG_Tensorflow_models==0.2)
#   Downloading mne-1.7.1-py3-none-any.whl.metadata (13 kB)
# Collecting mne-bids<0.15,>=0.14 (from moabb->EEG_Tensorflow_models==0.2)
#   Downloading mne_bids-0.14-py2.py3-none-any.whl.metadata (4.8 kB)
# Collecting pandas (from braindecode==0.7->EEG_Tensorflow_models==0.2)
#   Downloading pandas-1.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: pooch<2.0.0,>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from moabb->EEG_Tensorflow_models==0.2) (1.8.1)
# Collecting pyriemann<0.7,>=0.6 (from moabb->EEG_Tensorflow_models==0.2)
#   Downloading pyriemann-0.6-py2.py3-none-any.whl.metadata (8.3 kB)
# Collecting pytest<8.0.0,>=7.4.0 (from moabb->EEG_Tensorflow_models==0.2)
#   Downloading pytest-7.4.4-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /opt/conda/lib/python3.10/site-packages (from moabb->EEG_Tensorflow_models==0.2) (2.31.0)
# Collecting scikit-learn>=1.4.2 (from moabb->EEG_Tensorflow_models==0.2)
#   Downloading scikit_learn-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: seaborn<0.13.0,>=0.12.1 in /opt/conda/lib/python3.10/site-packages (from moabb->EEG_Tensorflow_models==0.2) (0.12.2)
# Requirement already satisfied: tqdm<5.0.0,>=4.64.1 in /opt/conda/lib/python3.10/site-packages (from moabb->EEG_Tensorflow_models==0.2) (4.66.1)
# Requirement already satisfied: urllib3<2.0.0,>=1.26.15 in /opt/conda/lib/python3.10/site-packages (from moabb->EEG_Tensorflow_models==0.2) (1.26.18)
# Collecting typeguard<3.0.0,>=2.7 (from tensorflow-addons->EEG_Tensorflow_models==0.2)
#   Downloading typeguard-2.13.3-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: pillow in /opt/conda/lib/python3.10/site-packages (from tf-keras-vis->EEG_Tensorflow_models==0.2) (9.5.0)
# Requirement already satisfied: deprecated in /opt/conda/lib/python3.10/site-packages (from tf-keras-vis->EEG_Tensorflow_models==0.2) (1.2.14)
# Requirement already satisfied: imageio in /opt/conda/lib/python3.10/site-packages (from tf-keras-vis->EEG_Tensorflow_models==0.2) (2.33.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/conda/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow>=2.8->EEG_Tensorflow_models==0.2) (0.42.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->braindecode==0.7->EEG_Tensorflow_models==0.2) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->braindecode==0.7->EEG_Tensorflow_models==0.2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->braindecode==0.7->EEG_Tensorflow_models==0.2) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->braindecode==0.7->EEG_Tensorflow_models==0.2) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->braindecode==0.7->EEG_Tensorflow_models==0.2) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->braindecode==0.7->EEG_Tensorflow_models==0.2) (2.9.0.post0)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from memory-profiler<0.62.0,>=0.61.0->moabb->EEG_Tensorflow_models==0.2) (5.9.3)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from mne->braindecode==0.7->EEG_Tensorflow_models==0.2) (5.1.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from mne->braindecode==0.7->EEG_Tensorflow_models==0.2) (3.1.2)
# Requirement already satisfied: lazy-loader>=0.3 in /opt/conda/lib/python3.10/site-packages (from mne->braindecode==0.7->EEG_Tensorflow_models==0.2) (0.3)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->braindecode==0.7->EEG_Tensorflow_models==0.2) (2023.3.post1)
# Requirement already satisfied: platformdirs>=2.5.0 in /opt/conda/lib/python3.10/site-packages (from pooch<2.0.0,>=1.6.0->moabb->EEG_Tensorflow_models==0.2) (4.2.0)
# Requirement already satisfied: joblib in /opt/conda/lib/python3.10/site-packages (from pyriemann<0.7,>=0.6->moabb->EEG_Tensorflow_models==0.2) (1.4.0)
# Requirement already satisfied: iniconfig in /opt/conda/lib/python3.10/site-packages (from pytest<8.0.0,>=7.4.0->moabb->EEG_Tensorflow_models==0.2) (2.0.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /opt/conda/lib/python3.10/site-packages (from pytest<8.0.0,>=7.4.0->moabb->EEG_Tensorflow_models==0.2) (1.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /opt/conda/lib/python3.10/site-packages (from pytest<8.0.0,>=7.4.0->moabb->EEG_Tensorflow_models==0.2) (1.2.0)
# Requirement already satisfied: tomli>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from pytest<8.0.0,>=7.4.0->moabb->EEG_Tensorflow_models==0.2) (2.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->moabb->EEG_Tensorflow_models==0.2) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->moabb->EEG_Tensorflow_models==0.2) (3.6)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0.0,>=2.28.1->moabb->EEG_Tensorflow_models==0.2) (2024.2.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn>=1.4.2->moabb->EEG_Tensorflow_models==0.2) (3.2.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.8->EEG_Tensorflow_models==0.2) (2.26.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.8->EEG_Tensorflow_models==0.2) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.8->EEG_Tensorflow_models==0.2) (3.5.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.8->EEG_Tensorflow_models==0.2) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from tensorboard<2.16,>=2.15->tensorflow>=2.8->EEG_Tensorflow_models==0.2) (3.0.2)
# Requirement already satisfied: tabulate>=0.7.7 in /opt/conda/lib/python3.10/site-packages (from skorch->braindecode==0.7->EEG_Tensorflow_models==0.2) (0.9.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.8->EEG_Tensorflow_models==0.2) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.8->EEG_Tensorflow_models==0.2) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /opt/conda/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.8->EEG_Tensorflow_models==0.2) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /opt/conda/lib/python3.10/site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow>=2.8->EEG_Tensorflow_models==0.2) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/conda/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow>=2.8->EEG_Tensorflow_models==0.2) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /opt/conda/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow>=2.8->EEG_Tensorflow_models==0.2) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow>=2.8->EEG_Tensorflow_models==0.2) (3.2.2)
# Downloading Braindecode-0.7-py3-none-any.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.4/184.4 kB 7.2 MB/s eta 0:00:00
# Downloading moabb-1.1.0-py3-none-any.whl (230 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 230.7/230.7 kB 12.0 MB/s eta 0:00:00
# Downloading tensorflow_addons-0.23.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (611 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 611.8/611.8 kB 32.7 MB/s eta 0:00:00
# Downloading tf_keras_vis-0.8.7-py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.5/52.5 kB 3.2 MB/s eta 0:00:00
# Downloading coverage-7.6.1-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (234 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 234.7/234.7 kB 14.0 MB/s eta 0:00:00
# Downloading edfio-0.4.3-py3-none-any.whl (25 kB)
# Downloading EDFlib_Python-1.0.8-py3-none-any.whl (26 kB)
# Downloading keras-2.15.0-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 55.0 MB/s eta 0:00:00
# Downloading mne-1.7.1-py3-none-any.whl (7.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 88.0 MB/s eta 0:00:00:00:0100:01
# Downloading mne_bids-0.14-py2.py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 51.0 MB/s eta 0:00:00
# Downloading pandas-1.5.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 85.1 MB/s eta 0:00:00:00:0100:01
# Downloading pyriemann-0.6-py2.py3-none-any.whl (111 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.7/111.7 kB 6.1 MB/s eta 0:00:00
# Downloading pytest-7.4.4-py3-none-any.whl (325 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 325.3/325.3 kB 20.6 MB/s eta 0:00:00
# Downloading scikit_learn-1.5.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 83.2 MB/s eta 0:00:00:00:0100:01
# Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Downloading skorch-1.0.0-py3-none-any.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 14.9 MB/s eta 0:00:00
# Building wheels for collected packages: EEG_Tensorflow_models
#   Building wheel for EEG_Tensorflow_models (setup.py) ... done
#   Created wheel for EEG_Tensorflow_models: filename=EEG_Tensorflow_models-0.2-py3-none-any.whl size=29376 sha256=3be7ec7b6cf44f79f7793ec739479a2b551b38c83039a5578c7b94bdf4b446c1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-omv0qvru/wheels/05/dc/8a/9d552a33fb901c0d7ab2a72746b5ea17643c570811c711d568
# Successfully built EEG_Tensorflow_models
# Installing collected packages: typeguard, keras, edflib-python, edfio, coverage, tf-keras-vis, tensorflow-addons, scikit-learn, pytest, pandas, skorch, pyriemann, mne, mne-bids, braindecode, moabb, EEG_Tensorflow_models
#   Attempting uninstall: typeguard
#     Found existing installation: typeguard 4.1.5
#     Uninstalling typeguard-4.1.5:
#       Successfully uninstalled typeguard-4.1.5
#   Attempting uninstall: keras
#     Found existing installation: keras 3.2.1
#     Uninstalling keras-3.2.1:
#       Successfully uninstalled keras-3.2.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
#   Attempting uninstall: pytest
#     Found existing installation: pytest 8.1.1
#     Uninstalling pytest-8.1.1:
#       Successfully uninstalled pytest-8.1.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.4
#     Uninstalling pandas-2.1.4:
#       Successfully uninstalled pandas-2.1.4
#   Attempting uninstall: mne
#     Found existing installation: mne 1.6.1
#     Uninstalling mne-1.6.1:
#       Successfully uninstalled mne-1.6.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# cudf 23.8.0 requires cubinlinker, which is not installed.
# cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# cudf 23.8.0 requires ptxcompiler, which is not installed.
# cuml 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# dask-cudf 23.8.0 requires cupy-cuda11x>=12.0.0, which is not installed.
# tensorflow-decision-forests 1.8.1 requires wurlitzer, which is not installed.
# beatrix-jupyterlab 2023.128.151533 requires jupyterlab~=3.6.0, but you have jupyterlab 4.1.6 which is incompatible.
# cudf 23.8.0 requires cuda-python<12.0a0,>=11.7.1, but you have cuda-python 12.4.0 which is incompatible.
# cudf 23.8.0 requires protobuf<5,>=4.21, but you have protobuf 3.20.3 which is incompatible.
# cudf 23.8.0 requires pyarrow==11.*, but you have pyarrow 15.0.2 which is incompatible.
# cuml 23.8.0 requires dask==2023.7.1, but you have dask 2024.4.1 which is incompatible.
# dask-cuda 23.8.0 requires dask==2023.7.1, but you have dask 2024.4.1 which is incompatible.
# dask-cudf 23.8.0 requires dask==2023.7.1, but you have dask 2024.4.1 which is incompatible.
# dask-expr 1.0.11 requires pandas>=2, but you have pandas 1.5.3 which is incompatible.
# featuretools 1.30.0 requires pandas>=2.0.0, but you have pandas 1.5.3 which is incompatible.
# libpysal 4.9.2 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# libpysal 4.9.2 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# mizani 0.11.1 requires pandas>=2.1.0, but you have pandas 1.5.3 which is incompatible.
# momepy 0.7.0 requires shapely>=2, but you have shapely 1.8.5.post1 which is incompatible.
# osmnx 1.9.2 requires shapely>=2.0, but you have shapely 1.8.5.post1 which is incompatible.
# plotnine 0.13.4 requires pandas<3.0.0,>=2.1.0, but you have pandas 1.5.3 which is incompatible.
# pyldavis 3.4.1 requires pandas>=2.0.0, but you have pandas 1.5.3 which is incompatible.
# raft-dask 23.8.0 requires dask==2023.7.1, but you have dask 2024.4.1 which is incompatible.
# spopt 0.6.0 requires shapely>=2.0.1, but you have shapely 1.8.5.post1 which is incompatible.
# woodwork 0.30.0 requires pandas>=2.0.0, but you have pandas 1.5.3 which is incompatible.
# xarray 2024.3.0 requires packaging>=22, but you have packaging 21.3 which is incompatible.
# ydata-profiling 4.6.4 requires numpy<1.26,>=1.16.0, but you have numpy 1.26.4 which is incompatible.
# ydata-profiling 4.6.4 requires typeguard<5,>=4.1.2, but you have typeguard 2.13.3 which is incompatible.
# Successfully installed EEG_Tensorflow_models-0.2 braindecode-0.7 coverage-7.6.1 edfio-0.4.3 edflib-python-1.0.8 keras-2.15.0 mne-1.7.1 mne-bids-0.14 moabb-1.1.0 pandas-1.5.3 pyriemann-0.6 pytest-7.4.4 scikit-learn-1.5.1 skorch-1.0.0 tensorflow-addons-0.23.0 tf-keras-vis-0.8.7 typeguard-2.13.3

# %% [markdown]
# # Librerias

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.layers import Input, Conv2D, Flatten, Dense, Lambda, Reshape, Conv2DTranspose, BatchNormalization, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras import layers, models, initializers,regularizers
from tensorflow.keras.losses import binary_crossentropy
# from tensorflow.keras import backend as K
from tensorflow.keras.datasets import mnist
from tensorflow.keras.optimizers import Adam
from keras.losses import MeanSquaredError
from sklearn.preprocessing import MinMaxScaler
from sklearn.manifold import TSNE
import matplotlib as mpl
from sklearn.model_selection import StratifiedKFold
from tensorflow.keras import backend as K
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import seaborn as sns

from matplotlib import cm
from tf_keras_vis.gradcam_plus_plus import GradcamPlusPlus
from tf_keras_vis.utils.model_modifiers import ReplaceToLinear
from tf_keras_vis.utils.scores import CategoricalScore
from tensorflow.keras.losses import Loss
from tensorflow.keras.utils import to_categorical

# %%
(X_train_full, y_train_full), (X_test, y_test) = keras.datasets.fashion_mnist.load_data()
X_train_full = X_train_full.astype(np.float32) / 255
X_test = X_test.astype(np.float32) / 255
X_train, X_valid = X_train_full[:-5000], X_train_full[-5000:]
y_train, y_valid = y_train_full[:-5000], y_train_full[-5000:]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# Conjunto de datos de entrenamiento, testeo y validación normalizados.

# %%
X_train.shape
# Out:
# (55000, 28, 28)

# %%
y_train.shape
# Out:
# (55000,)

# %%
plt.figure(figsize=(10, 5))

# Etiquetas 
categories = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
              'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']


for i in range(10):
    # Encontrar el primer ejemplo de la categoría actual
    example_index = np.where(y_train == i)[0][0]
    image = X_train[example_index]
    
    # Configurar un subgráfico para cada categoría
    plt.subplot(2, 5, i + 1)  # 2 filas, 5 columnas
    plt.imshow(image, cmap='gray')
    plt.title(categories[i])
    plt.axis('off') 

plt.tight_layout()
plt.show()

# %% [markdown]
# Las etiquetas de la base de datos Mnist Fashion

# %% [markdown]
# # Funciones

# %%
@tf.keras.utils.register_keras_serializable()
class Sampling(tf.keras.layers.Layer):
    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.keras.backend.random_normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
def plot_mnist_autoencoder(x, x_, y=None, y_=None, cmap='gray', vmin=0, vmax=1):
    """
    Plot the original and reconstructed MNIST images using an autoencoder, including labels.
    
    Parameters:
    ----------
    x : Sequence[np.ndarray]
        Original images.
    x_ : Sequence[np.ndarray]
        Reconstructed images.
    y : Optional[Sequence], optional
        True labels of the images, by default None.
    y_ : Optional[Sequence], optional
        Predicted labels of the images, by default None.
    cmap : str, optional
        Color map for the images, by default 'gray'.
    vmin : float, optional
        Minimum value for normalization, by default 0.
    vmax : float, optional
        Maximum value for normalization, by default 1.
    """
    plt.figure(figsize=(20, 4))
    num_images = len(x)
    
    for i in range(num_images):
        # Display original image
        plt.subplot(2, num_images, i + 1)
        plt.imshow(x[i].reshape(28, 28), cmap=cmap, vmin=vmin, vmax=vmax)
        if y is not None:
            plt.title(f'True: {y[i]}')
        plt.axis('off')
        
        # Display reconstructed image
        plt.subplot(2, num_images, num_images + i + 1)
        plt.imshow(x_[i].reshape(28, 28), cmap=cmap, vmin=vmin, vmax=vmax)
        if y_ is not None:
            color = "red" if y is not None and y[i] != y_[i] else 'green'
            plt.title(f'Pred: {y_[i]}', color=color)
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# %%
def compare_images(original_images, predicted_images, true_labels, label_names, indices, figsize=(10, 5)):
    """
    Función para comparar visualmente imágenes originales con las predicciones, mostrando también las etiquetas verdaderas.
    Args:
    original_images (numpy.array): Array de imágenes originales.
    predicted_images (numpy.array): Array de imágenes reconstruidas por el modelo, con la forma (n_samples, height, width, channels).
    true_labels (numpy.array): Array de etiquetas verdaderas para las imágenes originales.
    label_names (list): Lista de nombres de etiquetas correspondientes a las clases.
    indices (list of int): Lista de índices de las imágenes a comparar.
    figsize (tuple): Tamaño de la figura de matplotlib.
    """
    plt.figure(figsize=figsize)
    num_images = len(indices)

    for i, index in enumerate(indices):
        # Mostrar imagen original
        plt.subplot(2, num_images, i + 1)
        plt.imshow(original_images[index].squeeze(), cmap='gray')
        plt.title(f'Original {index}\nLabel: {label_names[true_labels[index]]}')
        plt.axis('off')

        # Mostrar imagen predicha
        plt.subplot(2, num_images, i + 1 + num_images)
        plt.imshow(predicted_images[index].squeeze(), cmap='gray')
        plt.title(f'Reconstrucción {index}')
        plt.axis('off')

    plt.tight_layout()
    plt.show()

# %%
def reconstruction_loss(inputs, outputs):
    return tf.reduce_mean(binary_crossentropy(K.flatten(inputs), K.flatten(outputs)))


def dkl_loss(inputs, outputs):
    z_mean, z_log_var = outputs[...,0], outputs[...,1]
    return - tf.reduce_mean(1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))


def classification_loss(true_labels, softmax_output):
    return tf.reduce_mean(tf.keras.losses.sparse_categorical_crossentropy(true_labels, softmax_output))

# %% [markdown]
# # Modelo

# %% [markdown]
# En mi modelo, se combina la arquitectura de LeNet-5 con un VAE (Variational Autoencoder). LeNet-5 es una red neuronal con 5 capas, de las cuales 3 son convolucionales, diseñada específicamente para la clasificación de imágenes de baja resolución y con un conjunto de datos relativamente pequeño. Esta red es eficaz para evitar el sobreentrenamiento debido a su menor profundidad en comparación con otras arquitecturas más complejas.
#
# He incorporado elementos de un VAE en la parte de reducción de dimensión de LeNet-5, añadiendo un espacio latente y un decodificador. Esto permite no solo la clasificación de imágenes, sino también la reconstrucción de las mismas y la obtención de una representación latente de los datos.
#
# El modelo tiene tres salidas:
#
# * Clasificación (Softmax Output): Esta salida se utiliza para la tarea de clasificación de imágenes en una de las clases predefinidas.
# * Reconstrucción (Reconstruction): Esta salida permite la reconstrucción de la imagen original a partir del espacio latente, facilitando el análisis de cómo el modelo está representando la información internamente.
# * Espacio Latente (Latent Space): Esta salida proporciona las variables latentes, que son útiles para entender las características subyacentes de los datos y pueden ser utilizadas para tareas adicionales como la generación de nuevas muestras.

# %%
def model_class(input_shape=(28, 28, 1), num_classes=10, latent_dim=128):
    
    # Encoder
    inputs = layers.Input(shape=input_shape)
    x = layers.Conv2D(6, kernel_size=3, activation='selu', 
                      kernel_initializer=tf.keras.initializers.GlorotUniform(seed=12), padding='same', name='conv1')(inputs)
    x = layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = layers.Dropout(0.15)(x)
    x = layers.Conv2D(16, kernel_size=3, activation='selu', 
                      kernel_initializer=tf.keras.initializers.GlorotUniform(seed=23), padding='same', name='conv2')(x)
    x = layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = layers.Conv2D(120, kernel_size=3, activation='selu',
                      kernel_initializer=tf.keras.initializers.GlorotUniform(seed=52),padding='same', name='conv3'
                     )(x)
    x = layers.Flatten()(x)
    x = layers.Dropout(0.15)(x)
    
    z_mean = layers.Dense(latent_dim, name='z_mean')(x)
    z_log_var = layers.Dense(latent_dim, name='z_log_var')(x)
    z_gaussian = tf.keras.layers.Concatenate(name='z_gaussian', axis=-1)([z_mean, z_log_var])
    z = Sampling()([z_mean, z_log_var])
    softmax_output = layers.Dense(num_classes, activation='softmax', name='softmax_output')(z)

    # Decoder
    x = layers.Dense(7 * 7 * 16, activation='selu')(z)
    x = layers.Reshape((7, 7, 16))(x)
    x = layers.Conv2DTranspose(16, kernel_size=3, activation='selu',
                               kernel_initializer=tf.keras.initializers.GlorotUniform(seed=12), padding='same')(x)
    x = layers.Dropout(0.15)(x)
    x = layers.UpSampling2D(size=(2, 2))(x)  
    x = layers.Conv2DTranspose(6, kernel_size=3, activation='selu', 
                               kernel_initializer=tf.keras.initializers.GlorotUniform(seed=23), padding='same', name='conv2Transpose')(x)
    x = layers.Dropout(0.15)(x)
    x = layers.UpSampling2D(size=(2, 2))(x)  
    reconstruction = layers.Conv2D(input_shape[2], kernel_size=3, padding='same', activation='sigmoid', name='reconstruction')(x) 

    # VAE Model
    vae = models.Model(inputs, [reconstruction, z_gaussian, softmax_output], name='vae')
    return vae

def build_and_compile_model(input_shape, num_classes, latent_dim, learning_rate):
    model = model_class(input_shape, num_classes, latent_dim)
    
    model.compile(optimizer=Adam(),
                  loss={'reconstruction': reconstruction_loss,
                        'z_gaussian': dkl_loss,
                        'softmax_output': classification_loss},
                  loss_weights={'reconstruction': 0.5,
                                'z_gaussian': 0.1,
                                'softmax_output': 0.4},
                  metrics={'reconstruction': [reconstruction_loss],
                            'z_gaussian': [dkl_loss],
                            'softmax_output': [classification_loss]}
                   )
    return model

# %% [markdown]
# En el modelo, utilice la función de activación **SELU** Garantiza una auto-normalización para modelos secuenciales.
#
# $
# SELU_\alpha(x) = \lambda\left\{\begin{split} \alpha(\exp(x)-1)& \quad if \quad & x < 0 \\
# x & \quad if \quad & x \geq 0 \\
# \end{split}\right.
# $

# %% [markdown]
# # Hiperparametros

# %% [markdown]
# Como hiperparametros del modelo, utilice una semilla, 100 epocas, (una epoca es el ciclo completo en el que el algoritmo de aprendizaje automático pasa por todo el conjunto de datos de entrenamiento una ve) para evaluar como cambiaban las metricas del rendimiento de mi modelo, atraves del tiempo.
#
# Como batch_size, probé 32,64,128, esto signific que el conjunto de datos de entrenamiento se dividirá en batches de 32 muestras cada uno, y los pesos se actualizarán después de cada batch, en mi caso a mi modelo le favorecio el tamaño de 64.
# Y como utilice el optimizador Adam,que calcula adaptativamente las tasas de aprendizaje individuales para cada parámetro del modelo utilizando tanto la primera (media) como la segunda (varianza) de los momentos de los gradientes. La tasa de aprendizaje por defecto que utiliza es 1e-3:
#
# * Tasa de Aprendizaje $(\alpha))$: Controla el tamaño del paso de actualización. Un valor típico es 0.001.
# * $(\beta_1)$: Tasa de decaimiento exponencial para el primer momento. Típicamente se usa 0.9.
# * $(\beta_2)$: Tasa de decaimiento exponencial para el segundo momento. Típicamente se usa 0.999.
# * $(\epsilon)$: Término de estabilidad numérica para evitar divisiones por cero, comúnmente $(10^{-8})$

# %%
seed = 42
epochs = 100
batch_size = 64
learning_rate =1e-3

# %%
model = build_and_compile_model(input_shape=(28, 28, 1), num_classes=10, 
                                    latent_dim=128, learning_rate=learning_rate)
model.summary()
# Out:
# Model: "vae"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]          0         []
#
#  conv1 (Conv2D)              (None, 28, 28, 6)            60        ['input_1[0][0]']
#
#  average_pooling2d (Average  (None, 14, 14, 6)            0         ['conv1[0][0]']
#  Pooling2D)
#
#  dropout (Dropout)           (None, 14, 14, 6)            0         ['average_pooling2d[0][0]']
#
#  conv2 (Conv2D)              (None, 14, 14, 16)           880       ['dropout[0][0]']
#
#  average_pooling2d_1 (Avera  (None, 7, 7, 16)             0         ['conv2[0][0]']
#  gePooling2D)
#
#  conv3 (Conv2D)              (None, 7, 7, 120)            17400     ['average_pooling2d_1[0][0]']
#
#  flatten (Flatten)           (None, 5880)                 0         ['conv3[0][0]']
#
#  dropout_1 (Dropout)         (None, 5880)                 0         ['flatten[0][0]']
#
#  z_mean (Dense)              (None, 128)                  752768    ['dropout_1[0][0]']
#
#  z_log_var (Dense)           (None, 128)                  752768    ['dropout_1[0][0]']
#
#  sampling (Sampling)         (None, 128)                  0         ['z_mean[0][0]',
#                                                                      'z_log_var[0][0]']
#
#  dense (Dense)               (None, 784)                  101136    ['sampling[0][0]']
#
#  reshape (Reshape)           (None, 7, 7, 16)             0         ['dense[0][0]']
#
#  conv2d_transpose (Conv2DTr  (None, 7, 7, 16)             2320      ['reshape[0][0]']
#  anspose)
#
#  dropout_2 (Dropout)         (None, 7, 7, 16)             0         ['conv2d_transpose[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 14, 14, 16)           0         ['dropout_2[0][0]']
#  D)
#
#  conv2Transpose (Conv2DTran  (None, 14, 14, 6)            870       ['up_sampling2d[0][0]']
#  spose)
#
#  dropout_3 (Dropout)         (None, 14, 14, 6)            0         ['conv2Transpose[0][0]']
#
#  up_sampling2d_1 (UpSamplin  (None, 28, 28, 6)            0         ['dropout_3[0][0]']
#  g2D)
#
#  reconstruction (Conv2D)     (None, 28, 28, 1)            55        ['up_sampling2d_1[0][0]']
#
#  z_gaussian (Concatenate)    (None, 256)                  0         ['z_mean[0][0]',
#                                                                      'z_log_var[0][0]']
#
#  softmax_output (Dense)      (None, 10)                   1290      ['sampling[0][0]']
#
# ==================================================================================================
# Total params: 1629547 (6.22 MB)
# Trainable params: 1629547 (6.22 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# # Entrenamiento

# %%
history = model.fit(X_train, 
                  [X_train,X_train,y_train],
                  epochs=epochs, 
                  batch_size=batch_size, 
                  validation_data=(X_valid, [X_valid,X_valid,y_valid])
                 )
# Out:
# Epoch 1/100
# 2024-08-06 00:45:14.552236: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape invae/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1722905117.789689     168 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 860/860 [==============================] - 17s 9ms/step - loss: 0.3956 - reconstruction_loss: 0.3400 - z_gaussian_loss: 0.0118 - softmax_output_loss: 0.5611 - reconstruction_reconstruction_loss: 0.3399 - z_gaussian_dkl_loss: 0.0118 - softmax_output_classification_loss: 0.5609 - val_loss: 0.3291 - val_reconstruction_loss: 0.2999 - val_z_gaussian_loss: 0.0046 - val_softmax_output_loss: 0.4467 - val_reconstruction_reconstruction_loss: 0.2996 - val_z_gaussian_dkl_loss: 0.0045 - val_softmax_output_classification_loss: 0.4432
# Epoch 2/100
# 860/860 [==============================] - 6s 8ms/step - loss: 0.3307 - reconstruction_loss: 0.3026 - z_gaussian_loss: 0.0049 - softmax_output_loss: 0.4474 - reconstruction_reconstruction_loss: 0.3025 - z_gaussian_dkl_loss: 0.0049 - softmax_output_classification_loss: 0.4473 - val_loss: 0.3079 - val_reconstruction_loss: 0.2884 - val_z_gaussian_loss: 0.0026 - val_softmax_output_loss: 0.4086 - val_reconstruction_reconstruction_loss: 0.2882 - val_z_gaussian_dkl_loss: 0.0026 - val_softmax_output_classification_loss: 0.4058
# Epoch 3/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.3119 - reconstruction_loss: 0.2949 - z_gaussian_loss: 0.0037 - softmax_output_loss: 0.4101 - reconstruction_reconstruction_loss: 0.2949 - z_gaussian_dkl_loss: 0.0037 - softmax_output_classification_loss: 0.4103 - val_loss: 0.2962 - val_reconstruction_loss: 0.2839 - val_z_gaussian_loss: 0.0022 - val_softmax_output_loss: 0.3852 - val_reconstruction_reconstruction_loss: 0.2836 - val_z_gaussian_dkl_loss: 0.0022 - val_softmax_output_classification_loss: 0.3822
# Epoch 4/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.3012 - reconstruction_loss: 0.2911 - z_gaussian_loss: 0.0037 - softmax_output_loss: 0.3881 - reconstruction_reconstruction_loss: 0.2911 - z_gaussian_dkl_loss: 0.0037 - softmax_output_classification_loss: 0.3882 - val_loss: 0.2837 - val_reconstruction_loss: 0.2813 - val_z_gaussian_loss: 0.0033 - val_softmax_output_loss: 0.3569 - val_reconstruction_reconstruction_loss: 0.2810 - val_z_gaussian_dkl_loss: 0.0033 - val_softmax_output_classification_loss: 0.3542
# Epoch 5/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2955 - reconstruction_loss: 0.2892 - z_gaussian_loss: 0.0052 - softmax_output_loss: 0.3759 - reconstruction_reconstruction_loss: 0.2892 - z_gaussian_dkl_loss: 0.0052 - softmax_output_classification_loss: 0.3758 - val_loss: 0.2746 - val_reconstruction_loss: 0.2795 - val_z_gaussian_loss: 0.0092 - val_softmax_output_loss: 0.3348 - val_reconstruction_reconstruction_loss: 0.2792 - val_z_gaussian_dkl_loss: 0.0091 - val_softmax_output_classification_loss: 0.3321
# Epoch 6/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2894 - reconstruction_loss: 0.2875 - z_gaussian_loss: 0.0064 - softmax_output_loss: 0.3624 - reconstruction_reconstruction_loss: 0.2875 - z_gaussian_dkl_loss: 0.0064 - softmax_output_classification_loss: 0.3624 - val_loss: 0.2777 - val_reconstruction_loss: 0.2795 - val_z_gaussian_loss: 0.0081 - val_softmax_output_loss: 0.3429 - val_reconstruction_reconstruction_loss: 0.2792 - val_z_gaussian_dkl_loss: 0.0080 - val_softmax_output_classification_loss: 0.3401
# Epoch 7/100
# 860/860 [==============================] - 6s 8ms/step - loss: 0.2832 - reconstruction_loss: 0.2861 - z_gaussian_loss: 0.0063 - softmax_output_loss: 0.3488 - reconstruction_reconstruction_loss: 0.2861 - z_gaussian_dkl_loss: 0.0063 - softmax_output_classification_loss: 0.3489 - val_loss: 0.2773 - val_reconstruction_loss: 0.2774 - val_z_gaussian_loss: 0.0062 - val_softmax_output_loss: 0.3450 - val_reconstruction_reconstruction_loss: 0.2771 - val_z_gaussian_dkl_loss: 0.0062 - val_softmax_output_classification_loss: 0.3424
# Epoch 8/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2803 - reconstruction_loss: 0.2852 - z_gaussian_loss: 0.0061 - softmax_output_loss: 0.3428 - reconstruction_reconstruction_loss: 0.2852 - z_gaussian_dkl_loss: 0.0061 - softmax_output_classification_loss: 0.3429 - val_loss: 0.2701 - val_reconstruction_loss: 0.2759 - val_z_gaussian_loss: 0.0095 - val_softmax_output_loss: 0.3281 - val_reconstruction_reconstruction_loss: 0.2756 - val_z_gaussian_dkl_loss: 0.0094 - val_softmax_output_classification_loss: 0.3252
# Epoch 9/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2766 - reconstruction_loss: 0.2844 - z_gaussian_loss: 0.0055 - softmax_output_loss: 0.3346 - reconstruction_reconstruction_loss: 0.2844 - z_gaussian_dkl_loss: 0.0055 - softmax_output_classification_loss: 0.3346 - val_loss: 0.2736 - val_reconstruction_loss: 0.2769 - val_z_gaussian_loss: 0.0040 - val_softmax_output_loss: 0.3369 - val_reconstruction_reconstruction_loss: 0.2766 - val_z_gaussian_dkl_loss: 0.0039 - val_softmax_output_classification_loss: 0.3341
# Epoch 10/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2746 - reconstruction_loss: 0.2839 - z_gaussian_loss: 0.0060 - softmax_output_loss: 0.3302 - reconstruction_reconstruction_loss: 0.2839 - z_gaussian_dkl_loss: 0.0060 - softmax_output_classification_loss: 0.3303 - val_loss: 0.2725 - val_reconstruction_loss: 0.2746 - val_z_gaussian_loss: 0.0058 - val_softmax_output_loss: 0.3365 - val_reconstruction_reconstruction_loss: 0.2743 - val_z_gaussian_dkl_loss: 0.0058 - val_softmax_output_classification_loss: 0.3333
# Epoch 11/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2716 - reconstruction_loss: 0.2830 - z_gaussian_loss: 0.0053 - softmax_output_loss: 0.3239 - reconstruction_reconstruction_loss: 0.2830 - z_gaussian_dkl_loss: 0.0053 - softmax_output_classification_loss: 0.3238 - val_loss: 0.2616 - val_reconstruction_loss: 0.2732 - val_z_gaussian_loss: 0.0041 - val_softmax_output_loss: 0.3113 - val_reconstruction_reconstruction_loss: 0.2729 - val_z_gaussian_dkl_loss: 0.0041 - val_softmax_output_classification_loss: 0.3087
# Epoch 12/100
# 860/860 [==============================] - 6s 8ms/step - loss: 0.2707 - reconstruction_loss: 0.2825 - z_gaussian_loss: 0.0047 - softmax_output_loss: 0.3223 - reconstruction_reconstruction_loss: 0.2825 - z_gaussian_dkl_loss: 0.0047 - softmax_output_classification_loss: 0.3223 - val_loss: 0.2597 - val_reconstruction_loss: 0.2738 - val_z_gaussian_loss: 0.0065 - val_softmax_output_loss: 0.3053 - val_reconstruction_reconstruction_loss: 0.2735 - val_z_gaussian_dkl_loss: 0.0064 - val_softmax_output_classification_loss: 0.3026
# Epoch 13/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2680 - reconstruction_loss: 0.2821 - z_gaussian_loss: 0.0048 - softmax_output_loss: 0.3162 - reconstruction_reconstruction_loss: 0.2821 - z_gaussian_dkl_loss: 0.0048 - softmax_output_classification_loss: 0.3163 - val_loss: 0.2591 - val_reconstruction_loss: 0.2740 - val_z_gaussian_loss: 0.0048 - val_softmax_output_loss: 0.3041 - val_reconstruction_reconstruction_loss: 0.2737 - val_z_gaussian_dkl_loss: 0.0048 - val_softmax_output_classification_loss: 0.3011
# Epoch 14/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2668 - reconstruction_loss: 0.2819 - z_gaussian_loss: 0.0040 - softmax_output_loss: 0.3137 - reconstruction_reconstruction_loss: 0.2819 - z_gaussian_dkl_loss: 0.0040 - softmax_output_classification_loss: 0.3136 - val_loss: 0.2636 - val_reconstruction_loss: 0.2723 - val_z_gaussian_loss: 0.0031 - val_softmax_output_loss: 0.3179 - val_reconstruction_reconstruction_loss: 0.2720 - val_z_gaussian_dkl_loss: 0.0031 - val_softmax_output_classification_loss: 0.3151
# Epoch 15/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2638 - reconstruction_loss: 0.2813 - z_gaussian_loss: 0.0039 - softmax_output_loss: 0.3069 - reconstruction_reconstruction_loss: 0.2814 - z_gaussian_dkl_loss: 0.0039 - softmax_output_classification_loss: 0.3070 - val_loss: 0.2585 - val_reconstruction_loss: 0.2721 - val_z_gaussian_loss: 0.0029 - val_softmax_output_loss: 0.3053 - val_reconstruction_reconstruction_loss: 0.2718 - val_z_gaussian_dkl_loss: 0.0029 - val_softmax_output_classification_loss: 0.3026
# Epoch 16/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2635 - reconstruction_loss: 0.2812 - z_gaussian_loss: 0.0045 - softmax_output_loss: 0.3061 - reconstruction_reconstruction_loss: 0.2812 - z_gaussian_dkl_loss: 0.0045 - softmax_output_classification_loss: 0.3061 - val_loss: 0.2560 - val_reconstruction_loss: 0.2708 - val_z_gaussian_loss: 0.0028 - val_softmax_output_loss: 0.3007 - val_reconstruction_reconstruction_loss: 0.2705 - val_z_gaussian_dkl_loss: 0.0028 - val_softmax_output_classification_loss: 0.2981
# Epoch 17/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2628 - reconstruction_loss: 0.2812 - z_gaussian_loss: 0.0042 - softmax_output_loss: 0.3046 - reconstruction_reconstruction_loss: 0.2812 - z_gaussian_dkl_loss: 0.0042 - softmax_output_classification_loss: 0.3045 - val_loss: 0.2555 - val_reconstruction_loss: 0.2712 - val_z_gaussian_loss: 0.0021 - val_softmax_output_loss: 0.2992 - val_reconstruction_reconstruction_loss: 0.2709 - val_z_gaussian_dkl_loss: 0.0021 - val_softmax_output_classification_loss: 0.2964
# Epoch 18/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2610 - reconstruction_loss: 0.2805 - z_gaussian_loss: 0.0039 - softmax_output_loss: 0.3008 - reconstruction_reconstruction_loss: 0.2805 - z_gaussian_dkl_loss: 0.0039 - softmax_output_classification_loss: 0.3007 - val_loss: 0.2551 - val_reconstruction_loss: 0.2706 - val_z_gaussian_loss: 0.0027 - val_softmax_output_loss: 0.2988 - val_reconstruction_reconstruction_loss: 0.2703 - val_z_gaussian_dkl_loss: 0.0028 - val_softmax_output_classification_loss: 0.2959
# Epoch 19/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2593 - reconstruction_loss: 0.2802 - z_gaussian_loss: 0.0040 - softmax_output_loss: 0.2969 - reconstruction_reconstruction_loss: 0.2802 - z_gaussian_dkl_loss: 0.0040 - softmax_output_classification_loss: 0.2969 - val_loss: 0.2560 - val_reconstruction_loss: 0.2710 - val_z_gaussian_loss: 0.0017 - val_softmax_output_loss: 0.3009 - val_reconstruction_reconstruction_loss: 0.2707 - val_z_gaussian_dkl_loss: 0.0017 - val_softmax_output_classification_loss: 0.2981
# Epoch 20/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.2592 - reconstruction_loss: 0.2802 - z_gaussian_loss: 0.0043 - softmax_output_loss: 0.2967 - reconstruction_reconstruction_loss: 0.2802 - z_gaussian_dkl_loss: 0.0043 - softmax_output_classification_loss: 0.2966 - val_loss: 0.2679 - val_reconstruction_loss: 0.2748 - val_z_gaussian_loss: 0.0073 - val_softmax_output_loss: 0.3245 - val_reconstruction_reconstruction_loss: 0.2744 - val_z_gaussian_dkl_loss: 0.0073 - val_softmax_output_classification_loss: 0.3212
# Epoch 21/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2587 - reconstruction_loss: 0.2801 - z_gaussian_loss: 0.0038 - softmax_output_loss: 0.2956 - reconstruction_reconstruction_loss: 0.2801 - z_gaussian_dkl_loss: 0.0038 - softmax_output_classification_loss: 0.2956 - val_loss: 0.2486 - val_reconstruction_loss: 0.2706 - val_z_gaussian_loss: 0.0026 - val_softmax_output_loss: 0.2826 - val_reconstruction_reconstruction_loss: 0.2702 - val_z_gaussian_dkl_loss: 0.0026 - val_softmax_output_classification_loss: 0.2800
# Epoch 22/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.2577 - reconstruction_loss: 0.2801 - z_gaussian_loss: 0.0050 - softmax_output_loss: 0.2930 - reconstruction_reconstruction_loss: 0.2800 - z_gaussian_dkl_loss: 0.0050 - softmax_output_classification_loss: 0.2930 - val_loss: 0.2533 - val_reconstruction_loss: 0.2701 - val_z_gaussian_loss: 0.0020 - val_softmax_output_loss: 0.2951 - val_reconstruction_reconstruction_loss: 0.2698 - val_z_gaussian_dkl_loss: 0.0020 - val_softmax_output_classification_loss: 0.2923
# Epoch 23/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2568 - reconstruction_loss: 0.2799 - z_gaussian_loss: 0.0038 - softmax_output_loss: 0.2912 - reconstruction_reconstruction_loss: 0.2799 - z_gaussian_dkl_loss: 0.0038 - softmax_output_classification_loss: 0.2915 - val_loss: 0.2524 - val_reconstruction_loss: 0.2715 - val_z_gaussian_loss: 0.0035 - val_softmax_output_loss: 0.2908 - val_reconstruction_reconstruction_loss: 0.2712 - val_z_gaussian_dkl_loss: 0.0035 - val_softmax_output_classification_loss: 0.2882
# Epoch 24/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2548 - reconstruction_loss: 0.2793 - z_gaussian_loss: 0.0037 - softmax_output_loss: 0.2868 - reconstruction_reconstruction_loss: 0.2793 - z_gaussian_dkl_loss: 0.0037 - softmax_output_classification_loss: 0.2870 - val_loss: 0.2522 - val_reconstruction_loss: 0.2704 - val_z_gaussian_loss: 0.0045 - val_softmax_output_loss: 0.2913 - val_reconstruction_reconstruction_loss: 0.2701 - val_z_gaussian_dkl_loss: 0.0045 - val_softmax_output_classification_loss: 0.2885
# Epoch 25/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2598 - reconstruction_loss: 0.2814 - z_gaussian_loss: 0.0045 - softmax_output_loss: 0.2967 - reconstruction_reconstruction_loss: 0.2814 - z_gaussian_dkl_loss: 0.0045 - softmax_output_classification_loss: 0.2967 - val_loss: 0.2557 - val_reconstruction_loss: 0.2719 - val_z_gaussian_loss: 0.0046 - val_softmax_output_loss: 0.2983 - val_reconstruction_reconstruction_loss: 0.2716 - val_z_gaussian_dkl_loss: 0.0046 - val_softmax_output_classification_loss: 0.2956
# Epoch 26/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2550 - reconstruction_loss: 0.2793 - z_gaussian_loss: 0.0026 - softmax_output_loss: 0.2877 - reconstruction_reconstruction_loss: 0.2793 - z_gaussian_dkl_loss: 0.0026 - softmax_output_classification_loss: 0.2879 - val_loss: 0.2469 - val_reconstruction_loss: 0.2698 - val_z_gaussian_loss: 0.0075 - val_softmax_output_loss: 0.2782 - val_reconstruction_reconstruction_loss: 0.2695 - val_z_gaussian_dkl_loss: 0.0075 - val_softmax_output_classification_loss: 0.2757
# Epoch 27/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.2531 - reconstruction_loss: 0.2788 - z_gaussian_loss: 0.0046 - softmax_output_loss: 0.2831 - reconstruction_reconstruction_loss: 0.2788 - z_gaussian_dkl_loss: 0.0046 - softmax_output_classification_loss: 0.2830 - val_loss: 0.2514 - val_reconstruction_loss: 0.2706 - val_z_gaussian_loss: 0.0020 - val_softmax_output_loss: 0.2899 - val_reconstruction_reconstruction_loss: 0.2703 - val_z_gaussian_dkl_loss: 0.0020 - val_softmax_output_classification_loss: 0.2871
# Epoch 28/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2520 - reconstruction_loss: 0.2788 - z_gaussian_loss: 0.0030 - softmax_output_loss: 0.2806 - reconstruction_reconstruction_loss: 0.2788 - z_gaussian_dkl_loss: 0.0030 - softmax_output_classification_loss: 0.2805 - val_loss: 0.2462 - val_reconstruction_loss: 0.2691 - val_z_gaussian_loss: 0.0031 - val_softmax_output_loss: 0.2783 - val_reconstruction_reconstruction_loss: 0.2688 - val_z_gaussian_dkl_loss: 0.0031 - val_softmax_output_classification_loss: 0.2755
# Epoch 29/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2524 - reconstruction_loss: 0.2791 - z_gaussian_loss: 0.0040 - softmax_output_loss: 0.2812 - reconstruction_reconstruction_loss: 0.2791 - z_gaussian_dkl_loss: 0.0040 - softmax_output_classification_loss: 0.2812 - val_loss: 0.2507 - val_reconstruction_loss: 0.2724 - val_z_gaussian_loss: 0.0038 - val_softmax_output_loss: 0.2853 - val_reconstruction_reconstruction_loss: 0.2721 - val_z_gaussian_dkl_loss: 0.0038 - val_softmax_output_classification_loss: 0.2824
# Epoch 30/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2543 - reconstruction_loss: 0.2794 - z_gaussian_loss: 0.0039 - softmax_output_loss: 0.2854 - reconstruction_reconstruction_loss: 0.2795 - z_gaussian_dkl_loss: 0.0039 - softmax_output_classification_loss: 0.2853 - val_loss: 0.2495 - val_reconstruction_loss: 0.2699 - val_z_gaussian_loss: 0.0031 - val_softmax_output_loss: 0.2856 - val_reconstruction_reconstruction_loss: 0.2696 - val_z_gaussian_dkl_loss: 0.0031 - val_softmax_output_classification_loss: 0.2829
# Epoch 31/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2511 - reconstruction_loss: 0.2789 - z_gaussian_loss: 0.0032 - softmax_output_loss: 0.2784 - reconstruction_reconstruction_loss: 0.2789 - z_gaussian_dkl_loss: 0.0032 - softmax_output_classification_loss: 0.2785 - val_loss: 0.2517 - val_reconstruction_loss: 0.2699 - val_z_gaussian_loss: 0.0025 - val_softmax_output_loss: 0.2911 - val_reconstruction_reconstruction_loss: 0.2696 - val_z_gaussian_dkl_loss: 0.0025 - val_softmax_output_classification_loss: 0.2886
# Epoch 32/100
# 860/860 [==============================] - 6s 8ms/step - loss: 0.2534 - reconstruction_loss: 0.2793 - z_gaussian_loss: 0.0037 - softmax_output_loss: 0.2834 - reconstruction_reconstruction_loss: 0.2793 - z_gaussian_dkl_loss: 0.0037 - softmax_output_classification_loss: 0.2834 - val_loss: 0.2501 - val_reconstruction_loss: 0.2705 - val_z_gaussian_loss: 0.0013 - val_softmax_output_loss: 0.2867 - val_reconstruction_reconstruction_loss: 0.2702 - val_z_gaussian_dkl_loss: 0.0013 - val_softmax_output_classification_loss: 0.2840
# Epoch 33/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2499 - reconstruction_loss: 0.2785 - z_gaussian_loss: 0.0031 - softmax_output_loss: 0.2759 - reconstruction_reconstruction_loss: 0.2785 - z_gaussian_dkl_loss: 0.0031 - softmax_output_classification_loss: 0.2759 - val_loss: 0.2586 - val_reconstruction_loss: 0.2702 - val_z_gaussian_loss: 0.0018 - val_softmax_output_loss: 0.3085 - val_reconstruction_reconstruction_loss: 0.2698 - val_z_gaussian_dkl_loss: 0.0018 - val_softmax_output_classification_loss: 0.3055
# Epoch 34/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2558 - reconstruction_loss: 0.2801 - z_gaussian_loss: 0.0041 - softmax_output_loss: 0.2884 - reconstruction_reconstruction_loss: 0.2801 - z_gaussian_dkl_loss: 0.0041 - softmax_output_classification_loss: 0.2883 - val_loss: 0.2535 - val_reconstruction_loss: 0.2700 - val_z_gaussian_loss: 0.0029 - val_softmax_output_loss: 0.2955 - val_reconstruction_reconstruction_loss: 0.2697 - val_z_gaussian_dkl_loss: 0.0029 - val_softmax_output_classification_loss: 0.2932
# Epoch 35/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2503 - reconstruction_loss: 0.2786 - z_gaussian_loss: 0.0030 - softmax_output_loss: 0.2767 - reconstruction_reconstruction_loss: 0.2786 - z_gaussian_dkl_loss: 0.0030 - softmax_output_classification_loss: 0.2765 - val_loss: 0.2441 - val_reconstruction_loss: 0.2690 - val_z_gaussian_loss: 0.0032 - val_softmax_output_loss: 0.2731 - val_reconstruction_reconstruction_loss: 0.2687 - val_z_gaussian_dkl_loss: 0.0032 - val_softmax_output_classification_loss: 0.2705
# Epoch 36/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2484 - reconstruction_loss: 0.2784 - z_gaussian_loss: 0.0033 - softmax_output_loss: 0.2721 - reconstruction_reconstruction_loss: 0.2784 - z_gaussian_dkl_loss: 0.0033 - softmax_output_classification_loss: 0.2722 - val_loss: 0.2507 - val_reconstruction_loss: 0.2691 - val_z_gaussian_loss: 0.0020 - val_softmax_output_loss: 0.2898 - val_reconstruction_reconstruction_loss: 0.2688 - val_z_gaussian_dkl_loss: 0.0020 - val_softmax_output_classification_loss: 0.2871
# Epoch 37/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.2481 - reconstruction_loss: 0.2785 - z_gaussian_loss: 0.0034 - softmax_output_loss: 0.2713 - reconstruction_reconstruction_loss: 0.2785 - z_gaussian_dkl_loss: 0.0034 - softmax_output_classification_loss: 0.2714 - val_loss: 0.2493 - val_reconstruction_loss: 0.2752 - val_z_gaussian_loss: 0.0021 - val_softmax_output_loss: 0.2788 - val_reconstruction_reconstruction_loss: 0.2748 - val_z_gaussian_dkl_loss: 0.0021 - val_softmax_output_classification_loss: 0.2760
# Epoch 38/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2482 - reconstruction_loss: 0.2787 - z_gaussian_loss: 0.0034 - softmax_output_loss: 0.2712 - reconstruction_reconstruction_loss: 0.2786 - z_gaussian_dkl_loss: 0.0034 - softmax_output_classification_loss: 0.2713 - val_loss: 0.2464 - val_reconstruction_loss: 0.2689 - val_z_gaussian_loss: 0.0024 - val_softmax_output_loss: 0.2793 - val_reconstruction_reconstruction_loss: 0.2685 - val_z_gaussian_dkl_loss: 0.0024 - val_softmax_output_classification_loss: 0.2768
# Epoch 39/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2525 - reconstruction_loss: 0.2793 - z_gaussian_loss: 0.0034 - softmax_output_loss: 0.2812 - reconstruction_reconstruction_loss: 0.2793 - z_gaussian_dkl_loss: 0.0034 - softmax_output_classification_loss: 0.2812 - val_loss: 0.2431 - val_reconstruction_loss: 0.2684 - val_z_gaussian_loss: 0.0014 - val_softmax_output_loss: 0.2718 - val_reconstruction_reconstruction_loss: 0.2681 - val_z_gaussian_dkl_loss: 0.0014 - val_softmax_output_classification_loss: 0.2693
# Epoch 40/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2475 - reconstruction_loss: 0.2783 - z_gaussian_loss: 0.0028 - softmax_output_loss: 0.2702 - reconstruction_reconstruction_loss: 0.2783 - z_gaussian_dkl_loss: 0.0028 - softmax_output_classification_loss: 0.2702 - val_loss: 0.2447 - val_reconstruction_loss: 0.2684 - val_z_gaussian_loss: 0.0019 - val_softmax_output_loss: 0.2758 - val_reconstruction_reconstruction_loss: 0.2681 - val_z_gaussian_dkl_loss: 0.0019 - val_softmax_output_classification_loss: 0.2731
# Epoch 41/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2466 - reconstruction_loss: 0.2782 - z_gaussian_loss: 0.0027 - softmax_output_loss: 0.2681 - reconstruction_reconstruction_loss: 0.2782 - z_gaussian_dkl_loss: 0.0027 - softmax_output_classification_loss: 0.2680 - val_loss: 0.2425 - val_reconstruction_loss: 0.2686 - val_z_gaussian_loss: 0.0016 - val_softmax_output_loss: 0.2700 - val_reconstruction_reconstruction_loss: 0.2683 - val_z_gaussian_dkl_loss: 0.0016 - val_softmax_output_classification_loss: 0.2674
# Epoch 42/100
# 860/860 [==============================] - 6s 8ms/step - loss: 0.2470 - reconstruction_loss: 0.2783 - z_gaussian_loss: 0.0033 - softmax_output_loss: 0.2689 - reconstruction_reconstruction_loss: 0.2783 - z_gaussian_dkl_loss: 0.0033 - softmax_output_classification_loss: 0.2689 - val_loss: 0.2472 - val_reconstruction_loss: 0.2684 - val_z_gaussian_loss: 0.0025 - val_softmax_output_loss: 0.2818 - val_reconstruction_reconstruction_loss: 0.2681 - val_z_gaussian_dkl_loss: 0.0025 - val_softmax_output_classification_loss: 0.2790
# Epoch 43/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2464 - reconstruction_loss: 0.2782 - z_gaussian_loss: 0.0034 - softmax_output_loss: 0.2673 - reconstruction_reconstruction_loss: 0.2782 - z_gaussian_dkl_loss: 0.0034 - softmax_output_classification_loss: 0.2673 - val_loss: 0.2458 - val_reconstruction_loss: 0.2696 - val_z_gaussian_loss: 0.0022 - val_softmax_output_loss: 0.2769 - val_reconstruction_reconstruction_loss: 0.2693 - val_z_gaussian_dkl_loss: 0.0022 - val_softmax_output_classification_loss: 0.2744
# Epoch 44/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2466 - reconstruction_loss: 0.2783 - z_gaussian_loss: 0.0040 - softmax_output_loss: 0.2677 - reconstruction_reconstruction_loss: 0.2783 - z_gaussian_dkl_loss: 0.0040 - softmax_output_classification_loss: 0.2677 - val_loss: 0.2478 - val_reconstruction_loss: 0.2720 - val_z_gaussian_loss: 0.0036 - val_softmax_output_loss: 0.2786 - val_reconstruction_reconstruction_loss: 0.2717 - val_z_gaussian_dkl_loss: 0.0036 - val_softmax_output_classification_loss: 0.2760
# Epoch 45/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2485 - reconstruction_loss: 0.2790 - z_gaussian_loss: 0.0041 - softmax_output_loss: 0.2716 - reconstruction_reconstruction_loss: 0.2790 - z_gaussian_dkl_loss: 0.0041 - softmax_output_classification_loss: 0.2718 - val_loss: 0.2427 - val_reconstruction_loss: 0.2685 - val_z_gaussian_loss: 0.0020 - val_softmax_output_loss: 0.2706 - val_reconstruction_reconstruction_loss: 0.2682 - val_z_gaussian_dkl_loss: 0.0019 - val_softmax_output_classification_loss: 0.2679
# Epoch 46/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2453 - reconstruction_loss: 0.2780 - z_gaussian_loss: 0.0035 - softmax_output_loss: 0.2647 - reconstruction_reconstruction_loss: 0.2780 - z_gaussian_dkl_loss: 0.0035 - softmax_output_classification_loss: 0.2647 - val_loss: 0.2476 - val_reconstruction_loss: 0.2689 - val_z_gaussian_loss: 0.0029 - val_softmax_output_loss: 0.2822 - val_reconstruction_reconstruction_loss: 0.2685 - val_z_gaussian_dkl_loss: 0.0029 - val_softmax_output_classification_loss: 0.2793
# Epoch 47/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.3083 - reconstruction_loss: 0.2886 - z_gaussian_loss: 0.0110 - softmax_output_loss: 0.4072 - reconstruction_reconstruction_loss: 0.2886 - z_gaussian_dkl_loss: 0.0110 - softmax_output_classification_loss: 0.4070 - val_loss: 0.2558 - val_reconstruction_loss: 0.2703 - val_z_gaussian_loss: 0.0043 - val_softmax_output_loss: 0.3006 - val_reconstruction_reconstruction_loss: 0.2700 - val_z_gaussian_dkl_loss: 0.0043 - val_softmax_output_classification_loss: 0.2978
# Epoch 48/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.2507 - reconstruction_loss: 0.2788 - z_gaussian_loss: 0.0043 - softmax_output_loss: 0.2771 - reconstruction_reconstruction_loss: 0.2788 - z_gaussian_dkl_loss: 0.0043 - softmax_output_classification_loss: 0.2771 - val_loss: 0.2471 - val_reconstruction_loss: 0.2690 - val_z_gaussian_loss: 0.0035 - val_softmax_output_loss: 0.2807 - val_reconstruction_reconstruction_loss: 0.2687 - val_z_gaussian_dkl_loss: 0.0035 - val_softmax_output_classification_loss: 0.2781
# Epoch 49/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.2445 - reconstruction_loss: 0.2776 - z_gaussian_loss: 0.0037 - softmax_output_loss: 0.2633 - reconstruction_reconstruction_loss: 0.2776 - z_gaussian_dkl_loss: 0.0037 - softmax_output_classification_loss: 0.2632 - val_loss: 0.2449 - val_reconstruction_loss: 0.2683 - val_z_gaussian_loss: 0.0027 - val_softmax_output_loss: 0.2761 - val_reconstruction_reconstruction_loss: 0.2680 - val_z_gaussian_dkl_loss: 0.0026 - val_softmax_output_classification_loss: 0.2733
# Epoch 50/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2444 - reconstruction_loss: 0.2775 - z_gaussian_loss: 0.0031 - softmax_output_loss: 0.2634 - reconstruction_reconstruction_loss: 0.2775 - z_gaussian_dkl_loss: 0.0031 - softmax_output_classification_loss: 0.2635 - val_loss: 0.2442 - val_reconstruction_loss: 0.2687 - val_z_gaussian_loss: 0.0022 - val_softmax_output_loss: 0.2740 - val_reconstruction_reconstruction_loss: 0.2684 - val_z_gaussian_dkl_loss: 0.0022 - val_softmax_output_classification_loss: 0.2712
# Epoch 51/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2432 - reconstruction_loss: 0.2775 - z_gaussian_loss: 0.0026 - softmax_output_loss: 0.2606 - reconstruction_reconstruction_loss: 0.2775 - z_gaussian_dkl_loss: 0.0026 - softmax_output_classification_loss: 0.2606 - val_loss: 0.2450 - val_reconstruction_loss: 0.2681 - val_z_gaussian_loss: 0.0023 - val_softmax_output_loss: 0.2767 - val_reconstruction_reconstruction_loss: 0.2678 - val_z_gaussian_dkl_loss: 0.0023 - val_softmax_output_classification_loss: 0.2739
# Epoch 52/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2438 - reconstruction_loss: 0.2776 - z_gaussian_loss: 0.0027 - softmax_output_loss: 0.2619 - reconstruction_reconstruction_loss: 0.2776 - z_gaussian_dkl_loss: 0.0027 - softmax_output_classification_loss: 0.2619 - val_loss: 0.2439 - val_reconstruction_loss: 0.2681 - val_z_gaussian_loss: 0.0017 - val_softmax_output_loss: 0.2743 - val_reconstruction_reconstruction_loss: 0.2678 - val_z_gaussian_dkl_loss: 0.0017 - val_softmax_output_classification_loss: 0.2715
# Epoch 53/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2438 - reconstruction_loss: 0.2778 - z_gaussian_loss: 0.0019 - softmax_output_loss: 0.2617 - reconstruction_reconstruction_loss: 0.2779 - z_gaussian_dkl_loss: 0.0019 - softmax_output_classification_loss: 0.2618 - val_loss: 0.2464 - val_reconstruction_loss: 0.2702 - val_z_gaussian_loss: 9.0348e-04 - val_softmax_output_loss: 0.2780 - val_reconstruction_reconstruction_loss: 0.2699 - val_z_gaussian_dkl_loss: 8.9966e-04 - val_softmax_output_classification_loss: 0.2752
# Epoch 54/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2612 - reconstruction_loss: 0.2812 - z_gaussian_loss: 0.0053 - softmax_output_loss: 0.3002 - reconstruction_reconstruction_loss: 0.2812 - z_gaussian_dkl_loss: 0.0053 - softmax_output_classification_loss: 0.3006 - val_loss: 0.2716 - val_reconstruction_loss: 0.2743 - val_z_gaussian_loss: 0.0031 - val_softmax_output_loss: 0.3353 - val_reconstruction_reconstruction_loss: 0.2740 - val_z_gaussian_dkl_loss: 0.0031 - val_softmax_output_classification_loss: 0.3325
# Epoch 55/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2521 - reconstruction_loss: 0.2786 - z_gaussian_loss: 0.0029 - softmax_output_loss: 0.2812 - reconstruction_reconstruction_loss: 0.2786 - z_gaussian_dkl_loss: 0.0029 - softmax_output_classification_loss: 0.2812 - val_loss: 0.2506 - val_reconstruction_loss: 0.2680 - val_z_gaussian_loss: 0.0019 - val_softmax_output_loss: 0.2910 - val_reconstruction_reconstruction_loss: 0.2677 - val_z_gaussian_dkl_loss: 0.0018 - val_softmax_output_classification_loss: 0.2882
# Epoch 56/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2446 - reconstruction_loss: 0.2771 - z_gaussian_loss: 0.0030 - softmax_output_loss: 0.2645 - reconstruction_reconstruction_loss: 0.2771 - z_gaussian_dkl_loss: 0.0030 - softmax_output_classification_loss: 0.2644 - val_loss: 0.2468 - val_reconstruction_loss: 0.2683 - val_z_gaussian_loss: 0.0012 - val_softmax_output_loss: 0.2814 - val_reconstruction_reconstruction_loss: 0.2680 - val_z_gaussian_dkl_loss: 0.0012 - val_softmax_output_classification_loss: 0.2787
# Epoch 57/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2433 - reconstruction_loss: 0.2773 - z_gaussian_loss: 0.0025 - softmax_output_loss: 0.2610 - reconstruction_reconstruction_loss: 0.2773 - z_gaussian_dkl_loss: 0.0025 - softmax_output_classification_loss: 0.2611 - val_loss: 0.2455 - val_reconstruction_loss: 0.2677 - val_z_gaussian_loss: 0.0014 - val_softmax_output_loss: 0.2787 - val_reconstruction_reconstruction_loss: 0.2673 - val_z_gaussian_dkl_loss: 0.0014 - val_softmax_output_classification_loss: 0.2758
# Epoch 58/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2441 - reconstruction_loss: 0.2774 - z_gaussian_loss: 0.0040 - softmax_output_loss: 0.2625 - reconstruction_reconstruction_loss: 0.2774 - z_gaussian_dkl_loss: 0.0040 - softmax_output_classification_loss: 0.2624 - val_loss: 0.2549 - val_reconstruction_loss: 0.2686 - val_z_gaussian_loss: 0.0051 - val_softmax_output_loss: 0.3003 - val_reconstruction_reconstruction_loss: 0.2683 - val_z_gaussian_dkl_loss: 0.0050 - val_softmax_output_classification_loss: 0.2971
# Epoch 59/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2435 - reconstruction_loss: 0.2776 - z_gaussian_loss: 0.0039 - softmax_output_loss: 0.2608 - reconstruction_reconstruction_loss: 0.2776 - z_gaussian_dkl_loss: 0.0039 - softmax_output_classification_loss: 0.2607 - val_loss: 0.2448 - val_reconstruction_loss: 0.2686 - val_z_gaussian_loss: 0.0029 - val_softmax_output_loss: 0.2756 - val_reconstruction_reconstruction_loss: 0.2683 - val_z_gaussian_dkl_loss: 0.0029 - val_softmax_output_classification_loss: 0.2730
# Epoch 60/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2455 - reconstruction_loss: 0.2779 - z_gaussian_loss: 0.0040 - softmax_output_loss: 0.2653 - reconstruction_reconstruction_loss: 0.2779 - z_gaussian_dkl_loss: 0.0040 - softmax_output_classification_loss: 0.2654 - val_loss: 0.2444 - val_reconstruction_loss: 0.2681 - val_z_gaussian_loss: 0.0022 - val_softmax_output_loss: 0.2752 - val_reconstruction_reconstruction_loss: 0.2678 - val_z_gaussian_dkl_loss: 0.0022 - val_softmax_output_classification_loss: 0.2727
# Epoch 61/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2434 - reconstruction_loss: 0.2776 - z_gaussian_loss: 0.0039 - softmax_output_loss: 0.2606 - reconstruction_reconstruction_loss: 0.2776 - z_gaussian_dkl_loss: 0.0039 - softmax_output_classification_loss: 0.2607 - val_loss: 0.2473 - val_reconstruction_loss: 0.2696 - val_z_gaussian_loss: 0.0025 - val_softmax_output_loss: 0.2807 - val_reconstruction_reconstruction_loss: 0.2692 - val_z_gaussian_dkl_loss: 0.0025 - val_softmax_output_classification_loss: 0.2778
# Epoch 62/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2438 - reconstruction_loss: 0.2779 - z_gaussian_loss: 0.0024 - softmax_output_loss: 0.2614 - reconstruction_reconstruction_loss: 0.2779 - z_gaussian_dkl_loss: 0.0024 - softmax_output_classification_loss: 0.2613 - val_loss: 0.2479 - val_reconstruction_loss: 0.2686 - val_z_gaussian_loss: 0.0017 - val_softmax_output_loss: 0.2836 - val_reconstruction_reconstruction_loss: 0.2683 - val_z_gaussian_dkl_loss: 0.0017 - val_softmax_output_classification_loss: 0.2807
# Epoch 63/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2439 - reconstruction_loss: 0.2778 - z_gaussian_loss: 0.0024 - softmax_output_loss: 0.2619 - reconstruction_reconstruction_loss: 0.2778 - z_gaussian_dkl_loss: 0.0024 - softmax_output_classification_loss: 0.2617 - val_loss: 0.2511 - val_reconstruction_loss: 0.2694 - val_z_gaussian_loss: 0.0016 - val_softmax_output_loss: 0.2907 - val_reconstruction_reconstruction_loss: 0.2690 - val_z_gaussian_dkl_loss: 0.0016 - val_softmax_output_classification_loss: 0.2877
# Epoch 64/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2437 - reconstruction_loss: 0.2775 - z_gaussian_loss: 0.0027 - softmax_output_loss: 0.2617 - reconstruction_reconstruction_loss: 0.2775 - z_gaussian_dkl_loss: 0.0027 - softmax_output_classification_loss: 0.2618 - val_loss: 0.2466 - val_reconstruction_loss: 0.2702 - val_z_gaussian_loss: 0.0038 - val_softmax_output_loss: 0.2779 - val_reconstruction_reconstruction_loss: 0.2699 - val_z_gaussian_dkl_loss: 0.0038 - val_softmax_output_classification_loss: 0.2751
# Epoch 65/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2434 - reconstruction_loss: 0.2778 - z_gaussian_loss: 0.0047 - softmax_output_loss: 0.2602 - reconstruction_reconstruction_loss: 0.2778 - z_gaussian_dkl_loss: 0.0047 - softmax_output_classification_loss: 0.2602 - val_loss: 0.2506 - val_reconstruction_loss: 0.2691 - val_z_gaussian_loss: 0.0031 - val_softmax_output_loss: 0.2894 - val_reconstruction_reconstruction_loss: 0.2688 - val_z_gaussian_dkl_loss: 0.0031 - val_softmax_output_classification_loss: 0.2864
# Epoch 66/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2433 - reconstruction_loss: 0.2777 - z_gaussian_loss: 0.0032 - softmax_output_loss: 0.2604 - reconstruction_reconstruction_loss: 0.2777 - z_gaussian_dkl_loss: 0.0032 - softmax_output_classification_loss: 0.2604 - val_loss: 0.2485 - val_reconstruction_loss: 0.2678 - val_z_gaussian_loss: 0.0017 - val_softmax_output_loss: 0.2860 - val_reconstruction_reconstruction_loss: 0.2675 - val_z_gaussian_dkl_loss: 0.0017 - val_softmax_output_classification_loss: 0.2830
# Epoch 67/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2425 - reconstruction_loss: 0.2777 - z_gaussian_loss: 0.0030 - softmax_output_loss: 0.2584 - reconstruction_reconstruction_loss: 0.2777 - z_gaussian_dkl_loss: 0.0030 - softmax_output_classification_loss: 0.2584 - val_loss: 0.2421 - val_reconstruction_loss: 0.2680 - val_z_gaussian_loss: 0.0019 - val_softmax_output_loss: 0.2698 - val_reconstruction_reconstruction_loss: 0.2677 - val_z_gaussian_dkl_loss: 0.0019 - val_softmax_output_classification_loss: 0.2670
# Epoch 68/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2415 - reconstruction_loss: 0.2777 - z_gaussian_loss: 0.0029 - softmax_output_loss: 0.2558 - reconstruction_reconstruction_loss: 0.2777 - z_gaussian_dkl_loss: 0.0029 - softmax_output_classification_loss: 0.2557 - val_loss: 0.2466 - val_reconstruction_loss: 0.2684 - val_z_gaussian_loss: 0.0020 - val_softmax_output_loss: 0.2805 - val_reconstruction_reconstruction_loss: 0.2681 - val_z_gaussian_dkl_loss: 0.0020 - val_softmax_output_classification_loss: 0.2775
# Epoch 69/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2421 - reconstruction_loss: 0.2775 - z_gaussian_loss: 0.0024 - softmax_output_loss: 0.2579 - reconstruction_reconstruction_loss: 0.2775 - z_gaussian_dkl_loss: 0.0024 - softmax_output_classification_loss: 0.2578 - val_loss: 0.2464 - val_reconstruction_loss: 0.2688 - val_z_gaussian_loss: 9.6467e-04 - val_softmax_output_loss: 0.2796 - val_reconstruction_reconstruction_loss: 0.2685 - val_z_gaussian_dkl_loss: 9.6928e-04 - val_softmax_output_classification_loss: 0.2771
# Epoch 70/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2509 - reconstruction_loss: 0.2797 - z_gaussian_loss: 0.0030 - softmax_output_loss: 0.2769 - reconstruction_reconstruction_loss: 0.2797 - z_gaussian_dkl_loss: 0.0030 - softmax_output_classification_loss: 0.2770 - val_loss: 0.2610 - val_reconstruction_loss: 0.2739 - val_z_gaussian_loss: 0.0012 - val_softmax_output_loss: 0.3098 - val_reconstruction_reconstruction_loss: 0.2736 - val_z_gaussian_dkl_loss: 0.0012 - val_softmax_output_classification_loss: 0.3068
# Epoch 71/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2460 - reconstruction_loss: 0.2782 - z_gaussian_loss: 0.0019 - softmax_output_loss: 0.2669 - reconstruction_reconstruction_loss: 0.2782 - z_gaussian_dkl_loss: 0.0019 - softmax_output_classification_loss: 0.2669 - val_loss: 0.2453 - val_reconstruction_loss: 0.2676 - val_z_gaussian_loss: 0.0016 - val_softmax_output_loss: 0.2782 - val_reconstruction_reconstruction_loss: 0.2673 - val_z_gaussian_dkl_loss: 0.0016 - val_softmax_output_classification_loss: 0.2754
# Epoch 72/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2408 - reconstruction_loss: 0.2771 - z_gaussian_loss: 0.0029 - softmax_output_loss: 0.2548 - reconstruction_reconstruction_loss: 0.2771 - z_gaussian_dkl_loss: 0.0029 - softmax_output_classification_loss: 0.2547 - val_loss: 0.2430 - val_reconstruction_loss: 0.2682 - val_z_gaussian_loss: 0.0038 - val_softmax_output_loss: 0.2712 - val_reconstruction_reconstruction_loss: 0.2679 - val_z_gaussian_dkl_loss: 0.0038 - val_softmax_output_classification_loss: 0.2685
# Epoch 73/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2398 - reconstruction_loss: 0.2772 - z_gaussian_loss: 0.0027 - softmax_output_loss: 0.2522 - reconstruction_reconstruction_loss: 0.2773 - z_gaussian_dkl_loss: 0.0027 - softmax_output_classification_loss: 0.2523 - val_loss: 0.2537 - val_reconstruction_loss: 0.2678 - val_z_gaussian_loss: 0.0020 - val_softmax_output_loss: 0.2988 - val_reconstruction_reconstruction_loss: 0.2675 - val_z_gaussian_dkl_loss: 0.0020 - val_softmax_output_classification_loss: 0.2958
# Epoch 74/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2414 - reconstruction_loss: 0.2774 - z_gaussian_loss: 0.0027 - softmax_output_loss: 0.2562 - reconstruction_reconstruction_loss: 0.2774 - z_gaussian_dkl_loss: 0.0027 - softmax_output_classification_loss: 0.2561 - val_loss: 0.2477 - val_reconstruction_loss: 0.2688 - val_z_gaussian_loss: 0.0019 - val_softmax_output_loss: 0.2828 - val_reconstruction_reconstruction_loss: 0.2685 - val_z_gaussian_dkl_loss: 0.0020 - val_softmax_output_classification_loss: 0.2800
# Epoch 75/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2409 - reconstruction_loss: 0.2775 - z_gaussian_loss: 0.0027 - softmax_output_loss: 0.2547 - reconstruction_reconstruction_loss: 0.2775 - z_gaussian_dkl_loss: 0.0027 - softmax_output_classification_loss: 0.2546 - val_loss: 0.2471 - val_reconstruction_loss: 0.2686 - val_z_gaussian_loss: 0.0027 - val_softmax_output_loss: 0.2813 - val_reconstruction_reconstruction_loss: 0.2683 - val_z_gaussian_dkl_loss: 0.0027 - val_softmax_output_classification_loss: 0.2785
# Epoch 76/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.2454 - reconstruction_loss: 0.2785 - z_gaussian_loss: 0.0034 - softmax_output_loss: 0.2645 - reconstruction_reconstruction_loss: 0.2785 - z_gaussian_dkl_loss: 0.0034 - softmax_output_classification_loss: 0.2645 - val_loss: 0.2504 - val_reconstruction_loss: 0.2684 - val_z_gaussian_loss: 0.0015 - val_softmax_output_loss: 0.2902 - val_reconstruction_reconstruction_loss: 0.2681 - val_z_gaussian_dkl_loss: 0.0015 - val_softmax_output_classification_loss: 0.2876
# Epoch 77/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2397 - reconstruction_loss: 0.2773 - z_gaussian_loss: 0.0013 - softmax_output_loss: 0.2521 - reconstruction_reconstruction_loss: 0.2773 - z_gaussian_dkl_loss: 0.0013 - softmax_output_classification_loss: 0.2522 - val_loss: 0.2420 - val_reconstruction_loss: 0.2676 - val_z_gaussian_loss: 3.2234e-04 - val_softmax_output_loss: 0.2704 - val_reconstruction_reconstruction_loss: 0.2673 - val_z_gaussian_dkl_loss: 3.2181e-04 - val_softmax_output_classification_loss: 0.2677
# Epoch 78/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2414 - reconstruction_loss: 0.2782 - z_gaussian_loss: 0.0012 - softmax_output_loss: 0.2554 - reconstruction_reconstruction_loss: 0.2782 - z_gaussian_dkl_loss: 0.0012 - softmax_output_classification_loss: 0.2553 - val_loss: 0.2472 - val_reconstruction_loss: 0.2686 - val_z_gaussian_loss: 0.0013 - val_softmax_output_loss: 0.2819 - val_reconstruction_reconstruction_loss: 0.2683 - val_z_gaussian_dkl_loss: 0.0013 - val_softmax_output_classification_loss: 0.2791
# Epoch 79/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2410 - reconstruction_loss: 0.2772 - z_gaussian_loss: 0.0018 - softmax_output_loss: 0.2555 - reconstruction_reconstruction_loss: 0.2772 - z_gaussian_dkl_loss: 0.0018 - softmax_output_classification_loss: 0.2555 - val_loss: 0.2466 - val_reconstruction_loss: 0.2697 - val_z_gaussian_loss: 0.0020 - val_softmax_output_loss: 0.2789 - val_reconstruction_reconstruction_loss: 0.2694 - val_z_gaussian_dkl_loss: 0.0020 - val_softmax_output_classification_loss: 0.2761
# Epoch 80/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2472 - reconstruction_loss: 0.2790 - z_gaussian_loss: 0.0037 - softmax_output_loss: 0.2685 - reconstruction_reconstruction_loss: 0.2790 - z_gaussian_dkl_loss: 0.0037 - softmax_output_classification_loss: 0.2684 - val_loss: 0.2415 - val_reconstruction_loss: 0.2675 - val_z_gaussian_loss: 0.0011 - val_softmax_output_loss: 0.2691 - val_reconstruction_reconstruction_loss: 0.2672 - val_z_gaussian_dkl_loss: 0.0011 - val_softmax_output_classification_loss: 0.2664
# Epoch 81/100
# 860/860 [==============================] - 6s 8ms/step - loss: 0.2403 - reconstruction_loss: 0.2774 - z_gaussian_loss: 0.0020 - softmax_output_loss: 0.2536 - reconstruction_reconstruction_loss: 0.2774 - z_gaussian_dkl_loss: 0.0020 - softmax_output_classification_loss: 0.2536 - val_loss: 0.2442 - val_reconstruction_loss: 0.2681 - val_z_gaussian_loss: 0.0013 - val_softmax_output_loss: 0.2751 - val_reconstruction_reconstruction_loss: 0.2678 - val_z_gaussian_dkl_loss: 0.0013 - val_softmax_output_classification_loss: 0.2723
# Epoch 82/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2407 - reconstruction_loss: 0.2773 - z_gaussian_loss: 0.0021 - softmax_output_loss: 0.2545 - reconstruction_reconstruction_loss: 0.2773 - z_gaussian_dkl_loss: 0.0021 - softmax_output_classification_loss: 0.2546 - val_loss: 0.2423 - val_reconstruction_loss: 0.2687 - val_z_gaussian_loss: 0.0019 - val_softmax_output_loss: 0.2694 - val_reconstruction_reconstruction_loss: 0.2683 - val_z_gaussian_dkl_loss: 0.0019 - val_softmax_output_classification_loss: 0.2667
# Epoch 83/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2417 - reconstruction_loss: 0.2777 - z_gaussian_loss: 0.0029 - softmax_output_loss: 0.2565 - reconstruction_reconstruction_loss: 0.2777 - z_gaussian_dkl_loss: 0.0029 - softmax_output_classification_loss: 0.2564 - val_loss: 0.2433 - val_reconstruction_loss: 0.2687 - val_z_gaussian_loss: 0.0023 - val_softmax_output_loss: 0.2719 - val_reconstruction_reconstruction_loss: 0.2684 - val_z_gaussian_dkl_loss: 0.0023 - val_softmax_output_classification_loss: 0.2693
# Epoch 84/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2396 - reconstruction_loss: 0.2774 - z_gaussian_loss: 0.0031 - softmax_output_loss: 0.2515 - reconstruction_reconstruction_loss: 0.2774 - z_gaussian_dkl_loss: 0.0031 - softmax_output_classification_loss: 0.2515 - val_loss: 0.2425 - val_reconstruction_loss: 0.2700 - val_z_gaussian_loss: 0.0038 - val_softmax_output_loss: 0.2678 - val_reconstruction_reconstruction_loss: 0.2696 - val_z_gaussian_dkl_loss: 0.0038 - val_softmax_output_classification_loss: 0.2651
# Epoch 85/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2406 - reconstruction_loss: 0.2775 - z_gaussian_loss: 0.0036 - softmax_output_loss: 0.2537 - reconstruction_reconstruction_loss: 0.2775 - z_gaussian_dkl_loss: 0.0036 - softmax_output_classification_loss: 0.2538 - val_loss: 0.2413 - val_reconstruction_loss: 0.2710 - val_z_gaussian_loss: 0.0018 - val_softmax_output_loss: 0.2640 - val_reconstruction_reconstruction_loss: 0.2707 - val_z_gaussian_dkl_loss: 0.0018 - val_softmax_output_classification_loss: 0.2614
# Epoch 86/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2404 - reconstruction_loss: 0.2776 - z_gaussian_loss: 0.0030 - softmax_output_loss: 0.2534 - reconstruction_reconstruction_loss: 0.2776 - z_gaussian_dkl_loss: 0.0030 - softmax_output_classification_loss: 0.2537 - val_loss: 0.2467 - val_reconstruction_loss: 0.2679 - val_z_gaussian_loss: 0.0030 - val_softmax_output_loss: 0.2811 - val_reconstruction_reconstruction_loss: 0.2676 - val_z_gaussian_dkl_loss: 0.0030 - val_softmax_output_classification_loss: 0.2785
# Epoch 87/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2398 - reconstruction_loss: 0.2776 - z_gaussian_loss: 0.0034 - softmax_output_loss: 0.2517 - reconstruction_reconstruction_loss: 0.2776 - z_gaussian_dkl_loss: 0.0034 - softmax_output_classification_loss: 0.2516 - val_loss: 0.2462 - val_reconstruction_loss: 0.2689 - val_z_gaussian_loss: 0.0029 - val_softmax_output_loss: 0.2786 - val_reconstruction_reconstruction_loss: 0.2686 - val_z_gaussian_dkl_loss: 0.0029 - val_softmax_output_classification_loss: 0.2758
# Epoch 88/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2538 - reconstruction_loss: 0.2805 - z_gaussian_loss: 0.0042 - softmax_output_loss: 0.2829 - reconstruction_reconstruction_loss: 0.2805 - z_gaussian_dkl_loss: 0.0042 - softmax_output_classification_loss: 0.2829 - val_loss: 0.2460 - val_reconstruction_loss: 0.2687 - val_z_gaussian_loss: 0.0029 - val_softmax_output_loss: 0.2784 - val_reconstruction_reconstruction_loss: 0.2684 - val_z_gaussian_dkl_loss: 0.0029 - val_softmax_output_classification_loss: 0.2757
# Epoch 89/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2399 - reconstruction_loss: 0.2771 - z_gaussian_loss: 0.0019 - softmax_output_loss: 0.2530 - reconstruction_reconstruction_loss: 0.2770 - z_gaussian_dkl_loss: 0.0019 - softmax_output_classification_loss: 0.2531 - val_loss: 0.2435 - val_reconstruction_loss: 0.2673 - val_z_gaussian_loss: 0.0013 - val_softmax_output_loss: 0.2744 - val_reconstruction_reconstruction_loss: 0.2670 - val_z_gaussian_dkl_loss: 0.0013 - val_softmax_output_classification_loss: 0.2717
# Epoch 90/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2381 - reconstruction_loss: 0.2768 - z_gaussian_loss: 0.0017 - softmax_output_loss: 0.2488 - reconstruction_reconstruction_loss: 0.2768 - z_gaussian_dkl_loss: 0.0017 - softmax_output_classification_loss: 0.2488 - val_loss: 0.2399 - val_reconstruction_loss: 0.2675 - val_z_gaussian_loss: 8.0400e-04 - val_softmax_output_loss: 0.2652 - val_reconstruction_reconstruction_loss: 0.2672 - val_z_gaussian_dkl_loss: 8.0091e-04 - val_softmax_output_classification_loss: 0.2626
# Epoch 91/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2378 - reconstruction_loss: 0.2770 - z_gaussian_loss: 0.0016 - softmax_output_loss: 0.2478 - reconstruction_reconstruction_loss: 0.2770 - z_gaussian_dkl_loss: 0.0016 - softmax_output_classification_loss: 0.2478 - val_loss: 0.2424 - val_reconstruction_loss: 0.2677 - val_z_gaussian_loss: 0.0012 - val_softmax_output_loss: 0.2711 - val_reconstruction_reconstruction_loss: 0.2674 - val_z_gaussian_dkl_loss: 0.0012 - val_softmax_output_classification_loss: 0.2684
# Epoch 92/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2384 - reconstruction_loss: 0.2774 - z_gaussian_loss: 0.0026 - softmax_output_loss: 0.2485 - reconstruction_reconstruction_loss: 0.2774 - z_gaussian_dkl_loss: 0.0026 - softmax_output_classification_loss: 0.2485 - val_loss: 0.2429 - val_reconstruction_loss: 0.2685 - val_z_gaussian_loss: 0.0014 - val_softmax_output_loss: 0.2713 - val_reconstruction_reconstruction_loss: 0.2681 - val_z_gaussian_dkl_loss: 0.0014 - val_softmax_output_classification_loss: 0.2686
# Epoch 93/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2395 - reconstruction_loss: 0.2774 - z_gaussian_loss: 0.0032 - softmax_output_loss: 0.2512 - reconstruction_reconstruction_loss: 0.2774 - z_gaussian_dkl_loss: 0.0032 - softmax_output_classification_loss: 0.2513 - val_loss: 0.2412 - val_reconstruction_loss: 0.2680 - val_z_gaussian_loss: 0.0034 - val_softmax_output_loss: 0.2673 - val_reconstruction_reconstruction_loss: 0.2676 - val_z_gaussian_dkl_loss: 0.0034 - val_softmax_output_classification_loss: 0.2647
# Epoch 94/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2394 - reconstruction_loss: 0.2775 - z_gaussian_loss: 0.0032 - softmax_output_loss: 0.2510 - reconstruction_reconstruction_loss: 0.2775 - z_gaussian_dkl_loss: 0.0032 - softmax_output_classification_loss: 0.2509 - val_loss: 0.2388 - val_reconstruction_loss: 0.2675 - val_z_gaussian_loss: 0.0019 - val_softmax_output_loss: 0.2622 - val_reconstruction_reconstruction_loss: 0.2672 - val_z_gaussian_dkl_loss: 0.0019 - val_softmax_output_classification_loss: 0.2595
# Epoch 95/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2404 - reconstruction_loss: 0.2777 - z_gaussian_loss: 0.0022 - softmax_output_loss: 0.2533 - reconstruction_reconstruction_loss: 0.2777 - z_gaussian_dkl_loss: 0.0022 - softmax_output_classification_loss: 0.2534 - val_loss: 0.2431 - val_reconstruction_loss: 0.2680 - val_z_gaussian_loss: 0.0041 - val_softmax_output_loss: 0.2717 - val_reconstruction_reconstruction_loss: 0.2677 - val_z_gaussian_dkl_loss: 0.0041 - val_softmax_output_classification_loss: 0.2690
# Epoch 96/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2387 - reconstruction_loss: 0.2773 - z_gaussian_loss: 0.0025 - softmax_output_loss: 0.2494 - reconstruction_reconstruction_loss: 0.2773 - z_gaussian_dkl_loss: 0.0025 - softmax_output_classification_loss: 0.2493 - val_loss: 0.2413 - val_reconstruction_loss: 0.2675 - val_z_gaussian_loss: 7.4227e-04 - val_softmax_output_loss: 0.2688 - val_reconstruction_reconstruction_loss: 0.2672 - val_z_gaussian_dkl_loss: 7.4214e-04 - val_softmax_output_classification_loss: 0.2662
# Epoch 97/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2388 - reconstruction_loss: 0.2775 - z_gaussian_loss: 0.0026 - softmax_output_loss: 0.2496 - reconstruction_reconstruction_loss: 0.2775 - z_gaussian_dkl_loss: 0.0026 - softmax_output_classification_loss: 0.2496 - val_loss: 0.2431 - val_reconstruction_loss: 0.2694 - val_z_gaussian_loss: 0.0024 - val_softmax_output_loss: 0.2705 - val_reconstruction_reconstruction_loss: 0.2691 - val_z_gaussian_dkl_loss: 0.0024 - val_softmax_output_classification_loss: 0.2679
# Epoch 98/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2388 - reconstruction_loss: 0.2779 - z_gaussian_loss: 0.0027 - softmax_output_loss: 0.2491 - reconstruction_reconstruction_loss: 0.2779 - z_gaussian_dkl_loss: 0.0027 - softmax_output_classification_loss: 0.2491 - val_loss: 0.2457 - val_reconstruction_loss: 0.2676 - val_z_gaussian_loss: 0.0012 - val_softmax_output_loss: 0.2795 - val_reconstruction_reconstruction_loss: 0.2673 - val_z_gaussian_dkl_loss: 0.0012 - val_softmax_output_classification_loss: 0.2766
# Epoch 99/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2393 - reconstruction_loss: 0.2774 - z_gaussian_loss: 0.0025 - softmax_output_loss: 0.2509 - reconstruction_reconstruction_loss: 0.2774 - z_gaussian_dkl_loss: 0.0025 - softmax_output_classification_loss: 0.2508 - val_loss: 0.2483 - val_reconstruction_loss: 0.2692 - val_z_gaussian_loss: 0.0016 - val_softmax_output_loss: 0.2838 - val_reconstruction_reconstruction_loss: 0.2689 - val_z_gaussian_dkl_loss: 0.0016 - val_softmax_output_classification_loss: 0.2810
# Epoch 100/100
# 860/860 [==============================] - 6s 7ms/step - loss: 0.2429 - reconstruction_loss: 0.2784 - z_gaussian_loss: 0.0028 - softmax_output_loss: 0.2585 - reconstruction_reconstruction_loss: 0.2784 - z_gaussian_dkl_loss: 0.0028 - softmax_output_classification_loss: 0.2586 - val_loss: 0.2452 - val_reconstruction_loss: 0.2678 - val_z_gaussian_loss: 0.0017 - val_softmax_output_loss: 0.2779 - val_reconstruction_reconstruction_loss: 0.2675 - val_z_gaussian_dkl_loss: 0.0017 - val_softmax_output_classification_loss: 0.2752

# %% [markdown]
# # Loss sin normalizar

# %% [markdown]
# **Funciones de pérdida:**
#
# La pérdida de reconstrucción asegura que el modelo pueda reconstruir las imágenes de entrada con precisión, utilice entropía cruzada binaria es adecuada para la comparación de imágenes píxel por píxel, especialmente cuando los píxeles pueden tener valores binarios (0 o 1) o valores continuos entre 0 y 1 (como en imágenes normalizadas).
#
# La pérdida de divergencia Kullback-Leibler regula el espacio latente, manteniendo su distribución cerca de una normal estándar, lo cual es crucial para la generación de nuevas muestras. La divergencia Kullback-Leibler (DKL) mide la diferencia entre la distribución aprendida por el modelo (parametrizada por z_mean y z_log_var) y una distribución normal estándar. Esta regularización es crucial para la generación de nuevas muestras y para mantener la consistencia en el espacio latente.
#
# La pérdida de clasificación optimiza la capacidad del modelo para clasificar correctamente las imágenes en diferentes categorías, la entropía cruzada categórica dispersa es adecuada para tareas de clasificación multi-clase donde las etiquetas son enteros. Evalúa la discrepancia entre las etiquetas verdaderas y las probabilidades predichas por el modelo.

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
reconstruction_loss = history.history['reconstruction_reconstruction_loss']
val_reconstruction_loss = history.history['val_reconstruction_reconstruction_loss']
classification_loss = history.history['softmax_output_classification_loss']
val_classification_loss = history.history['val_softmax_output_classification_loss']
dkl_loss = history.history['z_gaussian_dkl_loss']
val_dkl_loss = history.history['val_z_gaussian_dkl_loss']

plt.figure(figsize=(14, 8))

# Gráfico para la pérdida total
plt.subplot(2, 2, 1)
plt.plot(loss, label='Training Total Loss')
plt.plot(val_loss, label='Validation Total Loss')
plt.title('Total Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Gráfico para la pérdida de reconstrucción
plt.subplot(2, 2, 2)
plt.plot(reconstruction_loss, label='Training Reconstruction Loss')
plt.plot(val_reconstruction_loss, label='Validation Reconstruction Loss')
plt.title('Reconstruction Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Gráfico para la pérdida de clasificación
plt.subplot(2, 2, 3)
plt.plot(classification_loss, label='Training Classification Loss')
plt.plot(val_classification_loss, label='Validation Classification Loss')
plt.title('Classification Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Gráfico para la pérdida DKL
plt.subplot(2, 2, 4)
plt.plot(dkl_loss, label='Training DKL Loss')
plt.plot(val_dkl_loss, label='Validation DKL Loss')
plt.title('DKL Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Mostrar los gráficos
plt.tight_layout()
plt.show()

# %% [markdown]
# En las graficas de las pérdidas se puede observar que:
#
# * **Pérdida Total (Total Training and Validation Loss)**: Este gráfico muestra que tanto la pérdida total de entrenamiento como de validación disminuyen de manera significativa al principio y luego se estabilizan, lo cual es un buen indicador de que el modelo está aprendiendo adecuadamente sin signos evidentes de sobreajuste, ya que las líneas de entrenamiento y validación siguen patrones similares.
#
# * **Pérdida de Reconstrucción (Reconstruction Loss)**: Se observa que la pérdida de reconstrucción, tanto en entrenamiento como en validación, disminuye de manera constante. Esto sugiere que el modelo está mejorando su capacidad para reconstruir los datos de entrada, lo cual es especialmente relevante en modelos como autoencoders.
#
# * ** Pérdida de Clasificación (Classification Loss)**: La pérdida de clasificación muestra picos esporádicos, especialmente en la fase de validación, lo que podría indicar problemas de estabilidad en el aprendizaje para la tarea de clasificación. Esto podría ser un área para revisar, tal vez ajustando hiperparámetros o revisando el balance de clases en los datos.
#
# * **Pérdida de Divergencia Kullback-Leibler (DKL Loss)**: Este gráfico muestra fluctuaciones en la pérdida de divergencia KL, que mide qué tan bien la distribución de probabilidad aprendida por el modelo se aproxima a la distribución real de los datos. Las fluctuaciones aquí podrían ser normales, pero si son muy pronunciadas o si el modelo no mejora, podrían necesitarse ajustes.

# %%
X_re = model.predict(X_test)
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %%
len(X_re)
# Out:
# 3

# %% [markdown]
# # *Reconstrucción*

# %%
X_re[0].shape
# Out:
# (10000, 28, 28, 1)

# %%
num_samples = 5 
indices_to_compare = [i for i in range(num_samples)] 

# Nombres de etiquetas para el dataset Fashion MNIST
label_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

compare_images(X_test, X_re[0], y_test, label_names, indices_to_compare)

# %% [markdown]
# La gráfica demuestra que el modelo es capaz de reconstruir imágenes de ropa de manera razonable, preservando la forma general y la clase de los objetos.

# %% [markdown]
# # *Espacio latente*

# %%
z=X_re[1].reshape(X_re[1].shape[0],-1)

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(z)
tsne = TSNE(n_components=2, perplexity= 50)
z_tsne =  MinMaxScaler().fit_transform(tsne.fit_transform(scaled_data))

# %%
plt.figure(figsize=(10, 8))
cmap = plt.cm.tab10

plt.scatter(z_tsne[:, 0], z_tsne[:, 1], c=y_test, alpha=0.5, s=10, cmap=cmap)

# Inicializar posiciones de imágenes
image_positions = np.array([[1., 1.]])

# Iterar sobre las posiciones y añadir imágenes
for index, position in enumerate(z_tsne):
    dist = np.sum((position - image_positions) ** 2, axis=1)
    if np.min(dist) > 0.01:  # si está suficientemente lejos de otras imágenes
        image_positions = np.r_[image_positions, [position]]
        imagebox = mpl.offsetbox.AnnotationBbox(
            mpl.offsetbox.OffsetImage(X_train[index], cmap="binary"),  # Suponiendo que X_train contiene las imágenes originales
            position, bboxprops={"edgecolor": cmap(y_test[index]), "lw": 2})
        plt.gca().add_artist(imagebox)

# Configurar el gráfico y guardar la figura
plt.axis("off")
plt.show()

# %% [markdown]
# La visualización del espacio latente muestra que el modelo de VAE ha aprendido representaciones efectivas y discriminativas de las diferentes clases de ropa. Las agrupaciones claras y la separación entre las clases indican que el modelo puede capturar las características esenciales de cada clase en el espacio latente.

# %% [markdown]
# # *Clasificación*

# %%
X_re[2].shape
# Out:
# (10000, 10)

# %%
# Obtén las predicciones de clasificación
softmax_output = X_re[2]  
predicted_labels = np.argmax(softmax_output, axis=1)

accuracy = accuracy_score(y_test, predicted_labels)
print("Accuracy:", accuracy)
print(classification_report(y_test, predicted_labels))
# Out:
# Accuracy: 0.8969
#               precision    recall  f1-score   support
#
#            0       0.82      0.88      0.85      1000
#            1       0.99      0.97      0.98      1000
#            2       0.78      0.89      0.83      1000
#            3       0.89      0.91      0.90      1000
#            4       0.86      0.81      0.83      1000
#            5       0.99      0.95      0.97      1000
#            6       0.79      0.65      0.71      1000
#            7       0.92      0.98      0.95      1000
#            8       0.97      0.98      0.98      1000
#            9       0.97      0.95      0.96      1000
#
#     accuracy                           0.90     10000
#    macro avg       0.90      0.90      0.90     10000
# weighted avg       0.90      0.90      0.90     10000

# %% [markdown]
# En general de cada una de las clases, tiene un buen rendimiento de clasificación.

# %% [markdown]
# # *Reconstrucción y clasificación*

# %%
N = 15
predicted_labels = np.argmax(X_re[2][:N], axis=1) 
plot_mnist_autoencoder(
    X_test[:N], 
    X_re[0][:N], 
    y_test[:N],  
    predicted_labels  
)

# %% [markdown]
# La gráfica proporciona una visión clara del rendimiento del modelo en términos de sus predicciones correctas e incorrectas. Las predicciones correctas predominan en este primer conjunto de datos, lo que sugiere que el modelo tiene un buen rendimiento general. Sin embargo, las predicciones incorrectas resaltadas en rojo indican áreas donde el modelo puede mejorar.

# %% [markdown]
# # *Cams*

# %% [markdown]
# Los **Class Activation Maps (CAM)** son una técnica visual que se utiliza para comprender qué partes de una imagen influyen más en la clasificación realizada por una red neuronal convolucional **(CNN)**. Esta técnica ayuda a hacer más transparente y comprensible el proceso de toma de decisiones de las **CNN,** lo cual es especialmente valioso en aplicaciones donde la interpretación de los resultados es crucial, como en diagnóstico médico o en sistemas de visión para vehículos autónomos.
#
# **Uso de Redes Neuronales Convolucionales (CNN):**
# Los CAM se generan utilizando redes neuronales convolucionales que han sido entrenadas para tareas de clasificación de imágenes. Estas redes aprenden automáticamente características relevantes de las imágenes a través de sus capas convolucionales.
#
# **Aplicabilidad de los CAM**
#
# * **Interpretabilidad:**
# Los CAM permiten visualizar qué áreas de la imagen fueron determinantes para la decisión de la red, lo que aporta transparencia y permite a los usuarios entender y verificar si el modelo está haciendo las predicciones por razones válidas.
#
# Al identificar las regiones de la imagen que son más informativas para la clasificación, los CAM pueden ser utilizados para mejorar el entrenamiento de la red neuronal. Por ejemplo, si un modelo se centra en áreas irrelevantes para tomar decisiones, esto puede indicar problemas en los datos de entrenamiento o en la arquitectura de la red.
#
# * **Diagnóstico Médico:**
# En aplicaciones médicas, los CAM pueden ayudar a los doctores a localizar áreas anormales en imágenes médicas, como tumores en imágenes de resonancia magnética o radiografías, proporcionando una segunda opinión automatizada que complementa la evaluación del especialista.
#
# * **Validación y Ajuste Fino:**
# En aplicaciones críticas, como la conducción autónoma, los CAM pueden utilizarse para validar que la red está centrando su atención en las áreas correctas de la carretera o en objetos relevantes como peatones o señales de tráfico, y no en distracciones o ruido.

# %%
tf.keras.utils.plot_model(model, show_layer_names=True, show_shapes=True, dpi=96)

# %%
layers = ['conv1', 'conv2', 'conv3']

# Visualizar la imagen original con mayor tamaño
fig, axes = plt.subplots(1, 5, figsize=(25, 5))

num_images = 5
images = X_test[:num_images].reshape(-1, 28, 28, 1)
labels = y_test[:num_images]

for i in range(5):
    image = images[i]
    label = labels[i]
    ax_img = axes[i]
    ax_img.imshow(image.squeeze(), cmap='gray')
    ax_img.axis('off')
    ax_img.set_title(f'Original\nClass {label}')

for layer in layers:
    # Crear el modelo que solo tenga la salida del clasificador
    model_for_gradcam = tf.keras.models.Model(inputs=model.input, outputs=model.get_layer('softmax_output').output)

    # Crear el objeto GradCAM++
    gradcam = GradcamPlusPlus(model_for_gradcam, model_modifier=ReplaceToLinear(), clone=True)

    # Seleccionar las primeras 6 imágenes del conjunto de prueba
    num_images = 6
    images = X_test[:num_images].reshape(-1, 28, 28, 1)
    labels = y_test[:num_images]

    # Crear una figura con subplots
    fig, axes = plt.subplots(1, 6, figsize=(25, 5))
    fig.suptitle(f'GradCAM++ for layer {layer}', fontsize=16)  # Añadir título con el nombre de la capa

    for i, (image, label) in enumerate(zip(images, labels)):
        # Generar el CAM con GradCAM++ usando la capa actual
        cam = gradcam(CategoricalScore(label), image.reshape(1, 28, 28, 1), penultimate_layer=layer)

        # Visualizar el mapa de calor superpuesto en la imagen original
        heatmap = np.uint8(cm.jet(cam[0])[..., :3] * 255)
        ax_heatmap = axes[i]
        ax_heatmap.imshow(image.squeeze(), cmap='gray')
        ax_heatmap.imshow(heatmap, cmap='jet', alpha=0.5)
        ax_heatmap.axis('off')
        ax_heatmap.set_title(f'Class {label}')
        
        # Añadir la barra de colores (color bar)
        norm = plt.Normalize(vmin=cam[0].min(), vmax=cam[0].max())
        sm = plt.cm.ScalarMappable(cmap='jet', norm=norm)
        sm.set_array([])
        fig.colorbar(sm, ax=ax_heatmap, orientation="vertical", fraction=0.046, pad=0.04)
    
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # Ajustar layout para el título
    plt.show()

# %% [markdown]
# GradCAM++ visualiza las regiones de la imagen que más contribuyen a la decisión de clasificación del modelo.
# Las áreas en rojo indican una alta activación y una fuerte contribución a la clasificación, mientras que las áreas en azul indican baja activación.
# Capa conv1:
#
# * En la primera capa convolucional **(conv1)**, las activaciones están dispersas y no claramente enfocadas en características específicas de las imágenes. Esto es esperado ya que las primeras capas suelen capturar características de bajo nivel como bordes y texturas.
#
#
# * En la segunda capa convolucional **(conv2)**, las activaciones empiezan a ser más enfocadas, indicando que el modelo comienza a capturar características más complejas y relevantes para la clasificación.
#
#
# * En la tercera capa convolucional **(conv3)**, las activaciones son aún más específicas y concentradas en las regiones más relevantes de las imágenes.
#
#
# Comparando las activaciones de diferentes capas, se puede observar cómo el modelo refina su atención a medida que las características pasan a través de las capas convolucionales.
# Las capas más profundas capturan características de alto nivel y están más alineadas con las características humanas perceptibles de las clases de ropa.

# %% [markdown]
# # *Clase 9*

# %% [markdown]
# En este caso, dicscrimine las clases para comparar como se comporta una clase, comparada con las demas clases, si se presentan activaciones cuando no es la clase que se esta evaluando.

# %%
layers = ['conv1', 'conv2', 'conv3']

# Visualizar la imagen original con mayor tamaño
fig, axes = plt.subplots(1, 5, figsize=(25, 5))

for i in range(5):
    num_images = 5
    images = X_test[:num_images].reshape(-1, 28, 28, 1)
    image = images[i]
    ax_img = axes[i]
    ax_img.imshow(image.squeeze(), cmap='gray')
    ax_img.axis('off')
    ax_img.set_title(f'Original\nClass {label}')

for layer in layers:
    # Crear el modelo que solo tenga la salida del clasificador
    model_for_gradcam = tf.keras.models.Model(inputs=model.input, outputs=model.get_layer('softmax_output').output)

    # Crear el objeto GradCAM++
    gradcam = GradcamPlusPlus(model_for_gradcam, model_modifier=ReplaceToLinear(), clone=True)

    # Seleccionar las primeras 6 imágenes del conjunto de prueba
    num_images = 6
    images = X_test[:num_images].reshape(-1, 28, 28, 1)
    labels = y_test[:num_images]

    # Crear una figura con subplots
    fig, axes = plt.subplots(1, 6, figsize=(25, 5))
    fig.suptitle(f'GradCAM++ for layer {layer}', fontsize=16)  # Añadir título con el nombre de la capa

    for i, (image, label) in enumerate(zip(images, labels)):
        # Generar el CAM con GradCAM++ usando la capa 'convv'
        cam = gradcam(CategoricalScore(9), image.reshape(1, 28, 28, 1), penultimate_layer=layer, normalize_cam=False)

        # Visualizar el mapa de calor superpuesto en la imagen original
        heatmap = np.uint8(cm.jet(cam[0])[..., :3] * 255)
        ax_heatmap = axes[i]
        ax_heatmap.imshow(image.squeeze(), cmap='gray')
        ax_heatmap.imshow(heatmap, cmap='jet', alpha=0.5)
        ax_heatmap.axis('off')
        ax_heatmap.set_title(f'Class {label}')
        
        # Añadir la barra de colores (color bar)
        norm = plt.Normalize(vmin=cam[0].min(), vmax=cam[0].max())
        sm = plt.cm.ScalarMappable(cmap='jet', norm=norm)
        sm.set_array([])
        fig.colorbar(sm, ax=ax_heatmap, orientation="vertical", fraction=0.046, pad=0.04)
    
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # Ajustar layout para el título
    plt.show()

# %% [markdown]
# # *Clase 1*

# %%
layers = ['conv1', 'conv2', 'conv3']

# Visualizar la imagen original con mayor tamaño
fig, axes = plt.subplots(1, 5, figsize=(25, 5))

for i in range(5):
    num_images = 5
    images = X_test[:num_images].reshape(-1, 28, 28, 1)
    image = images[i]
    ax_img = axes[i]
    ax_img.imshow(image.squeeze(), cmap='gray')
    ax_img.axis('off')
    ax_img.set_title(f'Original\nClass {label}')

for layer in layers:
    # Crear el modelo que solo tenga la salida del clasificador
    model_for_gradcam = tf.keras.models.Model(inputs=model.input, outputs=model.get_layer('softmax_output').output)

    # Crear el objeto GradCAM++
    gradcam = GradcamPlusPlus(model_for_gradcam, model_modifier=ReplaceToLinear(), clone=True)

    # Seleccionar las primeras 6 imágenes del conjunto de prueba
    num_images = 6
    images = X_test[:num_images].reshape(-1, 28, 28, 1)
    labels = y_test[:num_images]

    # Crear una figura con subplots
    fig, axes = plt.subplots(1, 6, figsize=(25, 5))
    fig.suptitle(f'GradCAM++ for layer {layer}', fontsize=16)  # Añadir título con el nombre de la capa

    for i, (image, label) in enumerate(zip(images, labels)):
        # Generar el CAM con GradCAM++ usando la capa 'convv'
        cam = gradcam(CategoricalScore(1), image.reshape(1, 28, 28, 1), penultimate_layer=layer, normalize_cam=False)

        # Visualizar el mapa de calor superpuesto en la imagen original
        heatmap = np.uint8(cm.jet(cam[0])[..., :3] * 255)
        ax_heatmap = axes[i]
        ax_heatmap.imshow(image.squeeze(), cmap='gray')
        ax_heatmap.imshow(heatmap, cmap='jet', alpha=0.5)
        ax_heatmap.axis('off')
        ax_heatmap.set_title(f'Class {label}')
        
        # Añadir la barra de colores (color bar)
        norm = plt.Normalize(vmin=cam[0].min(), vmax=cam[0].max())
        sm = plt.cm.ScalarMappable(cmap='jet', norm=norm)
        sm.set_array([])
        fig.colorbar(sm, ax=ax_heatmap, orientation="vertical", fraction=0.046, pad=0.04)
    
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # Ajustar layout para el título
    plt.show()

# %%
model_for_gradcam.summary()
# Out:
# Model: "model_56"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]          0         []
#
#  conv1 (Conv2D)              (None, 28, 28, 6)            60        ['input_1[0][0]']
#
#  average_pooling2d (Average  (None, 14, 14, 6)            0         ['conv1[0][0]']
#  Pooling2D)
#
#  dropout (Dropout)           (None, 14, 14, 6)            0         ['average_pooling2d[0][0]']
#
#  conv2 (Conv2D)              (None, 14, 14, 16)           880       ['dropout[0][0]']
#
#  average_pooling2d_1 (Avera  (None, 7, 7, 16)             0         ['conv2[0][0]']
#  gePooling2D)
#
#  conv3 (Conv2D)              (None, 7, 7, 120)            17400     ['average_pooling2d_1[0][0]']
#
#  flatten (Flatten)           (None, 5880)                 0         ['conv3[0][0]']
#
#  dropout_1 (Dropout)         (None, 5880)                 0         ['flatten[0][0]']
#
#  z_mean (Dense)              (None, 128)                  752768    ['dropout_1[0][0]']
#
#  z_log_var (Dense)           (None, 128)                  752768    ['dropout_1[0][0]']
#
#  sampling (Sampling)         (None, 128)                  0         ['z_mean[0][0]',
#                                                                      'z_log_var[0][0]']
#
#  softmax_output (Dense)      (None, 10)                   1290      ['sampling[0][0]']
#
# ==================================================================================================
# Total params: 1525166 (5.82 MB)
# Trainable params: 1525166 (5.82 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model_for_gradcam, show_layer_names=True, show_shapes=True, dpi=96)

# %% [markdown]
# # Loss normalizado

# %% [markdown]
# Quise hacer una comparación con el mismo modelo, los mismos hiperparámetros y lo único que cambiaría serían las funciones de pérdida que le pondría al modelo. En este caso, utilizaría las funciones de pérdida normalizadas, con el fin de evaluar el impacto que estas tienen en el rendimiento y la estabilidad del modelo.

# %%
class NormalizedBinaryCrossentropy(Loss):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    def call(self, y_true, y_pred):
        """
        y_true: N x (height x width x channels)
        y_pred: N x (height x width x channels)
        """
        bce = tf.keras.losses.binary_crossentropy(tf.keras.backend.flatten(y_true), tf.keras.backend.flatten(y_pred))
        bce_true = tf.keras.losses.binary_crossentropy(tf.keras.backend.flatten(y_true), tf.keras.backend.flatten(y_true))
        nbce = tf.reduce_mean(bce) / tf.reduce_mean(bce_true)
        return nbce


class NormalizedCategoricalCrossentropy(Loss):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)

    def call(self, y_true, y_pred):
        """
        y_true: N x num_classes
        y_pred: N x num_classes
        """
        batch_size = tf.shape(y_pred)[0]
        cce = tf.keras.losses.categorical_crossentropy(y_true, y_pred)
       
        left = tf.one_hot(tf.zeros(batch_size, dtype=tf.int32), depth=tf.shape(y_true)[-1])
        right = tf.one_hot(tf.ones(batch_size, dtype=tf.int32), depth=tf.shape(y_true)[-1])
       
        cce_left = tf.keras.losses.categorical_crossentropy(left, y_pred)
        cce_right = tf.keras.losses.categorical_crossentropy(right, y_pred)
       
        cce_norm = tf.divide(cce, (cce_left + cce_right))
       
        return cce_norm
    
    
class DKLLoss(Loss):
    def __init__(self, **kwargs):
        super().__init__(**kwargs)
    
        
    def call(self, y_true, y_pred):
        z_mean, z_log_var = y_pred[..., 0], y_pred[..., 1]
        dkl = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
        
        # Calcular la entropía de una distribución uniforme en función del tamaño del lote
        batch_size = tf.cast(tf.shape(y_true)[0], tf.float32)
        
        return tf.reduce_mean(dkl) / tf.math.log(batch_size)

# %%
def model_class_nor(input_shape=(28, 28, 1), num_classes=10, latent_dim=128):
    
    # Encoder
    inputs = layers.Input(shape=input_shape)
    x = layers.Conv2D(6, kernel_size=3, activation='selu', 
                      kernel_initializer=tf.keras.initializers.GlorotUniform(seed=12), padding='same', name='conv1')(inputs)
    x = layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = layers.Dropout(0.15)(x)
    x = layers.Conv2D(16, kernel_size=3, activation='selu', 
                      kernel_initializer=tf.keras.initializers.GlorotUniform(seed=23), padding='same', name='conv2')(x)
    x = layers.AveragePooling2D(pool_size=(2, 2), strides=(2, 2))(x)
    x = layers.Conv2D(120, kernel_size=3, activation='selu',
                      kernel_initializer=tf.keras.initializers.GlorotUniform(seed=52),padding='same', name='conv3'
                     )(x)
    x = layers.Flatten()(x)
    x = layers.Dropout(0.15)(x)
    
    z_mean = layers.Dense(latent_dim, name='z_mean')(x)
    z_log_var = layers.Dense(latent_dim, name='z_log_var')(x)
    z_gaussian = tf.keras.layers.Concatenate(name='z_gaussian', axis=-1)([z_mean, z_log_var])
    z = Sampling()([z_mean, z_log_var])
    softmax_output = layers.Dense(num_classes, activation='softmax', name='softmax_output')(z)

    # Decoder
    x = layers.Dense(7 * 7 * 16, activation='selu')(z)
    x = layers.Reshape((7, 7, 16))(x)
    x = layers.Conv2DTranspose(16, kernel_size=3, activation='selu',
                               kernel_initializer=tf.keras.initializers.GlorotUniform(seed=12), padding='same')(x)
    x = layers.Dropout(0.15)(x)
    x = layers.UpSampling2D(size=(2, 2))(x)  
    x = layers.Conv2DTranspose(6, kernel_size=3, activation='selu', 
                               kernel_initializer=tf.keras.initializers.GlorotUniform(seed=23), padding='same', name='conv2Transpose')(x)
    x = layers.Dropout(0.15)(x)
    x = layers.UpSampling2D(size=(2, 2))(x)  
    reconstruction = layers.Conv2D(input_shape[2], kernel_size=3, padding='same', activation='sigmoid', name='reconstruction')(x) 

    # VAE Model
    vae = models.Model(inputs, [reconstruction, z_gaussian, softmax_output], name='vae')
    return vae

def build_and_compile_model(input_shape, num_classes, latent_dim, learning_rate):
    model = model_class_nor(input_shape, num_classes, latent_dim)
    
    model.compile(optimizer=Adam(),
                  loss={
                      'reconstruction': NormalizedBinaryCrossentropy(name="BinaryLoss"),
                      'softmax_output': NormalizedCategoricalCrossentropy(name="Categoricalloss"),
                      'z_gaussian': DKLLoss(name="DKLloss")
                  },
                  loss_weights={
                      'reconstruction': 0.3,
                      'z_gaussian': 0.2,
                      'softmax_output': 0.5
                  },
                  metrics={
                      'reconstruction': [NormalizedBinaryCrossentropy(name="BinaryLoss")],
                      'softmax_output': [NormalizedCategoricalCrossentropy(name="Categoricalloss"), 'accuracy'],
                      'z_gaussian': [DKLLoss(name="DKLloss")]
                  })
    return model

# %% [markdown]
# # Hiperparametros

# %%
seed = 42
epochs = 100
batch_size = 64
learning_rate =1e-3

# %%
model = build_and_compile_model(input_shape=(28, 28, 1), num_classes=10, 
                                    latent_dim=64, learning_rate=learning_rate)
model.summary()
# Out:
# Model: "vae"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_4 (InputLayer)        [(None, 28, 28, 1)]          0         []
#
#  conv1 (Conv2D)              (None, 28, 28, 6)            60        ['input_4[0][0]']
#
#  average_pooling2d_6 (Avera  (None, 14, 14, 6)            0         ['conv1[0][0]']
#  gePooling2D)
#
#  dropout_12 (Dropout)        (None, 14, 14, 6)            0         ['average_pooling2d_6[0][0]']
#
#  conv2 (Conv2D)              (None, 14, 14, 16)           880       ['dropout_12[0][0]']
#
#  average_pooling2d_7 (Avera  (None, 7, 7, 16)             0         ['conv2[0][0]']
#  gePooling2D)
#
#  conv3 (Conv2D)              (None, 7, 7, 120)            17400     ['average_pooling2d_7[0][0]']
#
#  flatten_3 (Flatten)         (None, 5880)                 0         ['conv3[0][0]']
#
#  dropout_13 (Dropout)        (None, 5880)                 0         ['flatten_3[0][0]']
#
#  z_mean (Dense)              (None, 64)                   376384    ['dropout_13[0][0]']
#
#  z_log_var (Dense)           (None, 64)                   376384    ['dropout_13[0][0]']
#
#  sampling_3 (Sampling)       (None, 64)                   0         ['z_mean[0][0]',
#                                                                      'z_log_var[0][0]']
#
#  dense_3 (Dense)             (None, 784)                  50960     ['sampling_3[0][0]']
#
#  reshape_3 (Reshape)         (None, 7, 7, 16)             0         ['dense_3[0][0]']
#
#  conv2d_transpose_3 (Conv2D  (None, 7, 7, 16)             2320      ['reshape_3[0][0]']
#  Transpose)
#
#  dropout_14 (Dropout)        (None, 7, 7, 16)             0         ['conv2d_transpose_3[0][0]']
#
#  up_sampling2d_6 (UpSamplin  (None, 14, 14, 16)           0         ['dropout_14[0][0]']
#  g2D)
#
#  conv2Transpose (Conv2DTran  (None, 14, 14, 6)            870       ['up_sampling2d_6[0][0]']
#  spose)
#
#  dropout_15 (Dropout)        (None, 14, 14, 6)            0         ['conv2Transpose[0][0]']
#
#  up_sampling2d_7 (UpSamplin  (None, 28, 28, 6)            0         ['dropout_15[0][0]']
#  g2D)
#
#  reconstruction (Conv2D)     (None, 28, 28, 1)            55        ['up_sampling2d_7[0][0]']
#
#  z_gaussian (Concatenate)    (None, 128)                  0         ['z_mean[0][0]',
#                                                                      'z_log_var[0][0]']
#
#  softmax_output (Dense)      (None, 10)                   650       ['sampling_3[0][0]']
#
# ==================================================================================================
# Total params: 825963 (3.15 MB)
# Trainable params: 825963 (3.15 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
tf.keras.utils.plot_model(model, show_layer_names=True, show_shapes=True, dpi=96)

# %%
# Convertir las etiquetas a one-hot encoding
y_train_one_hot = to_categorical(y_train, num_classes=10)
y_valid_one_hot = to_categorical(y_valid, num_classes=10)

# Construir y compilar el modelo
input_shape = (28, 28, 1)
num_classes = 10
latent_dim = 128
learning_rate = 0.001

model = build_and_compile_model(input_shape, num_classes, latent_dim, learning_rate)

# Entrenar el modelo
epochs = 100
batch_size = 64

history = model.fit(X_train, 
                    [X_train, X_train, y_train_one_hot],
                    epochs=epochs, 
                    batch_size=batch_size, 
                    validation_data=(X_valid, [X_valid, X_valid, y_valid_one_hot])
                   )
# Out:
# Epoch 1/100
# 2024-08-06 01:04:29.949539: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape invae/dropout_16/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 860/860 [==============================] - 12s 9ms/step - loss: 0.4067 - reconstruction_loss: 1.3163 - z_gaussian_loss: 0.0024 - softmax_output_loss: 0.0226 - reconstruction_BinaryLoss: 1.3163 - z_gaussian_DKLloss: 0.0024 - softmax_output_Categoricalloss: 0.0226 - softmax_output_accuracy: 0.7656 - val_loss: 0.3599 - val_reconstruction_loss: 1.1785 - val_z_gaussian_loss: 4.7797e-04 - val_softmax_output_loss: 0.0125 - val_reconstruction_BinaryLoss: 1.1789 - val_z_gaussian_DKLloss: 4.8237e-04 - val_softmax_output_Categoricalloss: 0.0124 - val_softmax_output_accuracy: 0.8090
# Epoch 2/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3663 - reconstruction_loss: 1.2039 - z_gaussian_loss: 6.7337e-04 - softmax_output_loss: 0.0101 - reconstruction_BinaryLoss: 1.2039 - z_gaussian_DKLloss: 6.7331e-04 - softmax_output_Categoricalloss: 0.0101 - softmax_output_accuracy: 0.8133 - val_loss: 0.3497 - val_reconstruction_loss: 1.1501 - val_z_gaussian_loss: 2.4593e-04 - val_softmax_output_loss: 0.0092 - val_reconstruction_BinaryLoss: 1.1505 - val_z_gaussian_DKLloss: 2.4806e-04 - val_softmax_output_Categoricalloss: 0.0091 - val_softmax_output_accuracy: 0.8284
# Epoch 3/100
# 860/860 [==============================] - 7s 9ms/step - loss: 0.3594 - reconstruction_loss: 1.1843 - z_gaussian_loss: 3.3077e-04 - softmax_output_loss: 0.0082 - reconstruction_BinaryLoss: 1.1842 - z_gaussian_DKLloss: 3.3079e-04 - softmax_output_Categoricalloss: 0.0082 - softmax_output_accuracy: 0.8208 - val_loss: 0.3457 - val_reconstruction_loss: 1.1372 - val_z_gaussian_loss: 1.6173e-04 - val_softmax_output_loss: 0.0091 - val_reconstruction_BinaryLoss: 1.1375 - val_z_gaussian_DKLloss: 1.6475e-04 - val_softmax_output_Categoricalloss: 0.0090 - val_softmax_output_accuracy: 0.8390
# Epoch 4/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3561 - reconstruction_loss: 1.1745 - z_gaussian_loss: 3.2144e-04 - softmax_output_loss: 0.0074 - reconstruction_BinaryLoss: 1.1745 - z_gaussian_DKLloss: 3.2137e-04 - softmax_output_Categoricalloss: 0.0074 - softmax_output_accuracy: 0.8225 - val_loss: 0.3435 - val_reconstruction_loss: 1.1322 - val_z_gaussian_loss: 6.3423e-04 - val_softmax_output_loss: 0.0074 - val_reconstruction_BinaryLoss: 1.1325 - val_z_gaussian_DKLloss: 6.3618e-04 - val_softmax_output_Categoricalloss: 0.0073 - val_softmax_output_accuracy: 0.8348
# Epoch 5/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3538 - reconstruction_loss: 1.1678 - z_gaussian_loss: 3.0928e-04 - softmax_output_loss: 0.0067 - reconstruction_BinaryLoss: 1.1679 - z_gaussian_DKLloss: 3.0993e-04 - softmax_output_Categoricalloss: 0.0067 - softmax_output_accuracy: 0.8281 - val_loss: 0.3429 - val_reconstruction_loss: 1.1271 - val_z_gaussian_loss: 4.6624e-04 - val_softmax_output_loss: 0.0094 - val_reconstruction_BinaryLoss: 1.1275 - val_z_gaussian_DKLloss: 4.6859e-04 - val_softmax_output_Categoricalloss: 0.0093 - val_softmax_output_accuracy: 0.8142
# Epoch 6/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3521 - reconstruction_loss: 1.1629 - z_gaussian_loss: 2.4899e-04 - softmax_output_loss: 0.0063 - reconstruction_BinaryLoss: 1.1629 - z_gaussian_DKLloss: 2.4897e-04 - softmax_output_Categoricalloss: 0.0063 - softmax_output_accuracy: 0.8297 - val_loss: 0.3401 - val_reconstruction_loss: 1.1219 - val_z_gaussian_loss: 1.2398e-04 - val_softmax_output_loss: 0.0071 - val_reconstruction_BinaryLoss: 1.1222 - val_z_gaussian_DKLloss: 1.2455e-04 - val_softmax_output_Categoricalloss: 0.0071 - val_softmax_output_accuracy: 0.8238
# Epoch 7/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3516 - reconstruction_loss: 1.1611 - z_gaussian_loss: 4.6491e-04 - softmax_output_loss: 0.0064 - reconstruction_BinaryLoss: 1.1611 - z_gaussian_DKLloss: 4.6502e-04 - softmax_output_Categoricalloss: 0.0064 - softmax_output_accuracy: 0.8287 - val_loss: 0.3386 - val_reconstruction_loss: 1.1163 - val_z_gaussian_loss: 2.3821e-04 - val_softmax_output_loss: 0.0073 - val_reconstruction_BinaryLoss: 1.1166 - val_z_gaussian_DKLloss: 2.3859e-04 - val_softmax_output_Categoricalloss: 0.0072 - val_softmax_output_accuracy: 0.8412
# Epoch 8/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3496 - reconstruction_loss: 1.1554 - z_gaussian_loss: 1.0379e-04 - softmax_output_loss: 0.0059 - reconstruction_BinaryLoss: 1.1554 - z_gaussian_DKLloss: 1.0374e-04 - softmax_output_Categoricalloss: 0.0059 - softmax_output_accuracy: 0.8341 - val_loss: 0.3368 - val_reconstruction_loss: 1.1120 - val_z_gaussian_loss: 2.7217e-05 - val_softmax_output_loss: 0.0065 - val_reconstruction_BinaryLoss: 1.1122 - val_z_gaussian_DKLloss: 2.7740e-05 - val_softmax_output_Categoricalloss: 0.0064 - val_softmax_output_accuracy: 0.8484
# Epoch 9/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3489 - reconstruction_loss: 1.1529 - z_gaussian_loss: 6.3616e-05 - softmax_output_loss: 0.0060 - reconstruction_BinaryLoss: 1.1529 - z_gaussian_DKLloss: 6.3655e-05 - softmax_output_Categoricalloss: 0.0060 - softmax_output_accuracy: 0.8378 - val_loss: 0.3360 - val_reconstruction_loss: 1.1095 - val_z_gaussian_loss: 6.9595e-05 - val_softmax_output_loss: 0.0062 - val_reconstruction_BinaryLoss: 1.1098 - val_z_gaussian_DKLloss: 6.9887e-05 - val_softmax_output_Categoricalloss: 0.0061 - val_softmax_output_accuracy: 0.8454
# Epoch 10/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3484 - reconstruction_loss: 1.1516 - z_gaussian_loss: 2.5680e-04 - softmax_output_loss: 0.0058 - reconstruction_BinaryLoss: 1.1516 - z_gaussian_DKLloss: 2.5680e-04 - softmax_output_Categoricalloss: 0.0058 - softmax_output_accuracy: 0.8381 - val_loss: 0.3354 - val_reconstruction_loss: 1.1080 - val_z_gaussian_loss: 2.2519e-04 - val_softmax_output_loss: 0.0060 - val_reconstruction_BinaryLoss: 1.1082 - val_z_gaussian_DKLloss: 2.2657e-04 - val_softmax_output_Categoricalloss: 0.0059 - val_softmax_output_accuracy: 0.8486
# Epoch 11/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3472 - reconstruction_loss: 1.1484 - z_gaussian_loss: 1.0788e-04 - softmax_output_loss: 0.0053 - reconstruction_BinaryLoss: 1.1483 - z_gaussian_DKLloss: 1.0787e-04 - softmax_output_Categoricalloss: 0.0053 - softmax_output_accuracy: 0.8445 - val_loss: 0.3349 - val_reconstruction_loss: 1.1060 - val_z_gaussian_loss: 4.5548e-05 - val_softmax_output_loss: 0.0063 - val_reconstruction_BinaryLoss: 1.1062 - val_z_gaussian_DKLloss: 4.6352e-05 - val_softmax_output_Categoricalloss: 0.0062 - val_softmax_output_accuracy: 0.8530
# Epoch 12/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3471 - reconstruction_loss: 1.1478 - z_gaussian_loss: 4.2776e-04 - softmax_output_loss: 0.0054 - reconstruction_BinaryLoss: 1.1478 - z_gaussian_DKLloss: 4.2751e-04 - softmax_output_Categoricalloss: 0.0054 - softmax_output_accuracy: 0.8407 - val_loss: 0.3344 - val_reconstruction_loss: 1.1044 - val_z_gaussian_loss: 9.0387e-05 - val_softmax_output_loss: 0.0061 - val_reconstruction_BinaryLoss: 1.1046 - val_z_gaussian_DKLloss: 9.0401e-05 - val_softmax_output_Categoricalloss: 0.0060 - val_softmax_output_accuracy: 0.8446
# Epoch 13/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3465 - reconstruction_loss: 1.1461 - z_gaussian_loss: 5.6846e-05 - softmax_output_loss: 0.0053 - reconstruction_BinaryLoss: 1.1462 - z_gaussian_DKLloss: 5.6862e-05 - softmax_output_Categoricalloss: 0.0053 - softmax_output_accuracy: 0.8403 - val_loss: 0.3341 - val_reconstruction_loss: 1.1045 - val_z_gaussian_loss: 3.0946e-05 - val_softmax_output_loss: 0.0054 - val_reconstruction_BinaryLoss: 1.1047 - val_z_gaussian_DKLloss: 3.0895e-05 - val_softmax_output_Categoricalloss: 0.0054 - val_softmax_output_accuracy: 0.8528
# Epoch 14/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3460 - reconstruction_loss: 1.1448 - z_gaussian_loss: 8.8807e-05 - softmax_output_loss: 0.0051 - reconstruction_BinaryLoss: 1.1448 - z_gaussian_DKLloss: 8.8811e-05 - softmax_output_Categoricalloss: 0.0051 - softmax_output_accuracy: 0.8429 - val_loss: 0.3335 - val_reconstruction_loss: 1.1023 - val_z_gaussian_loss: 7.8529e-05 - val_softmax_output_loss: 0.0055 - val_reconstruction_BinaryLoss: 1.1025 - val_z_gaussian_DKLloss: 7.9168e-05 - val_softmax_output_Categoricalloss: 0.0055 - val_softmax_output_accuracy: 0.8566
# Epoch 15/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3457 - reconstruction_loss: 1.1436 - z_gaussian_loss: 1.7020e-04 - softmax_output_loss: 0.0051 - reconstruction_BinaryLoss: 1.1436 - z_gaussian_DKLloss: 1.7029e-04 - softmax_output_Categoricalloss: 0.0051 - softmax_output_accuracy: 0.8439 - val_loss: 0.3336 - val_reconstruction_loss: 1.1024 - val_z_gaussian_loss: 1.8106e-04 - val_softmax_output_loss: 0.0057 - val_reconstruction_BinaryLoss: 1.1026 - val_z_gaussian_DKLloss: 1.8134e-04 - val_softmax_output_Categoricalloss: 0.0056 - val_softmax_output_accuracy: 0.8442
# Epoch 16/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3453 - reconstruction_loss: 1.1427 - z_gaussian_loss: 2.0982e-04 - softmax_output_loss: 0.0049 - reconstruction_BinaryLoss: 1.1427 - z_gaussian_DKLloss: 2.0997e-04 - softmax_output_Categoricalloss: 0.0049 - softmax_output_accuracy: 0.8446 - val_loss: 0.3326 - val_reconstruction_loss: 1.0991 - val_z_gaussian_loss: 4.8471e-04 - val_softmax_output_loss: 0.0055 - val_reconstruction_BinaryLoss: 1.0993 - val_z_gaussian_DKLloss: 4.8721e-04 - val_softmax_output_Categoricalloss: 0.0054 - val_softmax_output_accuracy: 0.8518
# Epoch 17/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3455 - reconstruction_loss: 1.1429 - z_gaussian_loss: 2.2137e-04 - softmax_output_loss: 0.0051 - reconstruction_BinaryLoss: 1.1429 - z_gaussian_DKLloss: 2.2130e-04 - softmax_output_Categoricalloss: 0.0051 - softmax_output_accuracy: 0.8433 - val_loss: 0.3326 - val_reconstruction_loss: 1.0987 - val_z_gaussian_loss: 1.3809e-04 - val_softmax_output_loss: 0.0059 - val_reconstruction_BinaryLoss: 1.0989 - val_z_gaussian_DKLloss: 1.3813e-04 - val_softmax_output_Categoricalloss: 0.0059 - val_softmax_output_accuracy: 0.8494
# Epoch 18/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3462 - reconstruction_loss: 1.1436 - z_gaussian_loss: 3.1658e-04 - softmax_output_loss: 0.0060 - reconstruction_BinaryLoss: 1.1436 - z_gaussian_DKLloss: 3.1646e-04 - softmax_output_Categoricalloss: 0.0060 - softmax_output_accuracy: 0.8375 - val_loss: 0.3321 - val_reconstruction_loss: 1.0983 - val_z_gaussian_loss: 1.1993e-04 - val_softmax_output_loss: 0.0052 - val_reconstruction_BinaryLoss: 1.0985 - val_z_gaussian_DKLloss: 1.2039e-04 - val_softmax_output_Categoricalloss: 0.0052 - val_softmax_output_accuracy: 0.8526
# Epoch 19/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3447 - reconstruction_loss: 1.1408 - z_gaussian_loss: 1.0485e-04 - softmax_output_loss: 0.0049 - reconstruction_BinaryLoss: 1.1408 - z_gaussian_DKLloss: 1.0483e-04 - softmax_output_Categoricalloss: 0.0049 - softmax_output_accuracy: 0.8432 - val_loss: 0.3328 - val_reconstruction_loss: 1.0998 - val_z_gaussian_loss: 1.5842e-04 - val_softmax_output_loss: 0.0056 - val_reconstruction_BinaryLoss: 1.1000 - val_z_gaussian_DKLloss: 1.6061e-04 - val_softmax_output_Categoricalloss: 0.0056 - val_softmax_output_accuracy: 0.8532
# Epoch 20/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3443 - reconstruction_loss: 1.1397 - z_gaussian_loss: 1.4768e-04 - softmax_output_loss: 0.0046 - reconstruction_BinaryLoss: 1.1397 - z_gaussian_DKLloss: 1.4766e-04 - softmax_output_Categoricalloss: 0.0047 - softmax_output_accuracy: 0.8481 - val_loss: 0.3315 - val_reconstruction_loss: 1.0960 - val_z_gaussian_loss: 2.6325e-04 - val_softmax_output_loss: 0.0053 - val_reconstruction_BinaryLoss: 1.0962 - val_z_gaussian_DKLloss: 2.6294e-04 - val_softmax_output_Categoricalloss: 0.0052 - val_softmax_output_accuracy: 0.8440
# Epoch 21/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3444 - reconstruction_loss: 1.1403 - z_gaussian_loss: 2.1978e-04 - softmax_output_loss: 0.0046 - reconstruction_BinaryLoss: 1.1403 - z_gaussian_DKLloss: 2.1995e-04 - softmax_output_Categoricalloss: 0.0046 - softmax_output_accuracy: 0.8475 - val_loss: 0.3327 - val_reconstruction_loss: 1.0984 - val_z_gaussian_loss: 2.0519e-04 - val_softmax_output_loss: 0.0063 - val_reconstruction_BinaryLoss: 1.0986 - val_z_gaussian_DKLloss: 2.0489e-04 - val_softmax_output_Categoricalloss: 0.0062 - val_softmax_output_accuracy: 0.8448
# Epoch 22/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3440 - reconstruction_loss: 1.1388 - z_gaussian_loss: 1.9428e-04 - softmax_output_loss: 0.0046 - reconstruction_BinaryLoss: 1.1388 - z_gaussian_DKLloss: 1.9429e-04 - softmax_output_Categoricalloss: 0.0046 - softmax_output_accuracy: 0.8480 - val_loss: 0.3313 - val_reconstruction_loss: 1.0961 - val_z_gaussian_loss: 1.2144e-04 - val_softmax_output_loss: 0.0049 - val_reconstruction_BinaryLoss: 1.0964 - val_z_gaussian_DKLloss: 1.2300e-04 - val_softmax_output_Categoricalloss: 0.0049 - val_softmax_output_accuracy: 0.8462
# Epoch 23/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3437 - reconstruction_loss: 1.1380 - z_gaussian_loss: 1.9006e-04 - softmax_output_loss: 0.0044 - reconstruction_BinaryLoss: 1.1380 - z_gaussian_DKLloss: 1.9006e-04 - softmax_output_Categoricalloss: 0.0044 - softmax_output_accuracy: 0.8486 - val_loss: 0.3310 - val_reconstruction_loss: 1.0953 - val_z_gaussian_loss: 2.3856e-04 - val_softmax_output_loss: 0.0047 - val_reconstruction_BinaryLoss: 1.0955 - val_z_gaussian_DKLloss: 2.4644e-04 - val_softmax_output_Categoricalloss: 0.0046 - val_softmax_output_accuracy: 0.8542
# Epoch 24/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3438 - reconstruction_loss: 1.1380 - z_gaussian_loss: 2.1653e-04 - softmax_output_loss: 0.0046 - reconstruction_BinaryLoss: 1.1380 - z_gaussian_DKLloss: 2.1664e-04 - softmax_output_Categoricalloss: 0.0046 - softmax_output_accuracy: 0.8465 - val_loss: 0.3329 - val_reconstruction_loss: 1.1000 - val_z_gaussian_loss: 2.3126e-04 - val_softmax_output_loss: 0.0057 - val_reconstruction_BinaryLoss: 1.1002 - val_z_gaussian_DKLloss: 2.3072e-04 - val_softmax_output_Categoricalloss: 0.0057 - val_softmax_output_accuracy: 0.8590
# Epoch 25/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3437 - reconstruction_loss: 1.1376 - z_gaussian_loss: 2.3477e-04 - softmax_output_loss: 0.0046 - reconstruction_BinaryLoss: 1.1376 - z_gaussian_DKLloss: 2.3496e-04 - softmax_output_Categoricalloss: 0.0047 - softmax_output_accuracy: 0.8491 - val_loss: 0.3321 - val_reconstruction_loss: 1.0974 - val_z_gaussian_loss: 2.7371e-04 - val_softmax_output_loss: 0.0057 - val_reconstruction_BinaryLoss: 1.0977 - val_z_gaussian_DKLloss: 2.7459e-04 - val_softmax_output_Categoricalloss: 0.0056 - val_softmax_output_accuracy: 0.8496
# Epoch 26/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3433 - reconstruction_loss: 1.1371 - z_gaussian_loss: 2.1230e-04 - softmax_output_loss: 0.0043 - reconstruction_BinaryLoss: 1.1371 - z_gaussian_DKLloss: 2.1239e-04 - softmax_output_Categoricalloss: 0.0043 - softmax_output_accuracy: 0.8490 - val_loss: 0.3308 - val_reconstruction_loss: 1.0933 - val_z_gaussian_loss: 1.3574e-04 - val_softmax_output_loss: 0.0056 - val_reconstruction_BinaryLoss: 1.0935 - val_z_gaussian_DKLloss: 1.3711e-04 - val_softmax_output_Categoricalloss: 0.0055 - val_softmax_output_accuracy: 0.8518
# Epoch 27/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3432 - reconstruction_loss: 1.1365 - z_gaussian_loss: 1.6109e-04 - softmax_output_loss: 0.0044 - reconstruction_BinaryLoss: 1.1365 - z_gaussian_DKLloss: 1.6111e-04 - softmax_output_Categoricalloss: 0.0044 - softmax_output_accuracy: 0.8493 - val_loss: 0.3305 - val_reconstruction_loss: 1.0930 - val_z_gaussian_loss: 1.1035e-04 - val_softmax_output_loss: 0.0051 - val_reconstruction_BinaryLoss: 1.0932 - val_z_gaussian_DKLloss: 1.1201e-04 - val_softmax_output_Categoricalloss: 0.0050 - val_softmax_output_accuracy: 0.8430
# Epoch 28/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3431 - reconstruction_loss: 1.1363 - z_gaussian_loss: 1.8595e-04 - softmax_output_loss: 0.0044 - reconstruction_BinaryLoss: 1.1363 - z_gaussian_DKLloss: 1.8592e-04 - softmax_output_Categoricalloss: 0.0044 - softmax_output_accuracy: 0.8472 - val_loss: 0.3313 - val_reconstruction_loss: 1.0943 - val_z_gaussian_loss: 1.5392e-04 - val_softmax_output_loss: 0.0060 - val_reconstruction_BinaryLoss: 1.0945 - val_z_gaussian_DKLloss: 1.5323e-04 - val_softmax_output_Categoricalloss: 0.0059 - val_softmax_output_accuracy: 0.8582
# Epoch 29/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3431 - reconstruction_loss: 1.1361 - z_gaussian_loss: 1.6789e-04 - softmax_output_loss: 0.0044 - reconstruction_BinaryLoss: 1.1361 - z_gaussian_DKLloss: 1.6787e-04 - softmax_output_Categoricalloss: 0.0044 - softmax_output_accuracy: 0.8494 - val_loss: 0.3309 - val_reconstruction_loss: 1.0943 - val_z_gaussian_loss: 1.2527e-04 - val_softmax_output_loss: 0.0051 - val_reconstruction_BinaryLoss: 1.0946 - val_z_gaussian_DKLloss: 1.2575e-04 - val_softmax_output_Categoricalloss: 0.0050 - val_softmax_output_accuracy: 0.8524
# Epoch 30/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3429 - reconstruction_loss: 1.1356 - z_gaussian_loss: 1.9976e-04 - softmax_output_loss: 0.0044 - reconstruction_BinaryLoss: 1.1356 - z_gaussian_DKLloss: 1.9972e-04 - softmax_output_Categoricalloss: 0.0044 - softmax_output_accuracy: 0.8501 - val_loss: 0.3296 - val_reconstruction_loss: 1.0914 - val_z_gaussian_loss: 1.1755e-04 - val_softmax_output_loss: 0.0043 - val_reconstruction_BinaryLoss: 1.0916 - val_z_gaussian_DKLloss: 1.1858e-04 - val_softmax_output_Categoricalloss: 0.0043 - val_softmax_output_accuracy: 0.8588
# Epoch 31/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3429 - reconstruction_loss: 1.1356 - z_gaussian_loss: 1.9229e-04 - softmax_output_loss: 0.0044 - reconstruction_BinaryLoss: 1.1356 - z_gaussian_DKLloss: 1.9239e-04 - softmax_output_Categoricalloss: 0.0044 - softmax_output_accuracy: 0.8514 - val_loss: 0.3298 - val_reconstruction_loss: 1.0916 - val_z_gaussian_loss: 1.6020e-04 - val_softmax_output_loss: 0.0045 - val_reconstruction_BinaryLoss: 1.0918 - val_z_gaussian_DKLloss: 1.6017e-04 - val_softmax_output_Categoricalloss: 0.0045 - val_softmax_output_accuracy: 0.8524
# Epoch 32/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3426 - reconstruction_loss: 1.1351 - z_gaussian_loss: 1.4858e-04 - softmax_output_loss: 0.0041 - reconstruction_BinaryLoss: 1.1352 - z_gaussian_DKLloss: 1.4855e-04 - softmax_output_Categoricalloss: 0.0041 - softmax_output_accuracy: 0.8508 - val_loss: 0.3303 - val_reconstruction_loss: 1.0930 - val_z_gaussian_loss: 1.0016e-04 - val_softmax_output_loss: 0.0048 - val_reconstruction_BinaryLoss: 1.0931 - val_z_gaussian_DKLloss: 1.0072e-04 - val_softmax_output_Categoricalloss: 0.0047 - val_softmax_output_accuracy: 0.8590
# Epoch 33/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3427 - reconstruction_loss: 1.1351 - z_gaussian_loss: 1.4504e-04 - softmax_output_loss: 0.0044 - reconstruction_BinaryLoss: 1.1351 - z_gaussian_DKLloss: 1.4505e-04 - softmax_output_Categoricalloss: 0.0044 - softmax_output_accuracy: 0.8482 - val_loss: 0.3296 - val_reconstruction_loss: 1.0909 - val_z_gaussian_loss: 8.1355e-05 - val_softmax_output_loss: 0.0047 - val_reconstruction_BinaryLoss: 1.0911 - val_z_gaussian_DKLloss: 8.1016e-05 - val_softmax_output_Categoricalloss: 0.0047 - val_softmax_output_accuracy: 0.8510
# Epoch 34/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3426 - reconstruction_loss: 1.1349 - z_gaussian_loss: 1.5911e-04 - softmax_output_loss: 0.0042 - reconstruction_BinaryLoss: 1.1349 - z_gaussian_DKLloss: 1.5934e-04 - softmax_output_Categoricalloss: 0.0042 - softmax_output_accuracy: 0.8507 - val_loss: 0.3301 - val_reconstruction_loss: 1.0922 - val_z_gaussian_loss: 2.8272e-04 - val_softmax_output_loss: 0.0048 - val_reconstruction_BinaryLoss: 1.0924 - val_z_gaussian_DKLloss: 2.8267e-04 - val_softmax_output_Categoricalloss: 0.0048 - val_softmax_output_accuracy: 0.8536
# Epoch 35/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3423 - reconstruction_loss: 1.1343 - z_gaussian_loss: 1.6179e-04 - softmax_output_loss: 0.0040 - reconstruction_BinaryLoss: 1.1344 - z_gaussian_DKLloss: 1.6178e-04 - softmax_output_Categoricalloss: 0.0040 - softmax_output_accuracy: 0.8483 - val_loss: 0.3298 - val_reconstruction_loss: 1.0910 - val_z_gaussian_loss: 1.1481e-04 - val_softmax_output_loss: 0.0050 - val_reconstruction_BinaryLoss: 1.0912 - val_z_gaussian_DKLloss: 1.1592e-04 - val_softmax_output_Categoricalloss: 0.0049 - val_softmax_output_accuracy: 0.8608
# Epoch 36/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3423 - reconstruction_loss: 1.1339 - z_gaussian_loss: 1.4597e-04 - softmax_output_loss: 0.0041 - reconstruction_BinaryLoss: 1.1339 - z_gaussian_DKLloss: 1.4613e-04 - softmax_output_Categoricalloss: 0.0041 - softmax_output_accuracy: 0.8517 - val_loss: 0.3298 - val_reconstruction_loss: 1.0919 - val_z_gaussian_loss: 1.7924e-04 - val_softmax_output_loss: 0.0043 - val_reconstruction_BinaryLoss: 1.0921 - val_z_gaussian_DKLloss: 1.8079e-04 - val_softmax_output_Categoricalloss: 0.0043 - val_softmax_output_accuracy: 0.8596
# Epoch 37/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3424 - reconstruction_loss: 1.1341 - z_gaussian_loss: 1.3937e-04 - softmax_output_loss: 0.0043 - reconstruction_BinaryLoss: 1.1341 - z_gaussian_DKLloss: 1.3935e-04 - softmax_output_Categoricalloss: 0.0043 - softmax_output_accuracy: 0.8496 - val_loss: 0.3301 - val_reconstruction_loss: 1.0920 - val_z_gaussian_loss: 1.1102e-04 - val_softmax_output_loss: 0.0049 - val_reconstruction_BinaryLoss: 1.0922 - val_z_gaussian_DKLloss: 1.1266e-04 - val_softmax_output_Categoricalloss: 0.0048 - val_softmax_output_accuracy: 0.8584
# Epoch 38/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3421 - reconstruction_loss: 1.1338 - z_gaussian_loss: 1.3245e-04 - softmax_output_loss: 0.0039 - reconstruction_BinaryLoss: 1.1338 - z_gaussian_DKLloss: 1.3240e-04 - softmax_output_Categoricalloss: 0.0039 - softmax_output_accuracy: 0.8523 - val_loss: 0.3303 - val_reconstruction_loss: 1.0913 - val_z_gaussian_loss: 6.8287e-05 - val_softmax_output_loss: 0.0058 - val_reconstruction_BinaryLoss: 1.0915 - val_z_gaussian_DKLloss: 6.9129e-05 - val_softmax_output_Categoricalloss: 0.0057 - val_softmax_output_accuracy: 0.8526
# Epoch 39/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3421 - reconstruction_loss: 1.1334 - z_gaussian_loss: 1.3235e-04 - softmax_output_loss: 0.0040 - reconstruction_BinaryLoss: 1.1334 - z_gaussian_DKLloss: 1.3242e-04 - softmax_output_Categoricalloss: 0.0040 - softmax_output_accuracy: 0.8521 - val_loss: 0.3292 - val_reconstruction_loss: 1.0900 - val_z_gaussian_loss: 2.9143e-04 - val_softmax_output_loss: 0.0043 - val_reconstruction_BinaryLoss: 1.0902 - val_z_gaussian_DKLloss: 2.9261e-04 - val_softmax_output_Categoricalloss: 0.0042 - val_softmax_output_accuracy: 0.8608
# Epoch 40/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3420 - reconstruction_loss: 1.1334 - z_gaussian_loss: 1.4049e-04 - softmax_output_loss: 0.0040 - reconstruction_BinaryLoss: 1.1335 - z_gaussian_DKLloss: 1.4053e-04 - softmax_output_Categoricalloss: 0.0040 - softmax_output_accuracy: 0.8492 - val_loss: 0.3295 - val_reconstruction_loss: 1.0911 - val_z_gaussian_loss: 7.8707e-05 - val_softmax_output_loss: 0.0044 - val_reconstruction_BinaryLoss: 1.0913 - val_z_gaussian_DKLloss: 7.9422e-05 - val_softmax_output_Categoricalloss: 0.0043 - val_softmax_output_accuracy: 0.8588
# Epoch 41/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3424 - reconstruction_loss: 1.1346 - z_gaussian_loss: 1.8027e-04 - softmax_output_loss: 0.0040 - reconstruction_BinaryLoss: 1.1346 - z_gaussian_DKLloss: 1.8028e-04 - softmax_output_Categoricalloss: 0.0040 - softmax_output_accuracy: 0.8482 - val_loss: 0.3292 - val_reconstruction_loss: 1.0903 - val_z_gaussian_loss: 1.4820e-04 - val_softmax_output_loss: 0.0042 - val_reconstruction_BinaryLoss: 1.0905 - val_z_gaussian_DKLloss: 1.4893e-04 - val_softmax_output_Categoricalloss: 0.0041 - val_softmax_output_accuracy: 0.8622
# Epoch 42/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3418 - reconstruction_loss: 1.1329 - z_gaussian_loss: 1.3248e-04 - softmax_output_loss: 0.0038 - reconstruction_BinaryLoss: 1.1329 - z_gaussian_DKLloss: 1.3254e-04 - softmax_output_Categoricalloss: 0.0038 - softmax_output_accuracy: 0.8548 - val_loss: 0.3293 - val_reconstruction_loss: 1.0901 - val_z_gaussian_loss: 3.0016e-04 - val_softmax_output_loss: 0.0045 - val_reconstruction_BinaryLoss: 1.0903 - val_z_gaussian_DKLloss: 2.9993e-04 - val_softmax_output_Categoricalloss: 0.0044 - val_softmax_output_accuracy: 0.8580
# Epoch 43/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3419 - reconstruction_loss: 1.1329 - z_gaussian_loss: 1.1542e-04 - softmax_output_loss: 0.0039 - reconstruction_BinaryLoss: 1.1328 - z_gaussian_DKLloss: 1.1547e-04 - softmax_output_Categoricalloss: 0.0040 - softmax_output_accuracy: 0.8517 - val_loss: 0.3303 - val_reconstruction_loss: 1.0940 - val_z_gaussian_loss: 8.7727e-05 - val_softmax_output_loss: 0.0041 - val_reconstruction_BinaryLoss: 1.0941 - val_z_gaussian_DKLloss: 8.7992e-05 - val_softmax_output_Categoricalloss: 0.0041 - val_softmax_output_accuracy: 0.8602
# Epoch 44/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3419 - reconstruction_loss: 1.1330 - z_gaussian_loss: 1.2542e-04 - softmax_output_loss: 0.0039 - reconstruction_BinaryLoss: 1.1330 - z_gaussian_DKLloss: 1.2542e-04 - softmax_output_Categoricalloss: 0.0039 - softmax_output_accuracy: 0.8501 - val_loss: 0.3294 - val_reconstruction_loss: 1.0906 - val_z_gaussian_loss: 6.7739e-05 - val_softmax_output_loss: 0.0045 - val_reconstruction_BinaryLoss: 1.0908 - val_z_gaussian_DKLloss: 6.8467e-05 - val_softmax_output_Categoricalloss: 0.0044 - val_softmax_output_accuracy: 0.8628
# Epoch 45/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3422 - reconstruction_loss: 1.1334 - z_gaussian_loss: 1.3028e-04 - softmax_output_loss: 0.0042 - reconstruction_BinaryLoss: 1.1334 - z_gaussian_DKLloss: 1.3030e-04 - softmax_output_Categoricalloss: 0.0042 - softmax_output_accuracy: 0.8472 - val_loss: 0.3296 - val_reconstruction_loss: 1.0910 - val_z_gaussian_loss: 1.5633e-04 - val_softmax_output_loss: 0.0046 - val_reconstruction_BinaryLoss: 1.0912 - val_z_gaussian_DKLloss: 1.5827e-04 - val_softmax_output_Categoricalloss: 0.0045 - val_softmax_output_accuracy: 0.8574
# Epoch 46/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3419 - reconstruction_loss: 1.1329 - z_gaussian_loss: 1.4179e-04 - softmax_output_loss: 0.0039 - reconstruction_BinaryLoss: 1.1329 - z_gaussian_DKLloss: 1.4179e-04 - softmax_output_Categoricalloss: 0.0039 - softmax_output_accuracy: 0.8501 - val_loss: 0.3300 - val_reconstruction_loss: 1.0913 - val_z_gaussian_loss: 9.4351e-05 - val_softmax_output_loss: 0.0052 - val_reconstruction_BinaryLoss: 1.0915 - val_z_gaussian_DKLloss: 9.5115e-05 - val_softmax_output_Categoricalloss: 0.0051 - val_softmax_output_accuracy: 0.8526
# Epoch 47/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3417 - reconstruction_loss: 1.1323 - z_gaussian_loss: 1.3435e-04 - softmax_output_loss: 0.0039 - reconstruction_BinaryLoss: 1.1323 - z_gaussian_DKLloss: 1.3479e-04 - softmax_output_Categoricalloss: 0.0039 - softmax_output_accuracy: 0.8528 - val_loss: 0.3308 - val_reconstruction_loss: 1.0944 - val_z_gaussian_loss: 1.8127e-04 - val_softmax_output_loss: 0.0048 - val_reconstruction_BinaryLoss: 1.0946 - val_z_gaussian_DKLloss: 1.8219e-04 - val_softmax_output_Categoricalloss: 0.0047 - val_softmax_output_accuracy: 0.8526
# Epoch 48/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3417 - reconstruction_loss: 1.1325 - z_gaussian_loss: 1.4266e-04 - softmax_output_loss: 0.0039 - reconstruction_BinaryLoss: 1.1325 - z_gaussian_DKLloss: 1.4264e-04 - softmax_output_Categoricalloss: 0.0039 - softmax_output_accuracy: 0.8514 - val_loss: 0.3294 - val_reconstruction_loss: 1.0905 - val_z_gaussian_loss: 8.5135e-05 - val_softmax_output_loss: 0.0045 - val_reconstruction_BinaryLoss: 1.0907 - val_z_gaussian_DKLloss: 8.7205e-05 - val_softmax_output_Categoricalloss: 0.0045 - val_softmax_output_accuracy: 0.8618
# Epoch 49/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3416 - reconstruction_loss: 1.1324 - z_gaussian_loss: 1.4847e-04 - softmax_output_loss: 0.0038 - reconstruction_BinaryLoss: 1.1324 - z_gaussian_DKLloss: 1.4864e-04 - softmax_output_Categoricalloss: 0.0038 - softmax_output_accuracy: 0.8520 - val_loss: 0.3303 - val_reconstruction_loss: 1.0910 - val_z_gaussian_loss: 6.2702e-05 - val_softmax_output_loss: 0.0060 - val_reconstruction_BinaryLoss: 1.0912 - val_z_gaussian_DKLloss: 6.2568e-05 - val_softmax_output_Categoricalloss: 0.0059 - val_softmax_output_accuracy: 0.8512
# Epoch 50/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3438 - reconstruction_loss: 1.1363 - z_gaussian_loss: 8.5017e-04 - softmax_output_loss: 0.0056 - reconstruction_BinaryLoss: 1.1363 - z_gaussian_DKLloss: 8.4961e-04 - softmax_output_Categoricalloss: 0.0055 - softmax_output_accuracy: 0.8395 - val_loss: 0.3307 - val_reconstruction_loss: 1.0940 - val_z_gaussian_loss: 3.0177e-05 - val_softmax_output_loss: 0.0051 - val_reconstruction_BinaryLoss: 1.0942 - val_z_gaussian_DKLloss: 3.0591e-05 - val_softmax_output_Categoricalloss: 0.0050 - val_softmax_output_accuracy: 0.8574
# Epoch 51/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3417 - reconstruction_loss: 1.1324 - z_gaussian_loss: 3.6913e-05 - softmax_output_loss: 0.0040 - reconstruction_BinaryLoss: 1.1324 - z_gaussian_DKLloss: 3.6908e-05 - softmax_output_Categoricalloss: 0.0040 - softmax_output_accuracy: 0.8499 - val_loss: 0.3294 - val_reconstruction_loss: 1.0904 - val_z_gaussian_loss: 1.2757e-05 - val_softmax_output_loss: 0.0046 - val_reconstruction_BinaryLoss: 1.0906 - val_z_gaussian_DKLloss: 1.2908e-05 - val_softmax_output_Categoricalloss: 0.0045 - val_softmax_output_accuracy: 0.8572
# Epoch 52/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3415 - reconstruction_loss: 1.1320 - z_gaussian_loss: 2.4088e-05 - softmax_output_loss: 0.0037 - reconstruction_BinaryLoss: 1.1320 - z_gaussian_DKLloss: 2.4088e-05 - softmax_output_Categoricalloss: 0.0037 - softmax_output_accuracy: 0.8515 - val_loss: 0.3289 - val_reconstruction_loss: 1.0891 - val_z_gaussian_loss: 2.0018e-05 - val_softmax_output_loss: 0.0043 - val_reconstruction_BinaryLoss: 1.0893 - val_z_gaussian_DKLloss: 2.0095e-05 - val_softmax_output_Categoricalloss: 0.0042 - val_softmax_output_accuracy: 0.8474
# Epoch 53/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3415 - reconstruction_loss: 1.1319 - z_gaussian_loss: 3.6385e-05 - softmax_output_loss: 0.0039 - reconstruction_BinaryLoss: 1.1319 - z_gaussian_DKLloss: 3.6395e-05 - softmax_output_Categoricalloss: 0.0040 - softmax_output_accuracy: 0.8528 - val_loss: 0.3308 - val_reconstruction_loss: 1.0916 - val_z_gaussian_loss: 4.3813e-05 - val_softmax_output_loss: 0.0066 - val_reconstruction_BinaryLoss: 1.0918 - val_z_gaussian_DKLloss: 4.4000e-05 - val_softmax_output_Categoricalloss: 0.0065 - val_softmax_output_accuracy: 0.8456
# Epoch 54/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3414 - reconstruction_loss: 1.1318 - z_gaussian_loss: 4.2353e-05 - softmax_output_loss: 0.0037 - reconstruction_BinaryLoss: 1.1318 - z_gaussian_DKLloss: 4.2355e-05 - softmax_output_Categoricalloss: 0.0037 - softmax_output_accuracy: 0.8505 - val_loss: 0.3293 - val_reconstruction_loss: 1.0905 - val_z_gaussian_loss: 3.2666e-05 - val_softmax_output_loss: 0.0043 - val_reconstruction_BinaryLoss: 1.0907 - val_z_gaussian_DKLloss: 3.2817e-05 - val_softmax_output_Categoricalloss: 0.0043 - val_softmax_output_accuracy: 0.8584
# Epoch 55/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3415 - reconstruction_loss: 1.1320 - z_gaussian_loss: 6.5794e-05 - softmax_output_loss: 0.0037 - reconstruction_BinaryLoss: 1.1320 - z_gaussian_DKLloss: 6.5872e-05 - softmax_output_Categoricalloss: 0.0037 - softmax_output_accuracy: 0.8509 - val_loss: 0.3288 - val_reconstruction_loss: 1.0879 - val_z_gaussian_loss: 4.9849e-05 - val_softmax_output_loss: 0.0048 - val_reconstruction_BinaryLoss: 1.0881 - val_z_gaussian_DKLloss: 5.0070e-05 - val_softmax_output_Categoricalloss: 0.0047 - val_softmax_output_accuracy: 0.8638
# Epoch 56/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3414 - reconstruction_loss: 1.1319 - z_gaussian_loss: 9.7146e-05 - softmax_output_loss: 0.0035 - reconstruction_BinaryLoss: 1.1319 - z_gaussian_DKLloss: 9.7153e-05 - softmax_output_Categoricalloss: 0.0035 - softmax_output_accuracy: 0.8519 - val_loss: 0.3292 - val_reconstruction_loss: 1.0894 - val_z_gaussian_loss: 4.9671e-05 - val_softmax_output_loss: 0.0047 - val_reconstruction_BinaryLoss: 1.0896 - val_z_gaussian_DKLloss: 4.9896e-05 - val_softmax_output_Categoricalloss: 0.0047 - val_softmax_output_accuracy: 0.8598
# Epoch 57/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3414 - reconstruction_loss: 1.1317 - z_gaussian_loss: 1.0561e-04 - softmax_output_loss: 0.0037 - reconstruction_BinaryLoss: 1.1317 - z_gaussian_DKLloss: 1.0571e-04 - softmax_output_Categoricalloss: 0.0037 - softmax_output_accuracy: 0.8527 - val_loss: 0.3318 - val_reconstruction_loss: 1.0979 - val_z_gaussian_loss: 6.0364e-05 - val_softmax_output_loss: 0.0049 - val_reconstruction_BinaryLoss: 1.0981 - val_z_gaussian_DKLloss: 6.0534e-05 - val_softmax_output_Categoricalloss: 0.0048 - val_softmax_output_accuracy: 0.8502
# Epoch 58/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3415 - reconstruction_loss: 1.1320 - z_gaussian_loss: 1.1412e-04 - softmax_output_loss: 0.0037 - reconstruction_BinaryLoss: 1.1320 - z_gaussian_DKLloss: 1.1417e-04 - softmax_output_Categoricalloss: 0.0037 - softmax_output_accuracy: 0.8527 - val_loss: 0.3286 - val_reconstruction_loss: 1.0880 - val_z_gaussian_loss: 9.4865e-05 - val_softmax_output_loss: 0.0044 - val_reconstruction_BinaryLoss: 1.0882 - val_z_gaussian_DKLloss: 9.7514e-05 - val_softmax_output_Categoricalloss: 0.0044 - val_softmax_output_accuracy: 0.8554
# Epoch 59/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3414 - reconstruction_loss: 1.1317 - z_gaussian_loss: 1.3285e-04 - softmax_output_loss: 0.0037 - reconstruction_BinaryLoss: 1.1317 - z_gaussian_DKLloss: 1.3282e-04 - softmax_output_Categoricalloss: 0.0037 - softmax_output_accuracy: 0.8503 - val_loss: 0.3291 - val_reconstruction_loss: 1.0892 - val_z_gaussian_loss: 1.5013e-04 - val_softmax_output_loss: 0.0045 - val_reconstruction_BinaryLoss: 1.0894 - val_z_gaussian_DKLloss: 1.5248e-04 - val_softmax_output_Categoricalloss: 0.0045 - val_softmax_output_accuracy: 0.8622
# Epoch 60/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3412 - reconstruction_loss: 1.1313 - z_gaussian_loss: 1.3544e-04 - softmax_output_loss: 0.0035 - reconstruction_BinaryLoss: 1.1313 - z_gaussian_DKLloss: 1.3545e-04 - softmax_output_Categoricalloss: 0.0035 - softmax_output_accuracy: 0.8528 - val_loss: 0.3285 - val_reconstruction_loss: 1.0878 - val_z_gaussian_loss: 7.7800e-05 - val_softmax_output_loss: 0.0043 - val_reconstruction_BinaryLoss: 1.0880 - val_z_gaussian_DKLloss: 7.8195e-05 - val_softmax_output_Categoricalloss: 0.0042 - val_softmax_output_accuracy: 0.8630
# Epoch 61/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3413 - reconstruction_loss: 1.1314 - z_gaussian_loss: 1.2468e-04 - softmax_output_loss: 0.0037 - reconstruction_BinaryLoss: 1.1314 - z_gaussian_DKLloss: 1.2486e-04 - softmax_output_Categoricalloss: 0.0037 - softmax_output_accuracy: 0.8519 - val_loss: 0.3282 - val_reconstruction_loss: 1.0878 - val_z_gaussian_loss: 1.9508e-04 - val_softmax_output_loss: 0.0037 - val_reconstruction_BinaryLoss: 1.0880 - val_z_gaussian_DKLloss: 1.9727e-04 - val_softmax_output_Categoricalloss: 0.0036 - val_softmax_output_accuracy: 0.8586
# Epoch 62/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3415 - reconstruction_loss: 1.1318 - z_gaussian_loss: 1.4223e-04 - softmax_output_loss: 0.0038 - reconstruction_BinaryLoss: 1.1318 - z_gaussian_DKLloss: 1.4227e-04 - softmax_output_Categoricalloss: 0.0038 - softmax_output_accuracy: 0.8509 - val_loss: 0.3324 - val_reconstruction_loss: 1.0974 - val_z_gaussian_loss: 4.0645e-04 - val_softmax_output_loss: 0.0062 - val_reconstruction_BinaryLoss: 1.0976 - val_z_gaussian_DKLloss: 4.0975e-04 - val_softmax_output_Categoricalloss: 0.0061 - val_softmax_output_accuracy: 0.8386
# Epoch 63/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3412 - reconstruction_loss: 1.1314 - z_gaussian_loss: 1.1836e-04 - softmax_output_loss: 0.0035 - reconstruction_BinaryLoss: 1.1314 - z_gaussian_DKLloss: 1.1834e-04 - softmax_output_Categoricalloss: 0.0035 - softmax_output_accuracy: 0.8511 - val_loss: 0.3292 - val_reconstruction_loss: 1.0904 - val_z_gaussian_loss: 5.4496e-05 - val_softmax_output_loss: 0.0041 - val_reconstruction_BinaryLoss: 1.0907 - val_z_gaussian_DKLloss: 5.5249e-05 - val_softmax_output_Categoricalloss: 0.0040 - val_softmax_output_accuracy: 0.8640
# Epoch 64/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3409 - reconstruction_loss: 1.1308 - z_gaussian_loss: 1.0627e-04 - softmax_output_loss: 0.0033 - reconstruction_BinaryLoss: 1.1308 - z_gaussian_DKLloss: 1.0628e-04 - softmax_output_Categoricalloss: 0.0033 - softmax_output_accuracy: 0.8543 - val_loss: 0.3295 - val_reconstruction_loss: 1.0898 - val_z_gaussian_loss: 1.1119e-04 - val_softmax_output_loss: 0.0051 - val_reconstruction_BinaryLoss: 1.0900 - val_z_gaussian_DKLloss: 1.1233e-04 - val_softmax_output_Categoricalloss: 0.0050 - val_softmax_output_accuracy: 0.8558
# Epoch 65/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3411 - reconstruction_loss: 1.1312 - z_gaussian_loss: 1.2044e-04 - softmax_output_loss: 0.0035 - reconstruction_BinaryLoss: 1.1312 - z_gaussian_DKLloss: 1.2044e-04 - softmax_output_Categoricalloss: 0.0035 - softmax_output_accuracy: 0.8543 - val_loss: 0.3295 - val_reconstruction_loss: 1.0902 - val_z_gaussian_loss: 7.3437e-05 - val_softmax_output_loss: 0.0049 - val_reconstruction_BinaryLoss: 1.0904 - val_z_gaussian_DKLloss: 7.4563e-05 - val_softmax_output_Categoricalloss: 0.0048 - val_softmax_output_accuracy: 0.8482
# Epoch 66/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3411 - reconstruction_loss: 1.1309 - z_gaussian_loss: 1.4306e-04 - softmax_output_loss: 0.0036 - reconstruction_BinaryLoss: 1.1309 - z_gaussian_DKLloss: 1.4304e-04 - softmax_output_Categoricalloss: 0.0036 - softmax_output_accuracy: 0.8533 - val_loss: 0.3282 - val_reconstruction_loss: 1.0875 - val_z_gaussian_loss: 1.8918e-04 - val_softmax_output_loss: 0.0038 - val_reconstruction_BinaryLoss: 1.0877 - val_z_gaussian_DKLloss: 1.9000e-04 - val_softmax_output_Categoricalloss: 0.0038 - val_softmax_output_accuracy: 0.8610
# Epoch 67/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3419 - reconstruction_loss: 1.1327 - z_gaussian_loss: 1.8762e-04 - softmax_output_loss: 0.0041 - reconstruction_BinaryLoss: 1.1327 - z_gaussian_DKLloss: 1.8763e-04 - softmax_output_Categoricalloss: 0.0041 - softmax_output_accuracy: 0.8470 - val_loss: 0.3298 - val_reconstruction_loss: 1.0902 - val_z_gaussian_loss: 8.4325e-05 - val_softmax_output_loss: 0.0054 - val_reconstruction_BinaryLoss: 1.0905 - val_z_gaussian_DKLloss: 8.4401e-05 - val_softmax_output_Categoricalloss: 0.0053 - val_softmax_output_accuracy: 0.8546
# Epoch 68/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3412 - reconstruction_loss: 1.1314 - z_gaussian_loss: 9.8393e-05 - softmax_output_loss: 0.0036 - reconstruction_BinaryLoss: 1.1314 - z_gaussian_DKLloss: 9.8553e-05 - softmax_output_Categoricalloss: 0.0036 - softmax_output_accuracy: 0.8530 - val_loss: 0.3283 - val_reconstruction_loss: 1.0876 - val_z_gaussian_loss: 6.0475e-05 - val_softmax_output_loss: 0.0040 - val_reconstruction_BinaryLoss: 1.0878 - val_z_gaussian_DKLloss: 6.2452e-05 - val_softmax_output_Categoricalloss: 0.0040 - val_softmax_output_accuracy: 0.8530
# Epoch 69/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3408 - reconstruction_loss: 1.1304 - z_gaussian_loss: 8.8609e-05 - softmax_output_loss: 0.0034 - reconstruction_BinaryLoss: 1.1304 - z_gaussian_DKLloss: 8.8707e-05 - softmax_output_Categoricalloss: 0.0034 - softmax_output_accuracy: 0.8539 - val_loss: 0.3285 - val_reconstruction_loss: 1.0880 - val_z_gaussian_loss: 7.7322e-05 - val_softmax_output_loss: 0.0042 - val_reconstruction_BinaryLoss: 1.0883 - val_z_gaussian_DKLloss: 7.7331e-05 - val_softmax_output_Categoricalloss: 0.0042 - val_softmax_output_accuracy: 0.8648
# Epoch 70/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3409 - reconstruction_loss: 1.1306 - z_gaussian_loss: 1.1662e-04 - softmax_output_loss: 0.0033 - reconstruction_BinaryLoss: 1.1306 - z_gaussian_DKLloss: 1.1668e-04 - softmax_output_Categoricalloss: 0.0033 - softmax_output_accuracy: 0.8532 - val_loss: 0.3294 - val_reconstruction_loss: 1.0901 - val_z_gaussian_loss: 8.3738e-05 - val_softmax_output_loss: 0.0047 - val_reconstruction_BinaryLoss: 1.0903 - val_z_gaussian_DKLloss: 8.4262e-05 - val_softmax_output_Categoricalloss: 0.0047 - val_softmax_output_accuracy: 0.8572
# Epoch 71/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3409 - reconstruction_loss: 1.1305 - z_gaussian_loss: 1.2251e-04 - softmax_output_loss: 0.0035 - reconstruction_BinaryLoss: 1.1304 - z_gaussian_DKLloss: 1.2247e-04 - softmax_output_Categoricalloss: 0.0035 - softmax_output_accuracy: 0.8541 - val_loss: 0.3284 - val_reconstruction_loss: 1.0882 - val_z_gaussian_loss: 9.3048e-05 - val_softmax_output_loss: 0.0039 - val_reconstruction_BinaryLoss: 1.0884 - val_z_gaussian_DKLloss: 9.3798e-05 - val_softmax_output_Categoricalloss: 0.0039 - val_softmax_output_accuracy: 0.8500
# Epoch 72/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3415 - reconstruction_loss: 1.1317 - z_gaussian_loss: 1.7000e-04 - softmax_output_loss: 0.0040 - reconstruction_BinaryLoss: 1.1317 - z_gaussian_DKLloss: 1.6997e-04 - softmax_output_Categoricalloss: 0.0040 - softmax_output_accuracy: 0.8496 - val_loss: 0.3283 - val_reconstruction_loss: 1.0883 - val_z_gaussian_loss: 6.4224e-05 - val_softmax_output_loss: 0.0037 - val_reconstruction_BinaryLoss: 1.0885 - val_z_gaussian_DKLloss: 6.3950e-05 - val_softmax_output_Categoricalloss: 0.0036 - val_softmax_output_accuracy: 0.8590
# Epoch 73/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3410 - reconstruction_loss: 1.1308 - z_gaussian_loss: 1.0702e-04 - softmax_output_loss: 0.0035 - reconstruction_BinaryLoss: 1.1308 - z_gaussian_DKLloss: 1.0705e-04 - softmax_output_Categoricalloss: 0.0035 - softmax_output_accuracy: 0.8525 - val_loss: 0.3288 - val_reconstruction_loss: 1.0897 - val_z_gaussian_loss: 1.4965e-04 - val_softmax_output_loss: 0.0037 - val_reconstruction_BinaryLoss: 1.0899 - val_z_gaussian_DKLloss: 1.4971e-04 - val_softmax_output_Categoricalloss: 0.0036 - val_softmax_output_accuracy: 0.8556
# Epoch 74/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3408 - reconstruction_loss: 1.1303 - z_gaussian_loss: 1.2532e-04 - softmax_output_loss: 0.0033 - reconstruction_BinaryLoss: 1.1303 - z_gaussian_DKLloss: 1.2544e-04 - softmax_output_Categoricalloss: 0.0033 - softmax_output_accuracy: 0.8560 - val_loss: 0.3284 - val_reconstruction_loss: 1.0881 - val_z_gaussian_loss: 2.4323e-04 - val_softmax_output_loss: 0.0039 - val_reconstruction_BinaryLoss: 1.0883 - val_z_gaussian_DKLloss: 2.4994e-04 - val_softmax_output_Categoricalloss: 0.0039 - val_softmax_output_accuracy: 0.8646
# Epoch 75/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3410 - reconstruction_loss: 1.1306 - z_gaussian_loss: 1.5911e-04 - softmax_output_loss: 0.0036 - reconstruction_BinaryLoss: 1.1307 - z_gaussian_DKLloss: 1.5911e-04 - softmax_output_Categoricalloss: 0.0036 - softmax_output_accuracy: 0.8505 - val_loss: 0.3287 - val_reconstruction_loss: 1.0882 - val_z_gaussian_loss: 8.5079e-05 - val_softmax_output_loss: 0.0045 - val_reconstruction_BinaryLoss: 1.0884 - val_z_gaussian_DKLloss: 8.5705e-05 - val_softmax_output_Categoricalloss: 0.0045 - val_softmax_output_accuracy: 0.8614
# Epoch 76/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3420 - reconstruction_loss: 1.1338 - z_gaussian_loss: 2.1243e-04 - softmax_output_loss: 0.0035 - reconstruction_BinaryLoss: 1.1338 - z_gaussian_DKLloss: 2.1238e-04 - softmax_output_Categoricalloss: 0.0036 - softmax_output_accuracy: 0.8475 - val_loss: 0.3289 - val_reconstruction_loss: 1.0885 - val_z_gaussian_loss: 7.9731e-05 - val_softmax_output_loss: 0.0047 - val_reconstruction_BinaryLoss: 1.0887 - val_z_gaussian_DKLloss: 8.0382e-05 - val_softmax_output_Categoricalloss: 0.0047 - val_softmax_output_accuracy: 0.8542
# Epoch 77/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3427 - reconstruction_loss: 1.1348 - z_gaussian_loss: 3.6687e-04 - softmax_output_loss: 0.0044 - reconstruction_BinaryLoss: 1.1348 - z_gaussian_DKLloss: 3.6670e-04 - softmax_output_Categoricalloss: 0.0044 - softmax_output_accuracy: 0.8413 - val_loss: 0.3301 - val_reconstruction_loss: 1.0916 - val_z_gaussian_loss: 4.3914e-05 - val_softmax_output_loss: 0.0053 - val_reconstruction_BinaryLoss: 1.0918 - val_z_gaussian_DKLloss: 4.4133e-05 - val_softmax_output_Categoricalloss: 0.0052 - val_softmax_output_accuracy: 0.8480
# Epoch 78/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3415 - reconstruction_loss: 1.1321 - z_gaussian_loss: 8.0581e-05 - softmax_output_loss: 0.0037 - reconstruction_BinaryLoss: 1.1321 - z_gaussian_DKLloss: 8.0570e-05 - softmax_output_Categoricalloss: 0.0037 - softmax_output_accuracy: 0.8497 - val_loss: 0.3286 - val_reconstruction_loss: 1.0876 - val_z_gaussian_loss: 3.0415e-05 - val_softmax_output_loss: 0.0047 - val_reconstruction_BinaryLoss: 1.0878 - val_z_gaussian_DKLloss: 3.0614e-05 - val_softmax_output_Categoricalloss: 0.0046 - val_softmax_output_accuracy: 0.8538
# Epoch 79/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3408 - reconstruction_loss: 1.1305 - z_gaussian_loss: 7.3257e-05 - softmax_output_loss: 0.0033 - reconstruction_BinaryLoss: 1.1305 - z_gaussian_DKLloss: 7.3255e-05 - softmax_output_Categoricalloss: 0.0034 - softmax_output_accuracy: 0.8531 - val_loss: 0.3284 - val_reconstruction_loss: 1.0872 - val_z_gaussian_loss: 3.5840e-05 - val_softmax_output_loss: 0.0045 - val_reconstruction_BinaryLoss: 1.0874 - val_z_gaussian_DKLloss: 3.6248e-05 - val_softmax_output_Categoricalloss: 0.0045 - val_softmax_output_accuracy: 0.8612
# Epoch 80/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3410 - reconstruction_loss: 1.1306 - z_gaussian_loss: 9.2633e-05 - softmax_output_loss: 0.0036 - reconstruction_BinaryLoss: 1.1306 - z_gaussian_DKLloss: 9.2714e-05 - softmax_output_Categoricalloss: 0.0036 - softmax_output_accuracy: 0.8517 - val_loss: 0.3278 - val_reconstruction_loss: 1.0860 - val_z_gaussian_loss: 7.8491e-05 - val_softmax_output_loss: 0.0040 - val_reconstruction_BinaryLoss: 1.0862 - val_z_gaussian_DKLloss: 7.9583e-05 - val_softmax_output_Categoricalloss: 0.0039 - val_softmax_output_accuracy: 0.8630
# Epoch 81/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3406 - reconstruction_loss: 1.1299 - z_gaussian_loss: 1.1070e-04 - softmax_output_loss: 0.0033 - reconstruction_BinaryLoss: 1.1299 - z_gaussian_DKLloss: 1.1081e-04 - softmax_output_Categoricalloss: 0.0033 - softmax_output_accuracy: 0.8538 - val_loss: 0.3288 - val_reconstruction_loss: 1.0888 - val_z_gaussian_loss: 7.8341e-05 - val_softmax_output_loss: 0.0042 - val_reconstruction_BinaryLoss: 1.0890 - val_z_gaussian_DKLloss: 7.9039e-05 - val_softmax_output_Categoricalloss: 0.0042 - val_softmax_output_accuracy: 0.8522
# Epoch 82/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3407 - reconstruction_loss: 1.1299 - z_gaussian_loss: 1.1041e-04 - softmax_output_loss: 0.0034 - reconstruction_BinaryLoss: 1.1299 - z_gaussian_DKLloss: 1.1044e-04 - softmax_output_Categoricalloss: 0.0034 - softmax_output_accuracy: 0.8549 - val_loss: 0.3282 - val_reconstruction_loss: 1.0874 - val_z_gaussian_loss: 1.1408e-04 - val_softmax_output_loss: 0.0039 - val_reconstruction_BinaryLoss: 1.0876 - val_z_gaussian_DKLloss: 1.1457e-04 - val_softmax_output_Categoricalloss: 0.0039 - val_softmax_output_accuracy: 0.8642
# Epoch 83/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3407 - reconstruction_loss: 1.1297 - z_gaussian_loss: 1.2861e-04 - softmax_output_loss: 0.0034 - reconstruction_BinaryLoss: 1.1297 - z_gaussian_DKLloss: 1.2873e-04 - softmax_output_Categoricalloss: 0.0034 - softmax_output_accuracy: 0.8543 - val_loss: 0.3295 - val_reconstruction_loss: 1.0914 - val_z_gaussian_loss: 1.1142e-04 - val_softmax_output_loss: 0.0042 - val_reconstruction_BinaryLoss: 1.0916 - val_z_gaussian_DKLloss: 1.1348e-04 - val_softmax_output_Categoricalloss: 0.0041 - val_softmax_output_accuracy: 0.8608
# Epoch 84/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3406 - reconstruction_loss: 1.1300 - z_gaussian_loss: 1.4081e-04 - softmax_output_loss: 0.0032 - reconstruction_BinaryLoss: 1.1300 - z_gaussian_DKLloss: 1.4086e-04 - softmax_output_Categoricalloss: 0.0032 - softmax_output_accuracy: 0.8527 - val_loss: 0.3287 - val_reconstruction_loss: 1.0895 - val_z_gaussian_loss: 1.5036e-04 - val_softmax_output_loss: 0.0036 - val_reconstruction_BinaryLoss: 1.0897 - val_z_gaussian_DKLloss: 1.5216e-04 - val_softmax_output_Categoricalloss: 0.0035 - val_softmax_output_accuracy: 0.8564
# Epoch 85/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3406 - reconstruction_loss: 1.1298 - z_gaussian_loss: 1.3953e-04 - softmax_output_loss: 0.0032 - reconstruction_BinaryLoss: 1.1298 - z_gaussian_DKLloss: 1.3965e-04 - softmax_output_Categoricalloss: 0.0032 - softmax_output_accuracy: 0.8560 - val_loss: 0.3274 - val_reconstruction_loss: 1.0858 - val_z_gaussian_loss: 1.4116e-04 - val_softmax_output_loss: 0.0034 - val_reconstruction_BinaryLoss: 1.0860 - val_z_gaussian_DKLloss: 1.4191e-04 - val_softmax_output_Categoricalloss: 0.0033 - val_softmax_output_accuracy: 0.8674
# Epoch 86/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3409 - reconstruction_loss: 1.1302 - z_gaussian_loss: 1.4909e-04 - softmax_output_loss: 0.0037 - reconstruction_BinaryLoss: 1.1302 - z_gaussian_DKLloss: 1.4906e-04 - softmax_output_Categoricalloss: 0.0037 - softmax_output_accuracy: 0.8519 - val_loss: 0.3280 - val_reconstruction_loss: 1.0867 - val_z_gaussian_loss: 6.8606e-05 - val_softmax_output_loss: 0.0040 - val_reconstruction_BinaryLoss: 1.0869 - val_z_gaussian_DKLloss: 6.9750e-05 - val_softmax_output_Categoricalloss: 0.0039 - val_softmax_output_accuracy: 0.8636
# Epoch 87/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3405 - reconstruction_loss: 1.1297 - z_gaussian_loss: 1.4159e-04 - softmax_output_loss: 0.0031 - reconstruction_BinaryLoss: 1.1297 - z_gaussian_DKLloss: 1.4167e-04 - softmax_output_Categoricalloss: 0.0032 - softmax_output_accuracy: 0.8560 - val_loss: 0.3285 - val_reconstruction_loss: 1.0879 - val_z_gaussian_loss: 8.3142e-05 - val_softmax_output_loss: 0.0042 - val_reconstruction_BinaryLoss: 1.0882 - val_z_gaussian_DKLloss: 8.3733e-05 - val_softmax_output_Categoricalloss: 0.0042 - val_softmax_output_accuracy: 0.8668
# Epoch 88/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3408 - reconstruction_loss: 1.1302 - z_gaussian_loss: 1.5025e-04 - softmax_output_loss: 0.0035 - reconstruction_BinaryLoss: 1.1303 - z_gaussian_DKLloss: 1.5043e-04 - softmax_output_Categoricalloss: 0.0035 - softmax_output_accuracy: 0.8542 - val_loss: 0.3295 - val_reconstruction_loss: 1.0896 - val_z_gaussian_loss: 1.2890e-04 - val_softmax_output_loss: 0.0051 - val_reconstruction_BinaryLoss: 1.0898 - val_z_gaussian_DKLloss: 1.2936e-04 - val_softmax_output_Categoricalloss: 0.0051 - val_softmax_output_accuracy: 0.8470
# Epoch 89/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3406 - reconstruction_loss: 1.1298 - z_gaussian_loss: 1.4771e-04 - softmax_output_loss: 0.0032 - reconstruction_BinaryLoss: 1.1298 - z_gaussian_DKLloss: 1.4776e-04 - softmax_output_Categoricalloss: 0.0032 - softmax_output_accuracy: 0.8550 - val_loss: 0.3290 - val_reconstruction_loss: 1.0901 - val_z_gaussian_loss: 9.4121e-05 - val_softmax_output_loss: 0.0039 - val_reconstruction_BinaryLoss: 1.0903 - val_z_gaussian_DKLloss: 9.4984e-05 - val_softmax_output_Categoricalloss: 0.0039 - val_softmax_output_accuracy: 0.8642
# Epoch 90/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3404 - reconstruction_loss: 1.1292 - z_gaussian_loss: 1.4723e-04 - softmax_output_loss: 0.0032 - reconstruction_BinaryLoss: 1.1292 - z_gaussian_DKLloss: 1.4722e-04 - softmax_output_Categoricalloss: 0.0032 - softmax_output_accuracy: 0.8575 - val_loss: 0.3277 - val_reconstruction_loss: 1.0864 - val_z_gaussian_loss: 7.3091e-05 - val_softmax_output_loss: 0.0036 - val_reconstruction_BinaryLoss: 1.0866 - val_z_gaussian_DKLloss: 7.3878e-05 - val_softmax_output_Categoricalloss: 0.0035 - val_softmax_output_accuracy: 0.8604
# Epoch 91/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3407 - reconstruction_loss: 1.1299 - z_gaussian_loss: 1.5621e-04 - softmax_output_loss: 0.0033 - reconstruction_BinaryLoss: 1.1299 - z_gaussian_DKLloss: 1.5618e-04 - softmax_output_Categoricalloss: 0.0033 - softmax_output_accuracy: 0.8539 - val_loss: 0.3289 - val_reconstruction_loss: 1.0882 - val_z_gaussian_loss: 1.2950e-04 - val_softmax_output_loss: 0.0049 - val_reconstruction_BinaryLoss: 1.0884 - val_z_gaussian_DKLloss: 1.2973e-04 - val_softmax_output_Categoricalloss: 0.0048 - val_softmax_output_accuracy: 0.8634
# Epoch 92/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3405 - reconstruction_loss: 1.1295 - z_gaussian_loss: 1.4731e-04 - softmax_output_loss: 0.0032 - reconstruction_BinaryLoss: 1.1295 - z_gaussian_DKLloss: 1.4729e-04 - softmax_output_Categoricalloss: 0.0032 - softmax_output_accuracy: 0.8526 - val_loss: 0.3280 - val_reconstruction_loss: 1.0864 - val_z_gaussian_loss: 8.4636e-05 - val_softmax_output_loss: 0.0042 - val_reconstruction_BinaryLoss: 1.0866 - val_z_gaussian_DKLloss: 8.5538e-05 - val_softmax_output_Categoricalloss: 0.0042 - val_softmax_output_accuracy: 0.8672
# Epoch 93/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3409 - reconstruction_loss: 1.1302 - z_gaussian_loss: 1.7515e-04 - softmax_output_loss: 0.0036 - reconstruction_BinaryLoss: 1.1302 - z_gaussian_DKLloss: 1.7522e-04 - softmax_output_Categoricalloss: 0.0037 - softmax_output_accuracy: 0.8522 - val_loss: 0.3281 - val_reconstruction_loss: 1.0874 - val_z_gaussian_loss: 1.8878e-04 - val_softmax_output_loss: 0.0037 - val_reconstruction_BinaryLoss: 1.0876 - val_z_gaussian_DKLloss: 1.8956e-04 - val_softmax_output_Categoricalloss: 0.0036 - val_softmax_output_accuracy: 0.8574
# Epoch 94/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3403 - reconstruction_loss: 1.1291 - z_gaussian_loss: 1.5733e-04 - softmax_output_loss: 0.0032 - reconstruction_BinaryLoss: 1.1291 - z_gaussian_DKLloss: 1.5734e-04 - softmax_output_Categoricalloss: 0.0032 - softmax_output_accuracy: 0.8541 - val_loss: 0.3283 - val_reconstruction_loss: 1.0875 - val_z_gaussian_loss: 1.1610e-04 - val_softmax_output_loss: 0.0041 - val_reconstruction_BinaryLoss: 1.0877 - val_z_gaussian_DKLloss: 1.1693e-04 - val_softmax_output_Categoricalloss: 0.0041 - val_softmax_output_accuracy: 0.8626
# Epoch 95/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3404 - reconstruction_loss: 1.1290 - z_gaussian_loss: 1.3570e-04 - softmax_output_loss: 0.0033 - reconstruction_BinaryLoss: 1.1290 - z_gaussian_DKLloss: 1.3576e-04 - softmax_output_Categoricalloss: 0.0033 - softmax_output_accuracy: 0.8552 - val_loss: 0.3279 - val_reconstruction_loss: 1.0862 - val_z_gaussian_loss: 7.3247e-05 - val_softmax_output_loss: 0.0041 - val_reconstruction_BinaryLoss: 1.0864 - val_z_gaussian_DKLloss: 7.4417e-05 - val_softmax_output_Categoricalloss: 0.0040 - val_softmax_output_accuracy: 0.8614
# Epoch 96/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3406 - reconstruction_loss: 1.1293 - z_gaussian_loss: 1.5350e-04 - softmax_output_loss: 0.0034 - reconstruction_BinaryLoss: 1.1293 - z_gaussian_DKLloss: 1.5346e-04 - softmax_output_Categoricalloss: 0.0034 - softmax_output_accuracy: 0.8547 - val_loss: 0.3282 - val_reconstruction_loss: 1.0869 - val_z_gaussian_loss: 8.3199e-05 - val_softmax_output_loss: 0.0041 - val_reconstruction_BinaryLoss: 1.0871 - val_z_gaussian_DKLloss: 8.5158e-05 - val_softmax_output_Categoricalloss: 0.0041 - val_softmax_output_accuracy: 0.8598
# Epoch 97/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3406 - reconstruction_loss: 1.1296 - z_gaussian_loss: 1.6364e-04 - softmax_output_loss: 0.0033 - reconstruction_BinaryLoss: 1.1296 - z_gaussian_DKLloss: 1.6363e-04 - softmax_output_Categoricalloss: 0.0033 - softmax_output_accuracy: 0.8533 - val_loss: 0.3281 - val_reconstruction_loss: 1.0856 - val_z_gaussian_loss: 7.8753e-05 - val_softmax_output_loss: 0.0048 - val_reconstruction_BinaryLoss: 1.0858 - val_z_gaussian_DKLloss: 8.0301e-05 - val_softmax_output_Categoricalloss: 0.0047 - val_softmax_output_accuracy: 0.8532
# Epoch 98/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3407 - reconstruction_loss: 1.1296 - z_gaussian_loss: 1.5581e-04 - softmax_output_loss: 0.0035 - reconstruction_BinaryLoss: 1.1296 - z_gaussian_DKLloss: 1.5597e-04 - softmax_output_Categoricalloss: 0.0035 - softmax_output_accuracy: 0.8522 - val_loss: 0.3281 - val_reconstruction_loss: 1.0863 - val_z_gaussian_loss: 1.4702e-04 - val_softmax_output_loss: 0.0043 - val_reconstruction_BinaryLoss: 1.0865 - val_z_gaussian_DKLloss: 1.4837e-04 - val_softmax_output_Categoricalloss: 0.0043 - val_softmax_output_accuracy: 0.8514
# Epoch 99/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3408 - reconstruction_loss: 1.1299 - z_gaussian_loss: 1.5214e-04 - softmax_output_loss: 0.0036 - reconstruction_BinaryLoss: 1.1299 - z_gaussian_DKLloss: 1.5234e-04 - softmax_output_Categoricalloss: 0.0036 - softmax_output_accuracy: 0.8527 - val_loss: 0.3296 - val_reconstruction_loss: 1.0892 - val_z_gaussian_loss: 2.3899e-04 - val_softmax_output_loss: 0.0057 - val_reconstruction_BinaryLoss: 1.0894 - val_z_gaussian_DKLloss: 2.4667e-04 - val_softmax_output_Categoricalloss: 0.0056 - val_softmax_output_accuracy: 0.8394
# Epoch 100/100
# 860/860 [==============================] - 7s 8ms/step - loss: 0.3405 - reconstruction_loss: 1.1293 - z_gaussian_loss: 1.5741e-04 - softmax_output_loss: 0.0034 - reconstruction_BinaryLoss: 1.1293 - z_gaussian_DKLloss: 1.5754e-04 - softmax_output_Categoricalloss: 0.0034 - softmax_output_accuracy: 0.8540 - val_loss: 0.3298 - val_reconstruction_loss: 1.0906 - val_z_gaussian_loss: 1.3010e-04 - val_softmax_output_loss: 0.0052 - val_reconstruction_BinaryLoss: 1.0908 - val_z_gaussian_DKLloss: 1.3188e-04 - val_softmax_output_Categoricalloss: 0.0052 - val_softmax_output_accuracy: 0.8456

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'reconstruction_loss', 'z_gaussian_loss', 'softmax_output_loss', 'reconstruction_BinaryLoss', 'z_gaussian_DKLloss', 'softmax_output_Categoricalloss', 'softmax_output_accuracy', 'val_loss', 'val_reconstruction_loss', 'val_z_gaussian_loss', 'val_softmax_output_loss', 'val_reconstruction_BinaryLoss', 'val_z_gaussian_DKLloss', 'val_softmax_output_Categoricalloss', 'val_softmax_output_accuracy'])

# %%
# Extraer las pérdidas del historial de entrenamiento
loss = history.history['loss']
val_loss = history.history['val_loss']
reconstruction_loss = history.history['reconstruction_BinaryLoss']
val_reconstruction_loss = history.history['val_reconstruction_BinaryLoss']
classification_loss = history.history['softmax_output_Categoricalloss']
val_classification_loss = history.history['val_softmax_output_Categoricalloss']
dkl_loss = history.history['z_gaussian_DKLloss']
val_dkl_loss = history.history['val_z_gaussian_DKLloss']

plt.figure(figsize=(14, 8))

# Gráfico para la pérdida total
plt.subplot(2, 2, 1)
plt.plot(loss, label='Training Total Loss')
plt.plot(val_loss, label='Validation Total Loss')
plt.title('Total Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Gráfico para la pérdida de reconstrucción
plt.subplot(2, 2, 2)
plt.plot(reconstruction_loss, label='Training Reconstruction Loss')
plt.plot(val_reconstruction_loss, label='Validation Reconstruction Loss')
plt.title('Reconstruction Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Gráfico para la pérdida de clasificación
plt.subplot(2, 2, 3)
plt.plot(classification_loss, label='Training Classification Loss')
plt.plot(val_classification_loss, label='Validation Classification Loss')
plt.title('Classification Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

# Gráfico para la pérdida DKL
plt.subplot(2, 2, 4)
plt.plot(dkl_loss, label='Training DKL Loss')
plt.plot(val_dkl_loss, label='Validation DKL Loss')
plt.title('DKL Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# En comparación con las graficas de perdidas sin normalizar se pueden observar algunas diferencias y patrones importantes en el entrenamiento y la validación del modelo:
#
# * **Pérdida Total (Total Training and Validation Loss)**: Se observa que tanto la pérdida total en entrenamiento como en validación disminuyen rápidamente en las primeras épocas y luego se estabilizan. La convergencia y la estabilidad en las curvas indican que el modelo no está sobreajustando significativamente y que ha alcanzado un estado estable en el aprendizaje.
#
# * **Pérdida de Reconstrucción (Reconstruction Loss):** Similar a la pérdida total, la pérdida de reconstrucción disminuye notablemente en las primeras épocas y luego se mantiene estable. Esto sugiere que el modelo es efectivo en reconstruir los datos, lo cual es crucial para tareas como autoencoder o modelado de generación.
#
# * **Pérdida de Clasificación (Classification Loss)**: La pérdida de clasificación también muestra una reducción constante y se estabiliza, con una pequeña brecha entre entrenamiento y validación. Esto es un buen indicador de que el modelo está generalizando bien sin un sobreajuste evidente. Los picos observados en el gráfico anterior se han atenuado, indicando posiblemente una mejor estabilidad en el aprendizaje tras la normalización.
#
# * **Pérdida de Divergencia Kullback-Leibler (DKL Loss)**: Este gráfico muestra fluctuaciones, especialmente en la fase de validación. Aunque las fluctuaciones son menores en comparación con el gráfico anterior, podrían indicar una variabilidad en cómo el modelo está aprendiendo las distribuciones de los datos. La pérdida de DKL puede ser sensible a los detalles de la implementación del modelo y a la calidad de los datos.

# %%
X_re_nor = model.predict(X_test)
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
X_re_nor[0].shape
# Out:
# (10000, 28, 28, 1)

# %% [markdown]
# # Reconstrucción

# %%
num_samples = 6 
indices_to_compare = [i for i in range(num_samples)] 

# Nombres de etiquetas para el dataset Fashion MNIST
label_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

compare_images(X_test, X_re_nor[0], y_test, label_names, indices_to_compare)

# %% [markdown]
# La gráfica demuestra que el modelo es capaz de reconstruir imágenes de ropa de manera razonable, preservando la forma general y la clase de los objetos.

# %% [markdown]
# # Espacio latente

# %%
z=X_re_nor[1].reshape(X_re_nor[1].shape[0],-1)

# %%
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(z)
tsne = TSNE(n_components=2, perplexity= 50)
z_tsne =  MinMaxScaler().fit_transform(tsne.fit_transform(scaled_data))

# %%
plt.figure(figsize=(10, 8))
cmap = plt.cm.tab10

plt.scatter(z_tsne[:, 0], z_tsne[:, 1], c=y_test, alpha=0.5, s=10, cmap=cmap)

# Inicializar posiciones de imágenes
image_positions = np.array([[1., 1.]])

# Iterar sobre las posiciones y añadir imágenes
for index, position in enumerate(z_tsne):
    dist = np.sum((position - image_positions) ** 2, axis=1)
    if np.min(dist) > 0.01:  # si está suficientemente lejos de otras imágenes
        image_positions = np.r_[image_positions, [position]]
        imagebox = mpl.offsetbox.AnnotationBbox(
            mpl.offsetbox.OffsetImage(X_train[index], cmap="binary"),  # Suponiendo que X_train contiene las imágenes originales
            position, bboxprops={"edgecolor": cmap(y_test[index]), "lw": 2})
        plt.gca().add_artist(imagebox)

# Configurar el gráfico y guardar la figura
plt.axis("off")
plt.show()

# %% [markdown]
# Si comparamos la grafica del espacio latente de ambos modelos, con funciones de pérdida normalizadas y sin normalizar, podemos observar que el espacio latente en este caso se nota mas regularizado.

# %% [markdown]
# # Clasificación

# %%
X_re_nor[2].shape
# Out:
# (10000, 10)

# %%
# Obtén las predicciones de clasificación
softmax_output = X_re_nor[2]  
predicted_labels = np.argmax(softmax_output, axis=1)

accuracy = accuracy_score(y_test, predicted_labels)
print("Accuracy:", accuracy)
print(classification_report(y_test, predicted_labels))
# Out:
# Accuracy: 0.8389
#               precision    recall  f1-score   support
#
#            0       0.63      0.89      0.73      1000
#            1       0.98      0.96      0.97      1000
#            2       0.77      0.73      0.75      1000
#            3       0.88      0.75      0.81      1000
#            4       0.75      0.80      0.78      1000
#            5       0.97      0.94      0.96      1000
#            6       0.62      0.48      0.54      1000
#            7       0.91      0.96      0.94      1000
#            8       0.96      0.92      0.94      1000
#            9       0.97      0.94      0.96      1000
#
#     accuracy                           0.84     10000
#    macro avg       0.84      0.84      0.84     10000
# weighted avg       0.84      0.84      0.84     10000

# %% [markdown]
# El rendimiento a comparacion con el modelo normalizado, disminuye el accuracy, pero podemos observar que en otros aspectos se ve mas estable, a parte la sincronización de los pesos de cada función de perdida fueron impuestos y no se realizo una rejilla de busqueda.

# %% [markdown]
# # Reconstrucción y clasificación

# %%
N = 15
predicted_labels = np.argmax(X_re_nor[2][:N], axis=1) 
plot_mnist_autoencoder(
    X_test[:N], 
    X_re_nor[0][:N], 
    y_test[:N],  
    predicted_labels  
)

# %% [markdown]
# En este primer conjunto de datos se ve una buena clasificación y su respectiva recosntrucción, donde podemos observar que en el conjunto de 15 imagenes, solo se equivoca una vez clasificando.

# %% [markdown]
# # Cams

# %%
tf.keras.utils.plot_model(model, show_layer_names=True, show_shapes=True, dpi=96)

# %%
layers = ['conv1', 'conv2', 'conv3']

# Visualizar la imagen original con mayor tamaño
fig, axes = plt.subplots(1, 5, figsize=(25, 5))

num_images = 5
images = X_test[:num_images].reshape(-1, 28, 28, 1)
labels = y_test[:num_images]

for i in range(5):
    image = images[i]
    label = labels[i]
    ax_img = axes[i]
    ax_img.imshow(image.squeeze(), cmap='gray')
    ax_img.axis('off')
    ax_img.set_title(f'Original\nClass {label}')

for layer in layers:
    # Crear el modelo que solo tenga la salida del clasificador
    model_for_gradcam = tf.keras.models.Model(inputs=model.input, outputs=model.get_layer('softmax_output').output)

    # Crear el objeto GradCAM++
    gradcam = GradcamPlusPlus(model_for_gradcam, model_modifier=ReplaceToLinear(), clone=True)

    # Seleccionar las primeras 6 imágenes del conjunto de prueba
    num_images = 6
    images = X_test[:num_images].reshape(-1, 28, 28, 1)
    labels = y_test[:num_images]

    # Crear una figura con subplots
    fig, axes = plt.subplots(1, 6, figsize=(25, 5))
    fig.suptitle(f'GradCAM++ for layer {layer}', fontsize=16)  # Añadir título con el nombre de la capa

    for i, (image, label) in enumerate(zip(images, labels)):
        # Generar el CAM con GradCAM++ usando la capa actual
        cam = gradcam(CategoricalScore(label), image.reshape(1, 28, 28, 1), penultimate_layer=layer)

        # Visualizar el mapa de calor superpuesto en la imagen original
        heatmap = np.uint8(cm.jet(cam[0])[..., :3] * 255)
        ax_heatmap = axes[i]
        ax_heatmap.imshow(image.squeeze(), cmap='gray')
        ax_heatmap.imshow(heatmap, cmap='jet', alpha=0.5)
        ax_heatmap.axis('off')
        ax_heatmap.set_title(f'Class {label}')
        
        # Añadir la barra de colores (color bar)
        norm = plt.Normalize(vmin=cam[0].min(), vmax=cam[0].max())
        sm = plt.cm.ScalarMappable(cmap='jet', norm=norm)
        sm.set_array([])
        fig.colorbar(sm, ax=ax_heatmap, orientation="vertical", fraction=0.046, pad=0.04)
    
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # Ajustar layout para el título
    plt.show()

# %% [markdown]
# La normalización de las funciones de costo parece mejorar la claridad y la focalización de las activaciones en los Class Activation Maps, permitiendo una mejor interpretación de las decisiones del modelo. Esto es beneficioso para identificar qué características específicas están impulsando las predicciones del modelo y puede ayudar en el ajuste y mejora del mismo

# %%
layers = ['conv1', 'conv2', 'conv3']

# Visualizar la imagen original con mayor tamaño
fig, axes = plt.subplots(1, 5, figsize=(25, 5))

for i in range(5):
    num_images = 5
    images = X_test[:num_images].reshape(-1, 28, 28, 1)
    image = images[i]
    ax_img = axes[i]
    ax_img.imshow(image.squeeze(), cmap='gray')
    ax_img.axis('off')
    ax_img.set_title(f'Original\nClass {label}')

for layer in layers:
    # Crear el modelo que solo tenga la salida del clasificador
    model_for_gradcam = tf.keras.models.Model(inputs=model.input, outputs=model.get_layer('softmax_output').output)

    # Crear el objeto GradCAM++
    gradcam = GradcamPlusPlus(model_for_gradcam, model_modifier=ReplaceToLinear(), clone=True)

    # Seleccionar las primeras 6 imágenes del conjunto de prueba
    num_images = 6
    images = X_test[:num_images].reshape(-1, 28, 28, 1)
    labels = y_test[:num_images]

    # Crear una figura con subplots
    fig, axes = plt.subplots(1, 6, figsize=(25, 5))
    fig.suptitle(f'GradCAM++ for layer {layer}', fontsize=16)  # Añadir título con el nombre de la capa

    for i, (image, label) in enumerate(zip(images, labels)):
        # Generar el CAM con GradCAM++ usando la capa 'convv'
        cam = gradcam(CategoricalScore(9), image.reshape(1, 28, 28, 1), penultimate_layer=layer, normalize_cam=False)

        # Visualizar el mapa de calor superpuesto en la imagen original
        heatmap = np.uint8(cm.jet(cam[0])[..., :3] * 255)
        ax_heatmap = axes[i]
        ax_heatmap.imshow(image.squeeze(), cmap='gray')
        ax_heatmap.imshow(heatmap, cmap='jet', alpha=0.5)
        ax_heatmap.axis('off')
        ax_heatmap.set_title(f'Class {label}')
        
        # Añadir la barra de colores (color bar)
        norm = plt.Normalize(vmin=cam[0].min(), vmax=cam[0].max())
        sm = plt.cm.ScalarMappable(cmap='jet', norm=norm)
        sm.set_array([])
        fig.colorbar(sm, ax=ax_heatmap, orientation="vertical", fraction=0.046, pad=0.04)
    
    plt.tight_layout(rect=[0, 0.03, 1, 0.95])  # Ajustar layout para el título
    plt.show()
